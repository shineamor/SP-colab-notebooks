# %% [markdown]
# <a href="https://colab.research.google.com/github/shineamor/SP-colab-notebooks/blob/main/qcnn_SAM_denoising_1000.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2.0.2)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (1.15.3)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (11.2.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2025.5.10)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (0.4)

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !find /content/drive/MyDrive -type d -name "quaternion_layers"
# Out:
# /content/drive/MyDrive/quaternion_layers

# %%
import sys
sys.path.append('/content/drive/MyDrive')

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.7.4.5)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.4.26)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.4.2)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from kaggle) (5.29.4)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.11/dist-packages (from kaggle) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.4.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from kaggle) (0.5.1)

# %%
pip install tensorflow-datasets
# Out:
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.11/dist-packages (4.9.8)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.4.0)
# Requirement already satisfied: array_record>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.7.2)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.1.9)
# Requirement already satisfied: etils>=1.9.1 in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (1.12.2)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (4.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (2.0.2)
# Requirement already satisfied: promise in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (5.29.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (18.1.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (2.32.3)
# Requirement already satisfied: simple_parsing in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.1.7)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.17.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (3.1.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.10.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (4.67.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.17.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (0.8.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (2025.3.2)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (6.5.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (4.13.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow-datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow-datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow-datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow-datasets) (2025.4.26)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.11/dist-packages (from dm-tree->tensorflow-datasets) (25.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from promise->tensorflow-datasets) (1.17.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.11/dist-packages (from simple_parsing->tensorflow-datasets) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /usr/local/lib/python3.11/dist-packages (from tensorflow-metadata->tensorflow-datasets) (1.70.0)

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import numpy as np
import PIL, os, random, skimage.util, csv
import tensorflow.keras.backend as K
from google.colab import files
from quaternion_layers import QConv2D, QDense
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, AveragePooling2D, UpSampling2D, Reshape, Flatten, Input, Add, Multiply, GlobalAveragePooling2D, GlobalMaxPooling2D, Concatenate, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import time

#Load Oxford Flowers dataset
dataset, info = tfds.load(
    "oxford_flowers102",
    with_info=True,
    as_supervised=True
)
print(info.splits)

#Function to covert TF Dataset to NumPy arrays
def ds_to_numpy(dataset):
    images, labels = [], []
    for img, lbl in dataset:
        images.append(img.numpy())
        labels.append(lbl.numpy())
    return np.array(images), np.array(labels)

#Preprocessing function: Resize & Normalize images
def preprocess_augmented(image, label):
    image = tf.image.resize(image, [128, 128])
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.rot90(image, k=np.random.randint(4))
    image = tf.cast(image, tf.float32) / 255.0
    image = (image * 2.0) - 1.0
    return image, label
def preprocess_clean(image, label):
    image = tf.image.resize(image, [128, 128])
    image = tf.cast(image, tf.float32) / 255.0
    image = (image * 2.0) - 1.0
    return image, label

# Function to add noise to images (Salt & Pepper, Gaussian)
def add_noise(images, noise_factor=0.2, salt_pepper_amount=0.1):
    noisy_images = []
    for img in images:
        # Add salt & pepper noise
        img_sp = skimage.util.random_noise(img, mode='s&p', amount=salt_pepper_amount)

        # Add Gaussian noise
        img_noisy = img_sp + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=img.shape)
        img_noisy = np.clip(img_noisy, -1.0, 1.0)  # Ensure values are in the valid range [-1, 1]

        noisy_images.append(img_noisy)

    return np.array(noisy_images)

def PSNR(y_true, y_pred):
    max_pixel = 1.0  # Since images are normalized to [-1,1]
    return 10.0 * K.log((max_pixel ** 2) / (K.mean(K.square(y_pred - y_true)))) / K.log(10.0)

def ssim_metric(y_true, y_pred):
    return tf.reduce_mean(tf.image.ssim(y_true, y_pred, max_val=2.0))

# Define the Spatial Attention Module (SAM)
def spatial_attention(input_feature):
    avg_pool = Lambda(lambda x: tf.reduce_mean(x, axis=-1, keepdims=True))(input_feature)
    max_pool = Lambda(lambda x: tf.reduce_max(x, axis=-1, keepdims=True))(input_feature)
    concat = Concatenate(axis=-1)([avg_pool, max_pool])
    attention = Conv2D(1, kernel_size=7, padding='same', activation='sigmoid')(concat)
    return Multiply()([input_feature, attention])

# Load dataset splits
splits, info = tfds.load(
    'oxford_flowers102',
    split=['train','test','validation'],
    as_supervised=True,
    with_info=True
)
train_ds, test_ds, val_ds = splits

# Apply preprocessing to dataset
train_ds = train_ds.map(preprocess_augmented, num_parallel_calls=tf.data.AUTOTUNE)
test_ds  = test_ds.map(preprocess_clean, num_parallel_calls=tf.data.AUTOTUNE)
val_ds   = val_ds.map(preprocess_clean, num_parallel_calls=tf.data.AUTOTUNE)

# Convert dataset to NumPy arrays
(x_train, _), (x_valid, _), (x_test, _) = (
    ds_to_numpy(train_ds),
    ds_to_numpy(val_ds),
    ds_to_numpy(test_ds)
)

# Convert each split to NumPy
(x_train, y_train) = ds_to_numpy(train_ds)
(x_test, y_test)   = ds_to_numpy(test_ds)
(x_valid, y_valid) = ds_to_numpy(val_ds)

print("Train shape:", x_train.shape)
print("Valid shape:", x_valid.shape)
print("Test shape: ", x_test.shape)

# Model Configuration
encoding_size = 90
perturbation_max = 40
image_shape = (128,128,3)

# Define Model Architecture
model_input = Input(shape=image_shape)

# Encoder
conv1 = QConv2D(23, 3, padding='same', activation='relu')(model_input)
print("conv1 shape:", conv1.shape)
conv1 = spatial_attention(conv1)  # Apply SAM here
print("after SAM conv1 shape:", conv1.shape)
conv2 = QConv2D(23, 3, padding='same', activation='relu')(conv1)
print("conv2 shape:", conv2.shape)
pool1 = AveragePooling2D(2, 2)(conv2)
print("pool1 shape:", pool1.shape)
conv3 = QConv2D(45, 3, padding='same', activation='relu')(pool1)
print("conv3 shape:", conv3.shape)
conv3 = spatial_attention(conv3)  # Apply SAM here
print("SAM conv3 shape:", conv3.shape)
conv4 = QConv2D(45, 3, padding='same', activation='relu')(conv3)
print("conv4 shape:", conv4.shape)
pool2 = AveragePooling2D(2, 2)(conv4)
print("pool2 shape:", pool2.shape)
conv5 = QConv2D(90, 3, padding='same', activation='relu')(pool2)
print("conv5 shape:", conv5.shape)
conv5 = spatial_attention(conv5)  # Apply SAM here
print("SAM conv5 shape:", conv5.shape)
conv6 = QConv2D(90, 3, padding='same', activation='relu')(conv5)
print("conv6 shape:", conv6.shape)

# Decoder
flatten = Flatten()(conv6)
print("flatten shape:", flatten.shape)
encoding = QDense(encoding_size, activation='relu')(flatten)
print("encoding shape:", encoding.shape)
dense2 = QDense(192, activation='relu')(encoding)
print("dense2 shape:", dense2.shape)
reshape = Reshape((8, 8, 9))(dense2)
print("reshape shape:", reshape.shape)
upsample2 = UpSampling2D(size=(4, 4))(reshape)
print("upsample2 shape:", upsample2.shape)
conv11 = QConv2D(90, 3, padding='same', activation='relu')(upsample2)
print("conv11 shape:", conv11.shape)
conv12 = QConv2D(90, 3, padding='same', activation='relu')(conv11)
print("conv12 shape:", conv12.shape)
add1 = Add()([conv12, conv6])
print("add1 shape:", add1.shape)
upsample3 = UpSampling2D(size=(4, 4))(add1)
print("upsample3 shape:", upsample3.shape)
conv13 = QConv2D(45, 3, padding='same', activation='relu')(upsample3)
print("conv13 shape:", conv13.shape)
conv13 = spatial_attention(conv13)  # Apply SAM here
print("conv13 shape:", conv13.shape)
conv14 = QConv2D(45, 3, padding='same', activation='relu')(conv13)
print("conv14 shape:", conv14.shape)
upsample_conv4 = UpSampling2D(size=(2, 2))(conv4)
print("upsample_conv4 shape:", upsample_conv4.shape)
add2 = Add()([conv14, upsample_conv4])
print("add2 shape:", add2.shape)
upsample3 = UpSampling2D(size=(4, 4))(add2)
conv15 = QConv2D(8, 3, padding='same', activation='relu')(add2)
print("conv15 shape:", conv15.shape)
conv16 = QConv2D(1, 3, padding='same', activation='tanh')(conv15)
print("conv16 shape:", conv16.shape)

autoencoder = Model(model_input, conv16)
autoencoder.compile(loss='mse', optimizer=Adam(1e-4), metrics=[PSNR, ssim_metric])

# Ensure checkpoint directory exists
checkpoint_dir = 'checkpoint_oxford_flowers'
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

# Define callbacks
checkpoint = ModelCheckpoint('checkpoint_oxford_flowers/best_weights.keras', monitor='val_loss', save_best_only=True, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=20, verbose=1)

# Generate noisy data
x_train_noisy = add_noise(x_train)
x_valid_noisy = add_noise(x_valid)

# Start runtime tracking
start_time = time.time()

#start training
epochs = 1000
batch_size = 32
history = autoencoder.fit(
    x_train_noisy, x_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_valid_noisy, x_valid),
    callbacks=[checkpoint, early_stop]
)

# Stop runtime tracking
elapsed_time = time.time() - start_time
print(f"\n🚀 Training Completed in {int(elapsed_time // 60)} min {int(elapsed_time % 60)} sec")

history_dict = history.history
num_epochs = len(history_dict['loss'])

csv_filename = f"qcnn-SAM_comparison_plot_{epochs}_epochs.csv"
with open(csv_filename, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["epoch","loss","val_loss","psnr","val_psnr","ssim_metric","val_ssim_metric"])
     # One row per epoch
    for epoch_idx in range(num_epochs):
        row = [
            epoch_idx + 1,
            history_dict['loss'][epoch_idx],
            history_dict['val_loss'][epoch_idx],
            history_dict['psnr'][epoch_idx],
            history_dict['val_psnr'][epoch_idx],
            history_dict['ssim_metric'][epoch_idx],
            history_dict['val_ssim_metric'][epoch_idx]
        ]
        writer.writerow(row)

# Download CSV in Colab
files.download(csv_filename)

# Denoise the images using the autoencoder
denoised_images = autoencoder.predict(x_valid_noisy)

plot_filename_loss = f"qcnn-SAM_loss_plot_{epochs}_epochs.png"
plot_filename_psnr = f"qcnn-SAM_psnr_plot_{epochs}_epochs.png"
plot_filename_ssim = f"qcnn-SAM_ssim_plot_{epochs}_epochs.png"
plot_filename_comparison = f"qcnn-SAM_comparison_plot_{epochs}_epochs.png"

# Plot training & validation loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig(plot_filename_loss)
plt.show()

# Plot PSNR
plt.figure()
plt.plot(history.history['psnr'], label='Train PSNR')
plt.plot(history.history['val_psnr'], label='Val PSNR')
plt.title('Model PSNR')
plt.xlabel('Epochs')
plt.ylabel('PSNR (dB)')
plt.legend()
plt.savefig(plot_filename_psnr)
plt.show()

#Plot SSIM
plt.figure()
plt.plot(history.history['ssim_metric'], label='Train SSIM')
plt.plot(history.history['val_ssim_metric'], label='Val SSIM')
plt.title('Model SSIM')
plt.xlabel('Epochs')
plt.ylabel('SSIM')
plt.legend()
plt.savefig(plot_filename_ssim)
plt.show()

files.download(plot_filename_loss)
files.download(plot_filename_psnr)
files.download(plot_filename_ssim)

def deprocess(x):
    x = (x + 1.0) * 127.5
    return np.clip(x, 0, 255).astype(np.uint8)

def display_images(original, noisy, denoised, n=5):
    plt.figure(figsize=(20, 6))
    for i in range(n):
        # Original
        ax = plt.subplot(3, n, i+1)
        plt.imshow(deprocess(original[i]))
        plt.title("Original")
        plt.axis("off")

        # Noisy
        ax = plt.subplot(3, n, i+1+n)
        plt.imshow(deprocess(noisy[i]))
        plt.title("Noisy")
        plt.axis("off")

        # Denoised
        ax = plt.subplot(3, n, i+1+2*n)
        plt.imshow(deprocess(denoised[i]))
        plt.title("Denoised")
        plt.axis("off")
    plt.savefig(plot_filename_comparison)
    plt.show()
    files.download(plot_filename_comparison)

# Visualize the first 5 original, noisy, and denoised images
display_images(x_valid, x_valid_noisy, denoised_images, n=5)

print("Training and visualization complete.")
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/oxford_flowers102/2.1.1 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/oxford_flowers102/2.1.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_flowers102/incomplete.FM3BKT_2.1.1/oxford_flowers102-train.tfrecord…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_flowers102/incomplete.FM3BKT_2.1.1/oxford_flowers102-test.tfrecord*…
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_flowers102/incomplete.FM3BKT_2.1.1/oxford_flowers102-validation.tfr…
# Dataset oxford_flowers102 downloaded and prepared to /root/tensorflow_datasets/oxford_flowers102/2.1.1. Subsequent calls will reuse this data.
# {Split('train'): <SplitInfo num_examples=1020, num_shards=1>, Split('test'): <SplitInfo num_examples=6149, num_shards=2>, Split('validation'): <SplitInfo num_examples=1020, num_shards=1>}
# Train shape: (1020, 128, 128, 3)
# Valid shape: (1020, 128, 128, 3)
# Test shape:  (6149, 128, 128, 3)
# conv1 shape: (None, 128, 128, 69)
# after SAM conv1 shape: (None, 128, 128, 69)
# conv2 shape: (None, 128, 128, 69)
# pool1 shape: (None, 64, 64, 69)
# conv3 shape: (None, 64, 64, 135)
# SAM conv3 shape: (None, 64, 64, 135)
# conv4 shape: (None, 64, 64, 135)
# pool2 shape: (None, 32, 32, 135)
# conv5 shape: (None, 32, 32, 270)
# SAM conv5 shape: (None, 32, 32, 270)
# conv6 shape: (None, 32, 32, 270)
# flatten shape: (None, 276480)
# encoding shape: (None, 270)
# dense2 shape: (None, 576)
# reshape shape: (None, 8, 8, 9)
# upsample2 shape: (None, 32, 32, 9)
# conv11 shape: (None, 32, 32, 270)
# conv12 shape: (None, 32, 32, 270)
# add1 shape: (None, 32, 32, 270)
# upsample3 shape: (None, 128, 128, 270)
# conv13 shape: (None, 128, 128, 135)
# conv13 shape: (None, 128, 128, 135)
# conv14 shape: (None, 128, 128, 135)
# upsample_conv4 shape: (None, 128, 128, 135)
# add2 shape: (None, 128, 128, 135)
# conv15 shape: (None, 128, 128, 24)
# conv16 shape: (None, 128, 128, 3)
# Epoch 1/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.3692 - psnr: 4.3577 - ssim_metric: 0.0210
# Epoch 1: val_loss improved from inf to 0.22155, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 166s 3s/step - loss: 0.3680 - psnr: 4.3744 - ssim_metric: 0.0220 - val_loss: 0.2216 - val_psnr: 6.5536 - val_ssim_metric: 0.1441
# Epoch 2/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - loss: 0.1714 - psnr: 7.8511 - ssim_metric: 0.2036
# Epoch 2: val_loss improved from 0.22155 to 0.06553, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 72s 771ms/step - loss: 0.1701 - psnr: 7.8938 - ssim_metric: 0.2053 - val_loss: 0.0655 - val_psnr: 11.8428 - val_ssim_metric: 0.3558
# Epoch 3/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 584ms/step - loss: 0.0609 - psnr: 12.1697 - ssim_metric: 0.3897
# Epoch 3: val_loss improved from 0.06553 to 0.04817, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 945ms/step - loss: 0.0608 - psnr: 12.1802 - ssim_metric: 0.3903 - val_loss: 0.0482 - val_psnr: 13.1810 - val_ssim_metric: 0.4414
# Epoch 4/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 564ms/step - loss: 0.0465 - psnr: 13.3346 - ssim_metric: 0.4546
# Epoch 4: val_loss improved from 0.04817 to 0.03993, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 924ms/step - loss: 0.0465 - psnr: 13.3401 - ssim_metric: 0.4550 - val_loss: 0.0399 - val_psnr: 13.9970 - val_ssim_metric: 0.4911
# Epoch 5/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - loss: 0.0387 - psnr: 14.1427 - ssim_metric: 0.5053
# Epoch 5: val_loss improved from 0.03993 to 0.03461, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 924ms/step - loss: 0.0386 - psnr: 14.1467 - ssim_metric: 0.5056 - val_loss: 0.0346 - val_psnr: 14.6182 - val_ssim_metric: 0.5328
# Epoch 6/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 581ms/step - loss: 0.0346 - psnr: 14.6148 - ssim_metric: 0.5375
# Epoch 6: val_loss improved from 0.03461 to 0.03224, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 942ms/step - loss: 0.0346 - psnr: 14.6187 - ssim_metric: 0.5377 - val_loss: 0.0322 - val_psnr: 14.9269 - val_ssim_metric: 0.5497
# Epoch 7/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - loss: 0.0316 - psnr: 15.0117 - ssim_metric: 0.5543
# Epoch 7: val_loss improved from 0.03224 to 0.03025, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 922ms/step - loss: 0.0316 - psnr: 15.0127 - ssim_metric: 0.5544 - val_loss: 0.0303 - val_psnr: 15.2031 - val_ssim_metric: 0.5620
# Epoch 8/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - loss: 0.0297 - psnr: 15.2873 - ssim_metric: 0.5708
# Epoch 8: val_loss improved from 0.03025 to 0.02894, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 929ms/step - loss: 0.0297 - psnr: 15.2869 - ssim_metric: 0.5707 - val_loss: 0.0289 - val_psnr: 15.3961 - val_ssim_metric: 0.5711
# Epoch 9/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - loss: 0.0289 - psnr: 15.3976 - ssim_metric: 0.5725
# Epoch 9: val_loss improved from 0.02894 to 0.02792, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 937ms/step - loss: 0.0289 - psnr: 15.3990 - ssim_metric: 0.5726 - val_loss: 0.0279 - val_psnr: 15.5528 - val_ssim_metric: 0.5758
# Epoch 10/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - loss: 0.0278 - psnr: 15.5746 - ssim_metric: 0.5807
# Epoch 10: val_loss improved from 0.02792 to 0.02713, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 925ms/step - loss: 0.0278 - psnr: 15.5754 - ssim_metric: 0.5807 - val_loss: 0.0271 - val_psnr: 15.6770 - val_ssim_metric: 0.5805
# Epoch 11/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - loss: 0.0273 - psnr: 15.6435 - ssim_metric: 0.5819
# Epoch 11: val_loss improved from 0.02713 to 0.02657, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 37s 789ms/step - loss: 0.0273 - psnr: 15.6457 - ssim_metric: 0.5820 - val_loss: 0.0266 - val_psnr: 15.7672 - val_ssim_metric: 0.5861
# Epoch 12/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 584ms/step - loss: 0.0266 - psnr: 15.7676 - ssim_metric: 0.5880
# Epoch 12: val_loss improved from 0.02657 to 0.02577, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 945ms/step - loss: 0.0266 - psnr: 15.7695 - ssim_metric: 0.5880 - val_loss: 0.0258 - val_psnr: 15.8997 - val_ssim_metric: 0.5874
# Epoch 13/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - loss: 0.0252 - psnr: 15.9856 - ssim_metric: 0.5933
# Epoch 13: val_loss improved from 0.02577 to 0.02524, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 917ms/step - loss: 0.0253 - psnr: 15.9838 - ssim_metric: 0.5932 - val_loss: 0.0252 - val_psnr: 15.9899 - val_ssim_metric: 0.5914
# Epoch 14/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 564ms/step - loss: 0.0253 - psnr: 15.9901 - ssim_metric: 0.5958
# Epoch 14: val_loss improved from 0.02524 to 0.02475, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 930ms/step - loss: 0.0253 - psnr: 15.9906 - ssim_metric: 0.5958 - val_loss: 0.0248 - val_psnr: 16.0754 - val_ssim_metric: 0.5946
# Epoch 15/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - loss: 0.0250 - psnr: 16.0329 - ssim_metric: 0.5963
# Epoch 15: val_loss improved from 0.02475 to 0.02448, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 930ms/step - loss: 0.0250 - psnr: 16.0348 - ssim_metric: 0.5964 - val_loss: 0.0245 - val_psnr: 16.1239 - val_ssim_metric: 0.5944
# Epoch 16/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - loss: 0.0242 - psnr: 16.1759 - ssim_metric: 0.6011
# Epoch 16: val_loss improved from 0.02448 to 0.02394, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 928ms/step - loss: 0.0242 - psnr: 16.1756 - ssim_metric: 0.6010 - val_loss: 0.0239 - val_psnr: 16.2198 - val_ssim_metric: 0.5989
# Epoch 17/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - loss: 0.0243 - psnr: 16.1509 - ssim_metric: 0.6040
# Epoch 17: val_loss improved from 0.02394 to 0.02365, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 915ms/step - loss: 0.0243 - psnr: 16.1532 - ssim_metric: 0.6039 - val_loss: 0.0236 - val_psnr: 16.2732 - val_ssim_metric: 0.6012
# Epoch 18/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - loss: 0.0235 - psnr: 16.2960 - ssim_metric: 0.6065
# Epoch 18: val_loss improved from 0.02365 to 0.02337, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 37s 792ms/step - loss: 0.0235 - psnr: 16.2959 - ssim_metric: 0.6064 - val_loss: 0.0234 - val_psnr: 16.3258 - val_ssim_metric: 0.6036
# Epoch 19/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 560ms/step - loss: 0.0231 - psnr: 16.3739 - ssim_metric: 0.6067
# Epoch 19: val_loss improved from 0.02337 to 0.02321, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 45s 920ms/step - loss: 0.0231 - psnr: 16.3730 - ssim_metric: 0.6067 - val_loss: 0.0232 - val_psnr: 16.3549 - val_ssim_metric: 0.6046
# Epoch 20/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - loss: 0.0228 - psnr: 16.4399 - ssim_metric: 0.6089
# Epoch 20: val_loss improved from 0.02321 to 0.02312, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 936ms/step - loss: 0.0228 - psnr: 16.4384 - ssim_metric: 0.6089 - val_loss: 0.0231 - val_psnr: 16.3708 - val_ssim_metric: 0.6057
# Epoch 21/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 562ms/step - loss: 0.0231 - psnr: 16.3785 - ssim_metric: 0.6092
# Epoch 21: val_loss did not improve from 0.02312
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 28s 893ms/step - loss: 0.0231 - psnr: 16.3800 - ssim_metric: 0.6093 - val_loss: 0.0232 - val_psnr: 16.3484 - val_ssim_metric: 0.6026
# Epoch 22/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - loss: 0.0228 - psnr: 16.4216 - ssim_metric: 0.6122
# Epoch 22: val_loss improved from 0.02312 to 0.02237, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 926ms/step - loss: 0.0228 - psnr: 16.4226 - ssim_metric: 0.6122 - val_loss: 0.0224 - val_psnr: 16.5141 - val_ssim_metric: 0.6117
# Epoch 23/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - loss: 0.0220 - psnr: 16.5922 - ssim_metric: 0.6186
# Epoch 23: val_loss improved from 0.02237 to 0.02218, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 938ms/step - loss: 0.0220 - psnr: 16.5904 - ssim_metric: 0.6185 - val_loss: 0.0222 - val_psnr: 16.5522 - val_ssim_metric: 0.6141
# Epoch 24/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - loss: 0.0220 - psnr: 16.5824 - ssim_metric: 0.6148
# Epoch 24: val_loss improved from 0.02218 to 0.02197, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 922ms/step - loss: 0.0220 - psnr: 16.5819 - ssim_metric: 0.6149 - val_loss: 0.0220 - val_psnr: 16.5928 - val_ssim_metric: 0.6140
# Epoch 25/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - loss: 0.0217 - psnr: 16.6432 - ssim_metric: 0.6179
# Epoch 25: val_loss improved from 0.02197 to 0.02186, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 933ms/step - loss: 0.0217 - psnr: 16.6419 - ssim_metric: 0.6179 - val_loss: 0.0219 - val_psnr: 16.6153 - val_ssim_metric: 0.6147
# Epoch 26/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - loss: 0.0221 - psnr: 16.5803 - ssim_metric: 0.6172
# Epoch 26: val_loss improved from 0.02186 to 0.02174, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 931ms/step - loss: 0.0221 - psnr: 16.5821 - ssim_metric: 0.6172 - val_loss: 0.0217 - val_psnr: 16.6382 - val_ssim_metric: 0.6154
# Epoch 27/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - loss: 0.0219 - psnr: 16.5990 - ssim_metric: 0.6174
# Epoch 27: val_loss improved from 0.02174 to 0.02149, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 923ms/step - loss: 0.0219 - psnr: 16.6008 - ssim_metric: 0.6175 - val_loss: 0.0215 - val_psnr: 16.6890 - val_ssim_metric: 0.6195
# Epoch 28/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - loss: 0.0218 - psnr: 16.6266 - ssim_metric: 0.6196
# Epoch 28: val_loss improved from 0.02149 to 0.02134, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 940ms/step - loss: 0.0218 - psnr: 16.6285 - ssim_metric: 0.6196 - val_loss: 0.0213 - val_psnr: 16.7195 - val_ssim_metric: 0.6197
# Epoch 29/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - loss: 0.0212 - psnr: 16.7374 - ssim_metric: 0.6198
# Epoch 29: val_loss improved from 0.02134 to 0.02119, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 917ms/step - loss: 0.0212 - psnr: 16.7376 - ssim_metric: 0.6200 - val_loss: 0.0212 - val_psnr: 16.7512 - val_ssim_metric: 0.6208
# Epoch 30/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 584ms/step - loss: 0.0209 - psnr: 16.8015 - ssim_metric: 0.6280
# Epoch 30: val_loss improved from 0.02119 to 0.02108, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 794ms/step - loss: 0.0209 - psnr: 16.8003 - ssim_metric: 0.6279 - val_loss: 0.0211 - val_psnr: 16.7733 - val_ssim_metric: 0.6231
# Epoch 31/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - loss: 0.0209 - psnr: 16.8214 - ssim_metric: 0.6286
# Epoch 31: val_loss improved from 0.02108 to 0.02100, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 45s 915ms/step - loss: 0.0209 - psnr: 16.8205 - ssim_metric: 0.6285 - val_loss: 0.0210 - val_psnr: 16.7903 - val_ssim_metric: 0.6227
# Epoch 32/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - loss: 0.0214 - psnr: 16.7124 - ssim_metric: 0.6254
# Epoch 32: val_loss did not improve from 0.02100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 912ms/step - loss: 0.0214 - psnr: 16.7148 - ssim_metric: 0.6254 - val_loss: 0.0210 - val_psnr: 16.7852 - val_ssim_metric: 0.6224
# Epoch 33/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - loss: 0.0209 - psnr: 16.8224 - ssim_metric: 0.6264
# Epoch 33: val_loss improved from 0.02100 to 0.02070, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 920ms/step - loss: 0.0209 - psnr: 16.8224 - ssim_metric: 0.6265 - val_loss: 0.0207 - val_psnr: 16.8529 - val_ssim_metric: 0.6248
# Epoch 34/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 573ms/step - loss: 0.0201 - psnr: 16.9721 - ssim_metric: 0.6298
# Epoch 34: val_loss improved from 0.02070 to 0.02058, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 932ms/step - loss: 0.0201 - psnr: 16.9687 - ssim_metric: 0.6298 - val_loss: 0.0206 - val_psnr: 16.8772 - val_ssim_metric: 0.6258
# Epoch 35/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - loss: 0.0207 - psnr: 16.8530 - ssim_metric: 0.6297
# Epoch 35: val_loss improved from 0.02058 to 0.02050, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 923ms/step - loss: 0.0207 - psnr: 16.8537 - ssim_metric: 0.6297 - val_loss: 0.0205 - val_psnr: 16.8948 - val_ssim_metric: 0.6263
# Epoch 36/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - loss: 0.0203 - psnr: 16.9421 - ssim_metric: 0.6256
# Epoch 36: val_loss improved from 0.02050 to 0.02037, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 783ms/step - loss: 0.0203 - psnr: 16.9412 - ssim_metric: 0.6258 - val_loss: 0.0204 - val_psnr: 16.9219 - val_ssim_metric: 0.6278
# Epoch 37/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - loss: 0.0207 - psnr: 16.8577 - ssim_metric: 0.6292
# Epoch 37: val_loss did not improve from 0.02037
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 44s 891ms/step - loss: 0.0207 - psnr: 16.8589 - ssim_metric: 0.6292 - val_loss: 0.0206 - val_psnr: 16.8732 - val_ssim_metric: 0.6295
# Epoch 38/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - loss: 0.0198 - psnr: 17.0417 - ssim_metric: 0.6335
# Epoch 38: val_loss improved from 0.02037 to 0.02033, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 939ms/step - loss: 0.0198 - psnr: 17.0388 - ssim_metric: 0.6335 - val_loss: 0.0203 - val_psnr: 16.9307 - val_ssim_metric: 0.6290
# Epoch 39/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - loss: 0.0201 - psnr: 16.9780 - ssim_metric: 0.6341
# Epoch 39: val_loss improved from 0.02033 to 0.02011, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 927ms/step - loss: 0.0201 - psnr: 16.9777 - ssim_metric: 0.6341 - val_loss: 0.0201 - val_psnr: 16.9773 - val_ssim_metric: 0.6296
# Epoch 40/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - loss: 0.0198 - psnr: 17.0374 - ssim_metric: 0.6345
# Epoch 40: val_loss did not improve from 0.02011
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 738ms/step - loss: 0.0198 - psnr: 17.0362 - ssim_metric: 0.6345 - val_loss: 0.0202 - val_psnr: 16.9665 - val_ssim_metric: 0.6288
# Epoch 41/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 562ms/step - loss: 0.0199 - psnr: 17.0168 - ssim_metric: 0.6331
# Epoch 41: val_loss improved from 0.02011 to 0.02000, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 47s 933ms/step - loss: 0.0199 - psnr: 17.0163 - ssim_metric: 0.6332 - val_loss: 0.0200 - val_psnr: 17.0028 - val_ssim_metric: 0.6315
# Epoch 42/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - loss: 0.0195 - psnr: 17.1222 - ssim_metric: 0.6331
# Epoch 42: val_loss improved from 0.02000 to 0.01990, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 930ms/step - loss: 0.0195 - psnr: 17.1196 - ssim_metric: 0.6332 - val_loss: 0.0199 - val_psnr: 17.0237 - val_ssim_metric: 0.6322
# Epoch 43/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - loss: 0.0199 - psnr: 17.0244 - ssim_metric: 0.6336
# Epoch 43: val_loss improved from 0.01990 to 0.01985, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 932ms/step - loss: 0.0199 - psnr: 17.0247 - ssim_metric: 0.6337 - val_loss: 0.0199 - val_psnr: 17.0339 - val_ssim_metric: 0.6323
# Epoch 44/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - loss: 0.0194 - psnr: 17.1373 - ssim_metric: 0.6351
# Epoch 44: val_loss improved from 0.01985 to 0.01969, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 763ms/step - loss: 0.0194 - psnr: 17.1349 - ssim_metric: 0.6351 - val_loss: 0.0197 - val_psnr: 17.0707 - val_ssim_metric: 0.6332
# Epoch 45/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - loss: 0.0195 - psnr: 17.1143 - ssim_metric: 0.6412
# Epoch 45: val_loss improved from 0.01969 to 0.01967, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 47s 944ms/step - loss: 0.0195 - psnr: 17.1136 - ssim_metric: 0.6410 - val_loss: 0.0197 - val_psnr: 17.0736 - val_ssim_metric: 0.6332
# Epoch 46/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - loss: 0.0198 - psnr: 17.0463 - ssim_metric: 0.6360
# Epoch 46: val_loss improved from 0.01967 to 0.01954, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 925ms/step - loss: 0.0198 - psnr: 17.0479 - ssim_metric: 0.6360 - val_loss: 0.0195 - val_psnr: 17.1029 - val_ssim_metric: 0.6364
# Epoch 47/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - loss: 0.0194 - psnr: 17.1349 - ssim_metric: 0.6381
# Epoch 47: val_loss improved from 0.01954 to 0.01945, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 915ms/step - loss: 0.0194 - psnr: 17.1343 - ssim_metric: 0.6382 - val_loss: 0.0194 - val_psnr: 17.1246 - val_ssim_metric: 0.6362
# Epoch 48/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - loss: 0.0193 - psnr: 17.1602 - ssim_metric: 0.6421
# Epoch 48: val_loss improved from 0.01945 to 0.01938, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 937ms/step - loss: 0.0193 - psnr: 17.1595 - ssim_metric: 0.6420 - val_loss: 0.0194 - val_psnr: 17.1396 - val_ssim_metric: 0.6362
# Epoch 49/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - loss: 0.0199 - psnr: 17.0325 - ssim_metric: 0.6395
# Epoch 49: val_loss did not improve from 0.01938
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 892ms/step - loss: 0.0199 - psnr: 17.0359 - ssim_metric: 0.6395 - val_loss: 0.0197 - val_psnr: 17.0610 - val_ssim_metric: 0.6374
# Epoch 50/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - loss: 0.0190 - psnr: 17.2284 - ssim_metric: 0.6400
# Epoch 50: val_loss improved from 0.01938 to 0.01925, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 937ms/step - loss: 0.0190 - psnr: 17.2263 - ssim_metric: 0.6400 - val_loss: 0.0192 - val_psnr: 17.1695 - val_ssim_metric: 0.6381
# Epoch 51/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - loss: 0.0187 - psnr: 17.2861 - ssim_metric: 0.6437
# Epoch 51: val_loss improved from 0.01925 to 0.01918, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 923ms/step - loss: 0.0188 - psnr: 17.2831 - ssim_metric: 0.6436 - val_loss: 0.0192 - val_psnr: 17.1856 - val_ssim_metric: 0.6384
# Epoch 52/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - loss: 0.0191 - psnr: 17.2064 - ssim_metric: 0.6408
# Epoch 52: val_loss improved from 0.01918 to 0.01914, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 922ms/step - loss: 0.0191 - psnr: 17.2059 - ssim_metric: 0.6408 - val_loss: 0.0191 - val_psnr: 17.1933 - val_ssim_metric: 0.6393
# Epoch 53/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - loss: 0.0193 - psnr: 17.1497 - ssim_metric: 0.6402
# Epoch 53: val_loss improved from 0.01914 to 0.01908, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 934ms/step - loss: 0.0193 - psnr: 17.1522 - ssim_metric: 0.6403 - val_loss: 0.0191 - val_psnr: 17.2065 - val_ssim_metric: 0.6386
# Epoch 54/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 560ms/step - loss: 0.0190 - psnr: 17.2232 - ssim_metric: 0.6434
# Epoch 54: val_loss improved from 0.01908 to 0.01902, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 778ms/step - loss: 0.0190 - psnr: 17.2236 - ssim_metric: 0.6434 - val_loss: 0.0190 - val_psnr: 17.2211 - val_ssim_metric: 0.6416
# Epoch 55/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - loss: 0.0193 - psnr: 17.1657 - ssim_metric: 0.6433
# Epoch 55: val_loss improved from 0.01902 to 0.01898, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 932ms/step - loss: 0.0193 - psnr: 17.1681 - ssim_metric: 0.6433 - val_loss: 0.0190 - val_psnr: 17.2303 - val_ssim_metric: 0.6405
# Epoch 56/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - loss: 0.0187 - psnr: 17.2908 - ssim_metric: 0.6437
# Epoch 56: val_loss improved from 0.01898 to 0.01890, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 924ms/step - loss: 0.0187 - psnr: 17.2894 - ssim_metric: 0.6437 - val_loss: 0.0189 - val_psnr: 17.2491 - val_ssim_metric: 0.6433
# Epoch 57/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - loss: 0.0187 - psnr: 17.2975 - ssim_metric: 0.6448
# Epoch 57: val_loss improved from 0.01890 to 0.01877, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 930ms/step - loss: 0.0187 - psnr: 17.2970 - ssim_metric: 0.6448 - val_loss: 0.0188 - val_psnr: 17.2793 - val_ssim_metric: 0.6428
# Epoch 58/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - loss: 0.0190 - psnr: 17.2292 - ssim_metric: 0.6423
# Epoch 58: val_loss improved from 0.01877 to 0.01874, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 928ms/step - loss: 0.0190 - psnr: 17.2313 - ssim_metric: 0.6424 - val_loss: 0.0187 - val_psnr: 17.2865 - val_ssim_metric: 0.6419
# Epoch 59/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - loss: 0.0184 - psnr: 17.3559 - ssim_metric: 0.6488
# Epoch 59: val_loss improved from 0.01874 to 0.01864, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 926ms/step - loss: 0.0184 - psnr: 17.3543 - ssim_metric: 0.6488 - val_loss: 0.0186 - val_psnr: 17.3079 - val_ssim_metric: 0.6443
# Epoch 60/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - loss: 0.0184 - psnr: 17.3652 - ssim_metric: 0.6477
# Epoch 60: val_loss did not improve from 0.01864
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 898ms/step - loss: 0.0184 - psnr: 17.3634 - ssim_metric: 0.6477 - val_loss: 0.0187 - val_psnr: 17.2838 - val_ssim_metric: 0.6421
# Epoch 61/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - loss: 0.0187 - psnr: 17.2916 - ssim_metric: 0.6462
# Epoch 61: val_loss improved from 0.01864 to 0.01856, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 939ms/step - loss: 0.0187 - psnr: 17.2930 - ssim_metric: 0.6462 - val_loss: 0.0186 - val_psnr: 17.3274 - val_ssim_metric: 0.6452
# Epoch 62/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - loss: 0.0185 - psnr: 17.3307 - ssim_metric: 0.6477
# Epoch 62: val_loss did not improve from 0.01856
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 39s 888ms/step - loss: 0.0185 - psnr: 17.3312 - ssim_metric: 0.6478 - val_loss: 0.0186 - val_psnr: 17.3258 - val_ssim_metric: 0.6440
# Epoch 63/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - loss: 0.0185 - psnr: 17.3297 - ssim_metric: 0.6485
# Epoch 63: val_loss improved from 0.01856 to 0.01847, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 38s 795ms/step - loss: 0.0185 - psnr: 17.3306 - ssim_metric: 0.6485 - val_loss: 0.0185 - val_psnr: 17.3486 - val_ssim_metric: 0.6456
# Epoch 64/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - loss: 0.0183 - psnr: 17.3928 - ssim_metric: 0.6505
# Epoch 64: val_loss improved from 0.01847 to 0.01837, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 45s 920ms/step - loss: 0.0183 - psnr: 17.3921 - ssim_metric: 0.6505 - val_loss: 0.0184 - val_psnr: 17.3729 - val_ssim_metric: 0.6462
# Epoch 65/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - loss: 0.0183 - psnr: 17.3895 - ssim_metric: 0.6534
# Epoch 65: val_loss improved from 0.01837 to 0.01836, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 933ms/step - loss: 0.0183 - psnr: 17.3901 - ssim_metric: 0.6533 - val_loss: 0.0184 - val_psnr: 17.3744 - val_ssim_metric: 0.6469
# Epoch 66/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - loss: 0.0184 - psnr: 17.3590 - ssim_metric: 0.6505
# Epoch 66: val_loss improved from 0.01836 to 0.01825, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 925ms/step - loss: 0.0184 - psnr: 17.3604 - ssim_metric: 0.6505 - val_loss: 0.0183 - val_psnr: 17.4002 - val_ssim_metric: 0.6476
# Epoch 67/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 560ms/step - loss: 0.0184 - psnr: 17.3476 - ssim_metric: 0.6479
# Epoch 67: val_loss did not improve from 0.01825
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 741ms/step - loss: 0.0184 - psnr: 17.3495 - ssim_metric: 0.6480 - val_loss: 0.0184 - val_psnr: 17.3724 - val_ssim_metric: 0.6472
# Epoch 68/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 586ms/step - loss: 0.0179 - psnr: 17.4946 - ssim_metric: 0.6540
# Epoch 68: val_loss did not improve from 0.01825
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 917ms/step - loss: 0.0179 - psnr: 17.4919 - ssim_metric: 0.6539 - val_loss: 0.0183 - val_psnr: 17.3868 - val_ssim_metric: 0.6458
# Epoch 69/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 560ms/step - loss: 0.0179 - psnr: 17.4767 - ssim_metric: 0.6493
# Epoch 69: val_loss improved from 0.01825 to 0.01815, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 765ms/step - loss: 0.0180 - psnr: 17.4754 - ssim_metric: 0.6494 - val_loss: 0.0182 - val_psnr: 17.4246 - val_ssim_metric: 0.6483
# Epoch 70/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - loss: 0.0180 - psnr: 17.4707 - ssim_metric: 0.6530
# Epoch 70: val_loss improved from 0.01815 to 0.01807, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 771ms/step - loss: 0.0180 - psnr: 17.4700 - ssim_metric: 0.6530 - val_loss: 0.0181 - val_psnr: 17.4430 - val_ssim_metric: 0.6494
# Epoch 71/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - loss: 0.0182 - psnr: 17.4060 - ssim_metric: 0.6524
# Epoch 71: val_loss improved from 0.01807 to 0.01802, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 938ms/step - loss: 0.0182 - psnr: 17.4078 - ssim_metric: 0.6525 - val_loss: 0.0180 - val_psnr: 17.4559 - val_ssim_metric: 0.6498
# Epoch 72/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - loss: 0.0174 - psnr: 17.5987 - ssim_metric: 0.6499
# Epoch 72: val_loss improved from 0.01802 to 0.01798, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 919ms/step - loss: 0.0175 - psnr: 17.5951 - ssim_metric: 0.6500 - val_loss: 0.0180 - val_psnr: 17.4662 - val_ssim_metric: 0.6508
# Epoch 73/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - loss: 0.0181 - psnr: 17.4428 - ssim_metric: 0.6515
# Epoch 73: val_loss improved from 0.01798 to 0.01793, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 929ms/step - loss: 0.0181 - psnr: 17.4441 - ssim_metric: 0.6516 - val_loss: 0.0179 - val_psnr: 17.4778 - val_ssim_metric: 0.6510
# Epoch 74/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - loss: 0.0182 - psnr: 17.4132 - ssim_metric: 0.6517
# Epoch 74: val_loss did not improve from 0.01793
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 898ms/step - loss: 0.0182 - psnr: 17.4157 - ssim_metric: 0.6518 - val_loss: 0.0180 - val_psnr: 17.4690 - val_ssim_metric: 0.6503
# Epoch 75/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 564ms/step - loss: 0.0178 - psnr: 17.4976 - ssim_metric: 0.6540
# Epoch 75: val_loss improved from 0.01793 to 0.01786, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 923ms/step - loss: 0.0178 - psnr: 17.4978 - ssim_metric: 0.6540 - val_loss: 0.0179 - val_psnr: 17.4950 - val_ssim_metric: 0.6519
# Epoch 76/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - loss: 0.0176 - psnr: 17.5609 - ssim_metric: 0.6574
# Epoch 76: val_loss improved from 0.01786 to 0.01778, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 37s 786ms/step - loss: 0.0176 - psnr: 17.5599 - ssim_metric: 0.6574 - val_loss: 0.0178 - val_psnr: 17.5136 - val_ssim_metric: 0.6532
# Epoch 77/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 582ms/step - loss: 0.0174 - psnr: 17.6189 - ssim_metric: 0.6591
# Epoch 77: val_loss improved from 0.01778 to 0.01773, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 942ms/step - loss: 0.0174 - psnr: 17.6165 - ssim_metric: 0.6590 - val_loss: 0.0177 - val_psnr: 17.5274 - val_ssim_metric: 0.6532
# Epoch 78/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 554ms/step - loss: 0.0179 - psnr: 17.4939 - ssim_metric: 0.6565
# Epoch 78: val_loss improved from 0.01773 to 0.01771, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 915ms/step - loss: 0.0179 - psnr: 17.4954 - ssim_metric: 0.6565 - val_loss: 0.0177 - val_psnr: 17.5315 - val_ssim_metric: 0.6539
# Epoch 79/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - loss: 0.0177 - psnr: 17.5409 - ssim_metric: 0.6563
# Epoch 79: val_loss did not improve from 0.01771
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 909ms/step - loss: 0.0177 - psnr: 17.5411 - ssim_metric: 0.6564 - val_loss: 0.0177 - val_psnr: 17.5257 - val_ssim_metric: 0.6547
# Epoch 80/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - loss: 0.0178 - psnr: 17.5131 - ssim_metric: 0.6568
# Epoch 80: val_loss improved from 0.01771 to 0.01764, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 778ms/step - loss: 0.0178 - psnr: 17.5146 - ssim_metric: 0.6568 - val_loss: 0.0176 - val_psnr: 17.5493 - val_ssim_metric: 0.6547
# Epoch 81/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 556ms/step - loss: 0.0175 - psnr: 17.5854 - ssim_metric: 0.6569
# Epoch 81: val_loss improved from 0.01764 to 0.01757, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 45s 915ms/step - loss: 0.0175 - psnr: 17.5851 - ssim_metric: 0.6570 - val_loss: 0.0176 - val_psnr: 17.5672 - val_ssim_metric: 0.6551
# Epoch 82/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - loss: 0.0175 - psnr: 17.5766 - ssim_metric: 0.6596
# Epoch 82: val_loss did not improve from 0.01757
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 765ms/step - loss: 0.0175 - psnr: 17.5767 - ssim_metric: 0.6596 - val_loss: 0.0176 - val_psnr: 17.5625 - val_ssim_metric: 0.6541
# Epoch 83/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - loss: 0.0170 - psnr: 17.7024 - ssim_metric: 0.6599
# Epoch 83: val_loss improved from 0.01757 to 0.01747, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 929ms/step - loss: 0.0171 - psnr: 17.6993 - ssim_metric: 0.6599 - val_loss: 0.0175 - val_psnr: 17.5904 - val_ssim_metric: 0.6560
# Epoch 84/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - loss: 0.0173 - psnr: 17.6278 - ssim_metric: 0.6599
# Epoch 84: val_loss did not improve from 0.01747
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 753ms/step - loss: 0.0173 - psnr: 17.6270 - ssim_metric: 0.6599 - val_loss: 0.0175 - val_psnr: 17.5903 - val_ssim_metric: 0.6576
# Epoch 85/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - loss: 0.0171 - psnr: 17.6810 - ssim_metric: 0.6618
# Epoch 85: val_loss improved from 0.01747 to 0.01742, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 926ms/step - loss: 0.0171 - psnr: 17.6791 - ssim_metric: 0.6617 - val_loss: 0.0174 - val_psnr: 17.6025 - val_ssim_metric: 0.6573
# Epoch 86/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - loss: 0.0171 - psnr: 17.6773 - ssim_metric: 0.6620
# Epoch 86: val_loss improved from 0.01742 to 0.01736, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 923ms/step - loss: 0.0171 - psnr: 17.6760 - ssim_metric: 0.6620 - val_loss: 0.0174 - val_psnr: 17.6187 - val_ssim_metric: 0.6583
# Epoch 87/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - loss: 0.0172 - psnr: 17.6665 - ssim_metric: 0.6599
# Epoch 87: val_loss improved from 0.01736 to 0.01733, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 935ms/step - loss: 0.0172 - psnr: 17.6655 - ssim_metric: 0.6599 - val_loss: 0.0173 - val_psnr: 17.6264 - val_ssim_metric: 0.6580
# Epoch 88/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - loss: 0.0171 - psnr: 17.6744 - ssim_metric: 0.6612
# Epoch 88: val_loss did not improve from 0.01733
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 896ms/step - loss: 0.0171 - psnr: 17.6736 - ssim_metric: 0.6613 - val_loss: 0.0173 - val_psnr: 17.6224 - val_ssim_metric: 0.6583
# Epoch 89/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - loss: 0.0170 - psnr: 17.7228 - ssim_metric: 0.6642
# Epoch 89: val_loss improved from 0.01733 to 0.01726, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 926ms/step - loss: 0.0170 - psnr: 17.7211 - ssim_metric: 0.6641 - val_loss: 0.0173 - val_psnr: 17.6434 - val_ssim_metric: 0.6588
# Epoch 90/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - loss: 0.0171 - psnr: 17.6757 - ssim_metric: 0.6609
# Epoch 90: val_loss improved from 0.01726 to 0.01719, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 925ms/step - loss: 0.0171 - psnr: 17.6755 - ssim_metric: 0.6609 - val_loss: 0.0172 - val_psnr: 17.6612 - val_ssim_metric: 0.6599
# Epoch 91/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 564ms/step - loss: 0.0168 - psnr: 17.7563 - ssim_metric: 0.6628
# Epoch 91: val_loss improved from 0.01719 to 0.01718, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 930ms/step - loss: 0.0168 - psnr: 17.7541 - ssim_metric: 0.6628 - val_loss: 0.0172 - val_psnr: 17.6646 - val_ssim_metric: 0.6591
# Epoch 92/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - loss: 0.0171 - psnr: 17.6645 - ssim_metric: 0.6641
# Epoch 92: val_loss improved from 0.01718 to 0.01714, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 930ms/step - loss: 0.0171 - psnr: 17.6651 - ssim_metric: 0.6641 - val_loss: 0.0171 - val_psnr: 17.6746 - val_ssim_metric: 0.6607
# Epoch 93/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - loss: 0.0167 - psnr: 17.7984 - ssim_metric: 0.6650
# Epoch 93: val_loss improved from 0.01714 to 0.01713, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 784ms/step - loss: 0.0167 - psnr: 17.7953 - ssim_metric: 0.6650 - val_loss: 0.0171 - val_psnr: 17.6765 - val_ssim_metric: 0.6613
# Epoch 94/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - loss: 0.0172 - psnr: 17.6698 - ssim_metric: 0.6619
# Epoch 94: val_loss did not improve from 0.01713
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 748ms/step - loss: 0.0172 - psnr: 17.6704 - ssim_metric: 0.6619 - val_loss: 0.0174 - val_psnr: 17.6168 - val_ssim_metric: 0.6607
# Epoch 95/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - loss: 0.0172 - psnr: 17.6689 - ssim_metric: 0.6656
# Epoch 95: val_loss improved from 0.01713 to 0.01702, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 49s 999ms/step - loss: 0.0171 - psnr: 17.6702 - ssim_metric: 0.6656 - val_loss: 0.0170 - val_psnr: 17.7051 - val_ssim_metric: 0.6622
# Epoch 96/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - loss: 0.0171 - psnr: 17.6841 - ssim_metric: 0.6621
# Epoch 96: val_loss improved from 0.01702 to 0.01698, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 784ms/step - loss: 0.0171 - psnr: 17.6852 - ssim_metric: 0.6622 - val_loss: 0.0170 - val_psnr: 17.7162 - val_ssim_metric: 0.6622
# Epoch 97/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - loss: 0.0169 - psnr: 17.7401 - ssim_metric: 0.6624
# Epoch 97: val_loss improved from 0.01698 to 0.01697, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 45s 918ms/step - loss: 0.0169 - psnr: 17.7399 - ssim_metric: 0.6625 - val_loss: 0.0170 - val_psnr: 17.7183 - val_ssim_metric: 0.6626
# Epoch 98/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - loss: 0.0170 - psnr: 17.7009 - ssim_metric: 0.6606
# Epoch 98: val_loss did not improve from 0.01697
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 912ms/step - loss: 0.0170 - psnr: 17.7023 - ssim_metric: 0.6608 - val_loss: 0.0170 - val_psnr: 17.7154 - val_ssim_metric: 0.6637
# Epoch 99/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - loss: 0.0170 - psnr: 17.6962 - ssim_metric: 0.6657
# Epoch 99: val_loss improved from 0.01697 to 0.01690, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 925ms/step - loss: 0.0170 - psnr: 17.6977 - ssim_metric: 0.6657 - val_loss: 0.0169 - val_psnr: 17.7350 - val_ssim_metric: 0.6635
# Epoch 100/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 572ms/step - loss: 0.0164 - psnr: 17.8628 - ssim_metric: 0.6688
# Epoch 100: val_loss improved from 0.01690 to 0.01690, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 37s 793ms/step - loss: 0.0164 - psnr: 17.8598 - ssim_metric: 0.6688 - val_loss: 0.0169 - val_psnr: 17.7351 - val_ssim_metric: 0.6635
# Epoch 101/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - loss: 0.0165 - psnr: 17.8573 - ssim_metric: 0.6682
# Epoch 101: val_loss improved from 0.01690 to 0.01683, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 45s 926ms/step - loss: 0.0165 - psnr: 17.8545 - ssim_metric: 0.6681 - val_loss: 0.0168 - val_psnr: 17.7541 - val_ssim_metric: 0.6636
# Epoch 102/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 574ms/step - loss: 0.0166 - psnr: 17.8155 - ssim_metric: 0.6687
# Epoch 102: val_loss improved from 0.01683 to 0.01681, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 936ms/step - loss: 0.0166 - psnr: 17.8141 - ssim_metric: 0.6687 - val_loss: 0.0168 - val_psnr: 17.7594 - val_ssim_metric: 0.6641
# Epoch 103/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - loss: 0.0167 - psnr: 17.7927 - ssim_metric: 0.6668
# Epoch 103: val_loss improved from 0.01681 to 0.01677, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 922ms/step - loss: 0.0167 - psnr: 17.7925 - ssim_metric: 0.6669 - val_loss: 0.0168 - val_psnr: 17.7703 - val_ssim_metric: 0.6653
# Epoch 104/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 565ms/step - loss: 0.0167 - psnr: 17.7865 - ssim_metric: 0.6690
# Epoch 104: val_loss improved from 0.01677 to 0.01676, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 920ms/step - loss: 0.0167 - psnr: 17.7867 - ssim_metric: 0.6690 - val_loss: 0.0168 - val_psnr: 17.7728 - val_ssim_metric: 0.6644
# Epoch 105/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 560ms/step - loss: 0.0170 - psnr: 17.6935 - ssim_metric: 0.6675
# Epoch 105: val_loss improved from 0.01676 to 0.01672, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - loss: 0.0170 - psnr: 17.6966 - ssim_metric: 0.6675 - val_loss: 0.0167 - val_psnr: 17.7827 - val_ssim_metric: 0.6650
# Epoch 106/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - loss: 0.0168 - psnr: 17.7553 - ssim_metric: 0.6668
# Epoch 106: val_loss improved from 0.01672 to 0.01670, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - loss: 0.0168 - psnr: 17.7569 - ssim_metric: 0.6669 - val_loss: 0.0167 - val_psnr: 17.7883 - val_ssim_metric: 0.6657
# Epoch 107/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - loss: 0.0168 - psnr: 17.7530 - ssim_metric: 0.6687
# Epoch 107: val_loss improved from 0.01670 to 0.01663, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 0.0168 - psnr: 17.7548 - ssim_metric: 0.6687 - val_loss: 0.0166 - val_psnr: 17.8058 - val_ssim_metric: 0.6663
# Epoch 108/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - loss: 0.0163 - psnr: 17.8852 - ssim_metric: 0.6715
# Epoch 108: val_loss improved from 0.01663 to 0.01660, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 0.0163 - psnr: 17.8834 - ssim_metric: 0.6715 - val_loss: 0.0166 - val_psnr: 17.8137 - val_ssim_metric: 0.6662
# Epoch 109/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 560ms/step - loss: 0.0167 - psnr: 17.7977 - ssim_metric: 0.6711
# Epoch 109: val_loss improved from 0.01660 to 0.01659, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - loss: 0.0167 - psnr: 17.7985 - ssim_metric: 0.6710 - val_loss: 0.0166 - val_psnr: 17.8165 - val_ssim_metric: 0.6679
# Epoch 110/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - loss: 0.0162 - psnr: 17.9208 - ssim_metric: 0.6705
# Epoch 110: val_loss improved from 0.01659 to 0.01658, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 945ms/step - loss: 0.0162 - psnr: 17.9180 - ssim_metric: 0.6705 - val_loss: 0.0166 - val_psnr: 17.8184 - val_ssim_metric: 0.6671
# Epoch 111/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - loss: 0.0165 - psnr: 17.8440 - ssim_metric: 0.6712
# Epoch 111: val_loss improved from 0.01658 to 0.01651, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - loss: 0.0165 - psnr: 17.8443 - ssim_metric: 0.6712 - val_loss: 0.0165 - val_psnr: 17.8372 - val_ssim_metric: 0.6680
# Epoch 112/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - loss: 0.0165 - psnr: 17.8245 - ssim_metric: 0.6705
# Epoch 112: val_loss improved from 0.01651 to 0.01648, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 964ms/step - loss: 0.0165 - psnr: 17.8256 - ssim_metric: 0.6705 - val_loss: 0.0165 - val_psnr: 17.8449 - val_ssim_metric: 0.6684
# Epoch 113/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - loss: 0.0165 - psnr: 17.8363 - ssim_metric: 0.6714
# Epoch 113: val_loss improved from 0.01648 to 0.01646, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 930ms/step - loss: 0.0165 - psnr: 17.8372 - ssim_metric: 0.6715 - val_loss: 0.0165 - val_psnr: 17.8501 - val_ssim_metric: 0.6690
# Epoch 114/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - loss: 0.0163 - psnr: 17.8874 - ssim_metric: 0.6728
# Epoch 114: val_loss improved from 0.01646 to 0.01644, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - loss: 0.0163 - psnr: 17.8868 - ssim_metric: 0.6728 - val_loss: 0.0164 - val_psnr: 17.8547 - val_ssim_metric: 0.6698
# Epoch 115/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 561ms/step - loss: 0.0162 - psnr: 17.9381 - ssim_metric: 0.6738
# Epoch 115: val_loss improved from 0.01644 to 0.01640, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 0.0162 - psnr: 17.9364 - ssim_metric: 0.6737 - val_loss: 0.0164 - val_psnr: 17.8665 - val_ssim_metric: 0.6691
# Epoch 116/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - loss: 0.0163 - psnr: 17.9002 - ssim_metric: 0.6741
# Epoch 116: val_loss did not improve from 0.01640
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 755ms/step - loss: 0.0163 - psnr: 17.9000 - ssim_metric: 0.6741 - val_loss: 0.0166 - val_psnr: 17.8205 - val_ssim_metric: 0.6698
# Epoch 117/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 584ms/step - loss: 0.0163 - psnr: 17.8786 - ssim_metric: 0.6754
# Epoch 117: val_loss did not improve from 0.01640
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 915ms/step - loss: 0.0163 - psnr: 17.8787 - ssim_metric: 0.6753 - val_loss: 0.0165 - val_psnr: 17.8515 - val_ssim_metric: 0.6693
# Epoch 118/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - loss: 0.0163 - psnr: 17.8938 - ssim_metric: 0.6733
# Epoch 118: val_loss improved from 0.01640 to 0.01631, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - loss: 0.0163 - psnr: 17.8942 - ssim_metric: 0.6733 - val_loss: 0.0163 - val_psnr: 17.8905 - val_ssim_metric: 0.6708
# Epoch 119/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - loss: 0.0163 - psnr: 17.9178 - ssim_metric: 0.6748
# Epoch 119: val_loss did not improve from 0.01631
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 908ms/step - loss: 0.0163 - psnr: 17.9180 - ssim_metric: 0.6748 - val_loss: 0.0163 - val_psnr: 17.8895 - val_ssim_metric: 0.6702
# Epoch 120/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 562ms/step - loss: 0.0159 - psnr: 18.0098 - ssim_metric: 0.6749
# Epoch 120: val_loss improved from 0.01631 to 0.01629, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - loss: 0.0159 - psnr: 18.0071 - ssim_metric: 0.6749 - val_loss: 0.0163 - val_psnr: 17.8951 - val_ssim_metric: 0.6704
# Epoch 121/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 573ms/step - loss: 0.0159 - psnr: 18.0114 - ssim_metric: 0.6765
# Epoch 121: val_loss did not improve from 0.01629
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 755ms/step - loss: 0.0159 - psnr: 18.0089 - ssim_metric: 0.6764 - val_loss: 0.0163 - val_psnr: 17.8935 - val_ssim_metric: 0.6713
# Epoch 122/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - loss: 0.0163 - psnr: 17.8934 - ssim_metric: 0.6732
# Epoch 122: val_loss improved from 0.01629 to 0.01622, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - loss: 0.0163 - psnr: 17.8946 - ssim_metric: 0.6732 - val_loss: 0.0162 - val_psnr: 17.9152 - val_ssim_metric: 0.6711
# Epoch 123/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - loss: 0.0159 - psnr: 17.9913 - ssim_metric: 0.6738
# Epoch 123: val_loss improved from 0.01622 to 0.01619, saving model to checkpoint_oxford_flowers/best_weights.keras
# ...
# Epoch 720: val_loss improved from 0.00997 to 0.00997, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 48s 975ms/step - loss: 0.0099 - psnr: 20.0783 - ssim_metric: 0.7763 - val_loss: 0.0100 - val_psnr: 20.0295 - val_ssim_metric: 0.7745
# Epoch 721/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - loss: 0.0100 - psnr: 20.0190 - ssim_metric: 0.7775
# Epoch 721: val_loss did not improve from 0.00997
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 39s 898ms/step - loss: 0.0100 - psnr: 20.0206 - ssim_metric: 0.7775 - val_loss: 0.0101 - val_psnr: 19.9833 - val_ssim_metric: 0.7737
# Epoch 722/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - loss: 0.0098 - psnr: 20.0799 - ssim_metric: 0.7765
# Epoch 722: val_loss improved from 0.00997 to 0.00996, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 977ms/step - loss: 0.0098 - psnr: 20.0796 - ssim_metric: 0.7765 - val_loss: 0.0100 - val_psnr: 20.0313 - val_ssim_metric: 0.7744
# Epoch 723/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - loss: 0.0098 - psnr: 20.0794 - ssim_metric: 0.7770
# Epoch 723: val_loss did not improve from 0.00996
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 34s 740ms/step - loss: 0.0098 - psnr: 20.0796 - ssim_metric: 0.7770 - val_loss: 0.0100 - val_psnr: 20.0299 - val_ssim_metric: 0.7741
# Epoch 724/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - loss: 0.0098 - psnr: 20.0937 - ssim_metric: 0.7754
# Epoch 724: val_loss improved from 0.00996 to 0.00996, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 48s 955ms/step - loss: 0.0098 - psnr: 20.0933 - ssim_metric: 0.7754 - val_loss: 0.0100 - val_psnr: 20.0326 - val_ssim_metric: 0.7743
# Epoch 725/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - loss: 0.0097 - psnr: 20.1448 - ssim_metric: 0.7798
# Epoch 725: val_loss did not improve from 0.00996
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 901ms/step - loss: 0.0097 - psnr: 20.1425 - ssim_metric: 0.7797 - val_loss: 0.0101 - val_psnr: 19.9890 - val_ssim_metric: 0.7736
# Epoch 726/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - loss: 0.0098 - psnr: 20.1029 - ssim_metric: 0.7749
# Epoch 726: val_loss did not improve from 0.00996
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 739ms/step - loss: 0.0098 - psnr: 20.1022 - ssim_metric: 0.7750 - val_loss: 0.0100 - val_psnr: 20.0265 - val_ssim_metric: 0.7737
# Epoch 727/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 582ms/step - loss: 0.0098 - psnr: 20.1192 - ssim_metric: 0.7781
# Epoch 727: val_loss did not improve from 0.00996
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 769ms/step - loss: 0.0098 - psnr: 20.1184 - ssim_metric: 0.7781 - val_loss: 0.0100 - val_psnr: 20.0325 - val_ssim_metric: 0.7742
# Epoch 728/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 562ms/step - loss: 0.0096 - psnr: 20.1721 - ssim_metric: 0.7792
# Epoch 728: val_loss did not improve from 0.00996
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 45s 894ms/step - loss: 0.0096 - psnr: 20.1696 - ssim_metric: 0.7792 - val_loss: 0.0100 - val_psnr: 20.0270 - val_ssim_metric: 0.7731
# Epoch 729/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - loss: 0.0095 - psnr: 20.2240 - ssim_metric: 0.7784
# Epoch 729: val_loss improved from 0.00996 to 0.00993, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 941ms/step - loss: 0.0096 - psnr: 20.2204 - ssim_metric: 0.7784 - val_loss: 0.0099 - val_psnr: 20.0455 - val_ssim_metric: 0.7740
# Epoch 730/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 570ms/step - loss: 0.0098 - psnr: 20.0880 - ssim_metric: 0.7793
# Epoch 730: val_loss improved from 0.00993 to 0.00993, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - loss: 0.0098 - psnr: 20.0884 - ssim_metric: 0.7792 - val_loss: 0.0099 - val_psnr: 20.0465 - val_ssim_metric: 0.7746
# Epoch 731/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - loss: 0.0099 - psnr: 20.0535 - ssim_metric: 0.7775
# Epoch 731: val_loss did not improve from 0.00993
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 37s 899ms/step - loss: 0.0099 - psnr: 20.0551 - ssim_metric: 0.7775 - val_loss: 0.0100 - val_psnr: 20.0335 - val_ssim_metric: 0.7741
# Epoch 732/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - loss: 0.0099 - psnr: 20.0582 - ssim_metric: 0.7758
# Epoch 732: val_loss improved from 0.00993 to 0.00992, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 963ms/step - loss: 0.0099 - psnr: 20.0595 - ssim_metric: 0.7759 - val_loss: 0.0099 - val_psnr: 20.0495 - val_ssim_metric: 0.7746
# Epoch 733/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - loss: 0.0096 - psnr: 20.1863 - ssim_metric: 0.7798
# Epoch 733: val_loss did not improve from 0.00992
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 742ms/step - loss: 0.0096 - psnr: 20.1835 - ssim_metric: 0.7798 - val_loss: 0.0099 - val_psnr: 20.0456 - val_ssim_metric: 0.7747
# Epoch 734/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - loss: 0.0101 - psnr: 19.9939 - ssim_metric: 0.7730
# Epoch 734: val_loss did not improve from 0.00992
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 745ms/step - loss: 0.0101 - psnr: 19.9973 - ssim_metric: 0.7732 - val_loss: 0.0099 - val_psnr: 20.0482 - val_ssim_metric: 0.7746
# Epoch 735/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 588ms/step - loss: 0.0098 - psnr: 20.0976 - ssim_metric: 0.7747
# Epoch 735: val_loss did not improve from 0.00992
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 919ms/step - loss: 0.0098 - psnr: 20.0977 - ssim_metric: 0.7748 - val_loss: 0.0099 - val_psnr: 20.0376 - val_ssim_metric: 0.7751
# Epoch 736/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 555ms/step - loss: 0.0099 - psnr: 20.0729 - ssim_metric: 0.7789
# Epoch 736: val_loss improved from 0.00992 to 0.00991, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - loss: 0.0099 - psnr: 20.0737 - ssim_metric: 0.7789 - val_loss: 0.0099 - val_psnr: 20.0557 - val_ssim_metric: 0.7754
# Epoch 737/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 581ms/step - loss: 0.0098 - psnr: 20.1000 - ssim_metric: 0.7762
# Epoch 737: val_loss did not improve from 0.00991
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 913ms/step - loss: 0.0098 - psnr: 20.0997 - ssim_metric: 0.7762 - val_loss: 0.0100 - val_psnr: 20.0247 - val_ssim_metric: 0.7742
# Epoch 738/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - loss: 0.0096 - psnr: 20.1915 - ssim_metric: 0.7788
# Epoch 738: val_loss did not improve from 0.00991
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 899ms/step - loss: 0.0096 - psnr: 20.1885 - ssim_metric: 0.7788 - val_loss: 0.0099 - val_psnr: 20.0426 - val_ssim_metric: 0.7743
# Epoch 739/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - loss: 0.0097 - psnr: 20.1527 - ssim_metric: 0.7780
# Epoch 739: val_loss improved from 0.00991 to 0.00990, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - loss: 0.0097 - psnr: 20.1513 - ssim_metric: 0.7780 - val_loss: 0.0099 - val_psnr: 20.0586 - val_ssim_metric: 0.7757
# Epoch 740/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 582ms/step - loss: 0.0098 - psnr: 20.0927 - ssim_metric: 0.7786
# Epoch 740: val_loss did not improve from 0.00990
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 25s 770ms/step - loss: 0.0098 - psnr: 20.0935 - ssim_metric: 0.7786 - val_loss: 0.0099 - val_psnr: 20.0550 - val_ssim_metric: 0.7759
# Epoch 741/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - loss: 0.0097 - psnr: 20.1324 - ssim_metric: 0.7760
# Epoch 741: val_loss improved from 0.00990 to 0.00990, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 975ms/step - loss: 0.0097 - psnr: 20.1321 - ssim_metric: 0.7761 - val_loss: 0.0099 - val_psnr: 20.0589 - val_ssim_metric: 0.7759
# Epoch 742/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - loss: 0.0097 - psnr: 20.1224 - ssim_metric: 0.7775
# Epoch 742: val_loss did not improve from 0.00990
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 38s 884ms/step - loss: 0.0097 - psnr: 20.1219 - ssim_metric: 0.7775 - val_loss: 0.0099 - val_psnr: 20.0508 - val_ssim_metric: 0.7740
# Epoch 743/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 578ms/step - loss: 0.0100 - psnr: 20.0277 - ssim_metric: 0.7798
# Epoch 743: val_loss did not improve from 0.00990
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 909ms/step - loss: 0.0100 - psnr: 20.0303 - ssim_metric: 0.7797 - val_loss: 0.0099 - val_psnr: 20.0571 - val_ssim_metric: 0.7747
# Epoch 744/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 564ms/step - loss: 0.0099 - psnr: 20.0459 - ssim_metric: 0.7780
# Epoch 744: val_loss did not improve from 0.00990
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 896ms/step - loss: 0.0099 - psnr: 20.0479 - ssim_metric: 0.7780 - val_loss: 0.0099 - val_psnr: 20.0511 - val_ssim_metric: 0.7748
# Epoch 745/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - loss: 0.0098 - psnr: 20.0854 - ssim_metric: 0.7754
# Epoch 745: val_loss did not improve from 0.00990
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 899ms/step - loss: 0.0098 - psnr: 20.0861 - ssim_metric: 0.7755 - val_loss: 0.0099 - val_psnr: 20.0494 - val_ssim_metric: 0.7745
# Epoch 746/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - loss: 0.0098 - psnr: 20.1095 - ssim_metric: 0.7773
# Epoch 746: val_loss did not improve from 0.00990
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 902ms/step - loss: 0.0098 - psnr: 20.1091 - ssim_metric: 0.7773 - val_loss: 0.0099 - val_psnr: 20.0561 - val_ssim_metric: 0.7746
# Epoch 747/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 567ms/step - loss: 0.0098 - psnr: 20.1119 - ssim_metric: 0.7791
# Epoch 747: val_loss improved from 0.00990 to 0.00990, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - loss: 0.0098 - psnr: 20.1121 - ssim_metric: 0.7791 - val_loss: 0.0099 - val_psnr: 20.0594 - val_ssim_metric: 0.7758
# Epoch 748/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - loss: 0.0096 - psnr: 20.1763 - ssim_metric: 0.7797
# Epoch 748: val_loss improved from 0.00990 to 0.00988, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 37s 940ms/step - loss: 0.0096 - psnr: 20.1742 - ssim_metric: 0.7797 - val_loss: 0.0099 - val_psnr: 20.0675 - val_ssim_metric: 0.7757
# Epoch 749/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - loss: 0.0101 - psnr: 20.0007 - ssim_metric: 0.7766
# Epoch 749: val_loss did not improve from 0.00988
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 751ms/step - loss: 0.0100 - psnr: 20.0042 - ssim_metric: 0.7766 - val_loss: 0.0099 - val_psnr: 20.0541 - val_ssim_metric: 0.7762
# Epoch 750/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - loss: 0.0098 - psnr: 20.0853 - ssim_metric: 0.7789
# Epoch 750: val_loss did not improve from 0.00988
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 901ms/step - loss: 0.0098 - psnr: 20.0862 - ssim_metric: 0.7789 - val_loss: 0.0099 - val_psnr: 20.0559 - val_ssim_metric: 0.7750
# Epoch 751/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 576ms/step - loss: 0.0098 - psnr: 20.0982 - ssim_metric: 0.7781
# Epoch 751: val_loss did not improve from 0.00988
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 908ms/step - loss: 0.0098 - psnr: 20.0988 - ssim_metric: 0.7781 - val_loss: 0.0099 - val_psnr: 20.0663 - val_ssim_metric: 0.7755
# Epoch 752/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - loss: 0.0098 - psnr: 20.0928 - ssim_metric: 0.7787
# Epoch 752: val_loss did not improve from 0.00988
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 892ms/step - loss: 0.0098 - psnr: 20.0936 - ssim_metric: 0.7786 - val_loss: 0.0099 - val_psnr: 20.0546 - val_ssim_metric: 0.7760
# Epoch 753/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - loss: 0.0097 - psnr: 20.1235 - ssim_metric: 0.7790
# Epoch 753: val_loss did not improve from 0.00988
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 911ms/step - loss: 0.0097 - psnr: 20.1236 - ssim_metric: 0.7790 - val_loss: 0.0099 - val_psnr: 20.0595 - val_ssim_metric: 0.7752
# Epoch 754/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 562ms/step - loss: 0.0100 - psnr: 20.0318 - ssim_metric: 0.7783
# Epoch 754: val_loss did not improve from 0.00988
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 894ms/step - loss: 0.0100 - psnr: 20.0348 - ssim_metric: 0.7784 - val_loss: 0.0099 - val_psnr: 20.0561 - val_ssim_metric: 0.7743
# Epoch 755/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 581ms/step - loss: 0.0095 - psnr: 20.2501 - ssim_metric: 0.7788
# Epoch 755: val_loss improved from 0.00988 to 0.00988, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 26s 801ms/step - loss: 0.0095 - psnr: 20.2465 - ssim_metric: 0.7788 - val_loss: 0.0099 - val_psnr: 20.0685 - val_ssim_metric: 0.7763
# Epoch 756/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - loss: 0.0100 - psnr: 20.0286 - ssim_metric: 0.7782
# Epoch 756: val_loss improved from 0.00988 to 0.00987, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 44s 915ms/step - loss: 0.0100 - psnr: 20.0318 - ssim_metric: 0.7782 - val_loss: 0.0099 - val_psnr: 20.0744 - val_ssim_metric: 0.7763
# Epoch 757/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - loss: 0.0096 - psnr: 20.1853 - ssim_metric: 0.7790
# Epoch 757: val_loss did not improve from 0.00987
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 768ms/step - loss: 0.0096 - psnr: 20.1839 - ssim_metric: 0.7790 - val_loss: 0.0099 - val_psnr: 20.0472 - val_ssim_metric: 0.7739
# Epoch 758/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 563ms/step - loss: 0.0095 - psnr: 20.2439 - ssim_metric: 0.7811
# Epoch 758: val_loss did not improve from 0.00987
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 45s 895ms/step - loss: 0.0095 - psnr: 20.2403 - ssim_metric: 0.7810 - val_loss: 0.0099 - val_psnr: 20.0685 - val_ssim_metric: 0.7745
# Epoch 759/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - loss: 0.0096 - psnr: 20.1722 - ssim_metric: 0.7772
# Epoch 759: val_loss did not improve from 0.00987
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 37s 757ms/step - loss: 0.0096 - psnr: 20.1708 - ssim_metric: 0.7772 - val_loss: 0.0099 - val_psnr: 20.0736 - val_ssim_metric: 0.7753
# Epoch 760/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 569ms/step - loss: 0.0101 - psnr: 19.9565 - ssim_metric: 0.7777
# Epoch 760: val_loss did not improve from 0.00987
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 45s 901ms/step - loss: 0.0101 - psnr: 19.9622 - ssim_metric: 0.7777 - val_loss: 0.0099 - val_psnr: 20.0667 - val_ssim_metric: 0.7746
# Epoch 761/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - loss: 0.0099 - psnr: 20.0814 - ssim_metric: 0.7771
# Epoch 761: val_loss improved from 0.00987 to 0.00986, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 38s 790ms/step - loss: 0.0099 - psnr: 20.0831 - ssim_metric: 0.7772 - val_loss: 0.0099 - val_psnr: 20.0780 - val_ssim_metric: 0.7763
# Epoch 762/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - loss: 0.0095 - psnr: 20.2198 - ssim_metric: 0.7812
# Epoch 762: val_loss did not improve from 0.00986
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 44s 903ms/step - loss: 0.0095 - psnr: 20.2170 - ssim_metric: 0.7811 - val_loss: 0.0099 - val_psnr: 20.0624 - val_ssim_metric: 0.7756
# Epoch 763/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - loss: 0.0098 - psnr: 20.1014 - ssim_metric: 0.7773
# Epoch 763: val_loss improved from 0.00986 to 0.00986, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - loss: 0.0098 - psnr: 20.1019 - ssim_metric: 0.7773 - val_loss: 0.0099 - val_psnr: 20.0792 - val_ssim_metric: 0.7758
# Epoch 764/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 557ms/step - loss: 0.0097 - psnr: 20.1289 - ssim_metric: 0.7795
# Epoch 764: val_loss did not improve from 0.00986
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 30s 737ms/step - loss: 0.0097 - psnr: 20.1290 - ssim_metric: 0.7795 - val_loss: 0.0099 - val_psnr: 20.0758 - val_ssim_metric: 0.7768
# Epoch 765/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 587ms/step - loss: 0.0099 - psnr: 20.0685 - ssim_metric: 0.7785
# Epoch 765: val_loss did not improve from 0.00986
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 918ms/step - loss: 0.0099 - psnr: 20.0704 - ssim_metric: 0.7785 - val_loss: 0.0099 - val_psnr: 20.0682 - val_ssim_metric: 0.7757
# Epoch 766/1000
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 558ms/step - loss: 0.0098 - psnr: 20.1167 - ssim_metric: 0.7804
# Epoch 766: val_loss did not improve from 0.00986
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 890ms/step - loss: 0.0098 - psnr: 20.1164 - ssim_metric: 0.7803 - val_loss: 0.0102 - val_psnr: 19.9260 - val_ssim_metric: 0.7688
# Epoch 767/1000
#  4/32 ━━━━━━━━━━━━━━━━━━━━ 16s 573ms/step - loss: 0.0101 - psnr: 19.9636 - ssim_metric: 0.7703
