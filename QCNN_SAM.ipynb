# %%
# !pip install scikit-image
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# !find /content/drive/MyDrive -type d -name "quaternion_layers"
import sys
sys.path.append('/content/drive/MyDrive')
# !pip install kaggle
# !pip install tensorflow-datasets

import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import numpy as np
import PIL, os, random, skimage.util, csv
import tensorflow.keras.backend as K
from google.colab import files
from quaternion_layers import QConv2D, QDense
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, AveragePooling2D, UpSampling2D, Reshape, Flatten, Input, Add, Multiply, GlobalAveragePooling2D, GlobalMaxPooling2D, Concatenate, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import time

#Load Oxford Flowers dataset
dataset, info = tfds.load(
    "oxford_flowers102",
    with_info=True,
    as_supervised=True
)
print(info.splits)

#Function to covert TF Dataset to NumPy arrays
def ds_to_numpy(dataset):
    images, labels = [], []
    for img, lbl in dataset:
        images.append(img.numpy())
        labels.append(lbl.numpy())
    return np.array(images), np.array(labels)

#Preprocessing function: Resize & Normalize images
def preprocess_augmented(image, label):
    image = tf.image.resize(image, [128, 128])
    image = tf.image.random_flip_left_right(image)
    image = tf.image.random_flip_up_down(image)
    image = tf.image.rot90(image, k=np.random.randint(4))
    image = tf.cast(image, tf.float32) / 255.0
    image = (image * 2.0) - 1.0
    return image, label
def preprocess_clean(image, label):
    image = tf.image.resize(image, [128, 128])
    image = tf.cast(image, tf.float32) / 255.0
    image = (image * 2.0) - 1.0
    return image, label

# Function to add noise to images (Salt & Pepper, Gaussian)
def add_noise(images, noise_factor=0.2, salt_pepper_amount=0.1):
    noisy_images = []
    for img in images:
        # Add salt & pepper noise
        img_sp = skimage.util.random_noise(img, mode='s&p', amount=salt_pepper_amount)

        # Add Gaussian noise
        img_noisy = img_sp + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=img.shape)
        img_noisy = np.clip(img_noisy, -1.0, 1.0)  # Ensure values are in the valid range [-1, 1]

        noisy_images.append(img_noisy)

    return np.array(noisy_images)

def PSNR(y_true, y_pred):
    max_pixel = 1.0  # Since images are normalized to [-1,1]
    return 10.0 * K.log((max_pixel ** 2) / (K.mean(K.square(y_pred - y_true)))) / K.log(10.0)

def ssim_metric(y_true, y_pred):
    return tf.reduce_mean(tf.image.ssim(y_true, y_pred, max_val=2.0))

# Define the Spatial Attention Module (SAM)
def spatial_attention(input_feature):
    avg_pool = Lambda(lambda x: tf.reduce_mean(x, axis=-1, keepdims=True))(input_feature)
    max_pool = Lambda(lambda x: tf.reduce_max(x, axis=-1, keepdims=True))(input_feature)
    concat = Concatenate(axis=-1)([avg_pool, max_pool])
    attention = Conv2D(1, kernel_size=7, padding='same', activation='sigmoid')(concat)
    return Multiply()([input_feature, attention])

# Load dataset splits
splits, info = tfds.load(
    'oxford_flowers102',
    split=['train','test','validation'],
    as_supervised=True,
    with_info=True
)
train_ds, test_ds, val_ds = splits

# Apply preprocessing to dataset
train_ds = train_ds.map(preprocess_augmented, num_parallel_calls=tf.data.AUTOTUNE)
test_ds  = test_ds.map(preprocess_clean, num_parallel_calls=tf.data.AUTOTUNE)
val_ds   = val_ds.map(preprocess_clean, num_parallel_calls=tf.data.AUTOTUNE)

# Convert dataset to NumPy arrays
(x_train, _), (x_valid, _), (x_test, _) = (
    ds_to_numpy(train_ds),
    ds_to_numpy(val_ds),
    ds_to_numpy(test_ds)
)

# Convert each split to NumPy
(x_train, y_train) = ds_to_numpy(train_ds)
(x_test, y_test)   = ds_to_numpy(test_ds)
(x_valid, y_valid) = ds_to_numpy(val_ds)

print("Train shape:", x_train.shape)
print("Valid shape:", x_valid.shape)
print("Test shape: ", x_test.shape)

# Model Configuration
encoding_size = 90
perturbation_max = 40
image_shape = (128,128,3)

# Define Model Architecture
model_input = Input(shape=image_shape)

# Encoder
conv1 = QConv2D(23, 3, padding='same', activation='relu')(model_input)
print("conv1 shape:", conv1.shape)
conv1 = spatial_attention(conv1)  # Apply SAM here
print("after SAM conv1 shape:", conv1.shape)
conv2 = QConv2D(23, 3, padding='same', activation='relu')(conv1)
print("conv2 shape:", conv2.shape)
pool1 = AveragePooling2D(2, 2)(conv2)
print("pool1 shape:", pool1.shape)
conv3 = QConv2D(45, 3, padding='same', activation='relu')(pool1)
print("conv3 shape:", conv3.shape)
conv3 = spatial_attention(conv3)  # Apply SAM here
print("SAM conv3 shape:", conv3.shape)
conv4 = QConv2D(45, 3, padding='same', activation='relu')(conv3)
print("conv4 shape:", conv4.shape)
pool2 = AveragePooling2D(2, 2)(conv4)
print("pool2 shape:", pool2.shape)
conv5 = QConv2D(90, 3, padding='same', activation='relu')(pool2)
print("conv5 shape:", conv5.shape)
conv5 = spatial_attention(conv5)  # Apply SAM here
print("SAM conv5 shape:", conv5.shape)
conv6 = QConv2D(90, 3, padding='same', activation='relu')(conv5)
print("conv6 shape:", conv6.shape)

# Decoder
flatten = Flatten()(conv6)
print("flatten shape:", flatten.shape)
encoding = QDense(encoding_size, activation='relu')(flatten)
print("encoding shape:", encoding.shape)
dense2 = QDense(192, activation='relu')(encoding)
print("dense2 shape:", dense2.shape)
reshape = Reshape((8, 8, 9))(dense2)
print("reshape shape:", reshape.shape)
upsample2 = UpSampling2D(size=(4, 4))(reshape)
print("upsample2 shape:", upsample2.shape)
conv11 = QConv2D(90, 3, padding='same', activation='relu')(upsample2)
print("conv11 shape:", conv11.shape)
conv12 = QConv2D(90, 3, padding='same', activation='relu')(conv11)
print("conv12 shape:", conv12.shape)
add1 = Add()([conv12, conv6])
print("add1 shape:", add1.shape)
upsample3 = UpSampling2D(size=(4, 4))(add1)
print("upsample3 shape:", upsample3.shape)
conv13 = QConv2D(45, 3, padding='same', activation='relu')(upsample3)
print("conv13 shape:", conv13.shape)
conv13 = spatial_attention(conv13)  # Apply SAM here
print("conv13 shape:", conv13.shape)
conv14 = QConv2D(45, 3, padding='same', activation='relu')(conv13)
print("conv14 shape:", conv14.shape)
upsample_conv4 = UpSampling2D(size=(2, 2))(conv4)
print("upsample_conv4 shape:", upsample_conv4.shape)
add2 = Add()([conv14, upsample_conv4])
print("add2 shape:", add2.shape)
upsample3 = UpSampling2D(size=(4, 4))(add2)
conv15 = QConv2D(8, 3, padding='same', activation='relu')(add2)
print("conv15 shape:", conv15.shape)
conv16 = QConv2D(1, 3, padding='same', activation='tanh')(conv15)
print("conv16 shape:", conv16.shape)

autoencoder = Model(model_input, conv16)
autoencoder.compile(loss='mse', optimizer=Adam(1e-4), metrics=[PSNR, ssim_metric])

# Ensure checkpoint directory exists
checkpoint_dir = 'checkpoint_oxford_flowers'
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

# Define callbacks
checkpoint = ModelCheckpoint('checkpoint_oxford_flowers/best_weights.keras', monitor='val_loss', save_best_only=True, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=20, verbose=1)

# Generate noisy data
x_train_noisy = add_noise(x_train)
x_valid_noisy = add_noise(x_valid)

# Start runtime tracking
start_time = time.time()

#start training
epochs = 100
batch_size = 32
history = autoencoder.fit(
    x_train_noisy, x_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_valid_noisy, x_valid),
    callbacks=[checkpoint, early_stop]
)

# Stop runtime tracking
elapsed_time = time.time() - start_time
print(f"\n🚀 Training Completed in {int(elapsed_time // 60)} min {int(elapsed_time % 60)} sec")

history_dict = history.history
num_epochs = len(history_dict['loss'])

csv_filename = f"qcnn-SAM_comparison_plot_{epochs}_epochs.csv"
with open(csv_filename, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["epoch","loss","val_loss","psnr","val_psnr","ssim_metric","val_ssim_metric"])
     # One row per epoch
    for epoch_idx in range(num_epochs):
        row = [
            epoch_idx + 1,
            history_dict['loss'][epoch_idx],
            history_dict['val_loss'][epoch_idx],
            history_dict['psnr'][epoch_idx],
            history_dict['val_psnr'][epoch_idx],
            history_dict['ssim_metric'][epoch_idx],
            history_dict['val_ssim_metric'][epoch_idx]
        ]
        writer.writerow(row)

# Download CSV in Colab
files.download(csv_filename)

# Denoise the images using the autoencoder
denoised_images = autoencoder.predict(x_valid_noisy)

plot_filename_loss = f"qcnn-SAM_loss_plot_{epochs}_epochs.png"
plot_filename_psnr = f"qcnn-SAM_psnr_plot_{epochs}_epochs.png"
plot_filename_ssim = f"qcnn-SAM_ssim_plot_{epochs}_epochs.png"
plot_filename_comparison = f"qcnn-SAM_comparison_plot_{epochs}_epochs.png"

# Plot training & validation loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig(plot_filename_loss)
plt.show()

# Plot PSNR
plt.figure()
plt.plot(history.history['psnr'], label='Train PSNR')
plt.plot(history.history['val_psnr'], label='Val PSNR')
plt.title('Model PSNR')
plt.xlabel('Epochs')
plt.ylabel('PSNR (dB)')
plt.legend()
plt.savefig(plot_filename_psnr)
plt.show()

#Plot SSIM
plt.figure()
plt.plot(history.history['ssim_metric'], label='Train SSIM')
plt.plot(history.history['val_ssim_metric'], label='Val SSIM')
plt.title('Model SSIM')
plt.xlabel('Epochs')
plt.ylabel('SSIM')
plt.legend()
plt.savefig(plot_filename_ssim)
plt.show()

files.download(plot_filename_loss)
files.download(plot_filename_psnr)
files.download(plot_filename_ssim)

def deprocess(x):
    x = (x + 1.0) * 127.5
    return np.clip(x, 0, 255).astype(np.uint8)

def display_images(original, noisy, denoised, n=5):
    plt.figure(figsize=(20, 6))
    for i in range(n):
        # Original
        ax = plt.subplot(3, n, i+1)
        plt.imshow(deprocess(original[i]))
        plt.title("Original")
        plt.axis("off")

        # Noisy
        ax = plt.subplot(3, n, i+1+n)
        plt.imshow(deprocess(noisy[i]))
        plt.title("Noisy")
        plt.axis("off")

        # Denoised
        ax = plt.subplot(3, n, i+1+2*n)
        plt.imshow(deprocess(denoised[i]))
        plt.title("Denoised")
        plt.axis("off")
    plt.savefig(plot_filename_comparison)
    plt.show()
    files.download(plot_filename_comparison)

# Visualize the first 5 original, noisy, and denoised images
display_images(x_valid, x_valid_noisy, denoised_images, n=5)

print("Training and visualization complete.")
# Out:
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2.0.2)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (1.14.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (11.1.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2025.3.30)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (0.4)
# Mounted at /content/drive
# /content/drive/MyDrive/quaternion_layers
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.7.4.2)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.1.31)
# Requirement already satisfied: charset-normalizer in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.4.1)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from kaggle) (3.10)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from kaggle) (5.29.4)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: setuptools>=21.0.0 in /usr/local/lib/python3.11/dist-packages (from kaggle) (75.2.0)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.3.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from kaggle) (0.5.1)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.11/dist-packages (4.9.8)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.4.0)
# Requirement already satisfied: array_record>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.7.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.1.9)
# Requirement already satisfied: etils>=1.9.1 in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (1.12.2)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (4.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (2.0.2)
# Requirement already satisfied: promise in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (5.29.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (18.1.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (2.32.3)
# Requirement already satisfied: simple_parsing in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.1.7)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.17.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (3.0.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.10.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (4.67.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.17.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (0.8.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (2025.3.2)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (6.5.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (4.13.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow-datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow-datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow-datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow-datasets) (2025.1.31)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.11/dist-packages (from dm-tree->tensorflow-datasets) (25.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from promise->tensorflow-datasets) (1.17.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.11/dist-packages (from simple_parsing->tensorflow-datasets) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /usr/local/lib/python3.11/dist-packages (from tensorflow-metadata->tensorflow-datasets) (1.70.0)
# WARNING:absl:Variant folder /root/tensorflow_datasets/oxford_flowers102/2.1.1 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/oxford_flowers102/2.1.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_flowers102/incomplete.ZAYH0U_2.1.1/oxford_flowers102-train.tfrecord…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_flowers102/incomplete.ZAYH0U_2.1.1/oxford_flowers102-test.tfrecord*…
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_flowers102/incomplete.ZAYH0U_2.1.1/oxford_flowers102-validation.tfr…
# Dataset oxford_flowers102 downloaded and prepared to /root/tensorflow_datasets/oxford_flowers102/2.1.1. Subsequent calls will reuse this data.
# {Split('train'): <SplitInfo num_examples=1020, num_shards=1>, Split('test'): <SplitInfo num_examples=6149, num_shards=2>, Split('validation'): <SplitInfo num_examples=1020, num_shards=1>}
# Train shape: (1020, 128, 128, 3)
# Valid shape: (1020, 128, 128, 3)
# Test shape:  (6149, 128, 128, 3)
# conv1 shape: (None, 128, 128, 69)
# after SAM conv1 shape: (None, 128, 128, 69)
# conv2 shape: (None, 128, 128, 69)
# pool1 shape: (None, 64, 64, 69)
# conv3 shape: (None, 64, 64, 135)
# SAM conv3 shape: (None, 64, 64, 135)
# conv4 shape: (None, 64, 64, 135)
# pool2 shape: (None, 32, 32, 135)
# conv5 shape: (None, 32, 32, 270)
# SAM conv5 shape: (None, 32, 32, 270)
# conv6 shape: (None, 32, 32, 270)
# flatten shape: (None, 276480)
# encoding shape: (None, 270)
# dense2 shape: (None, 576)
# reshape shape: (None, 8, 8, 9)
# upsample2 shape: (None, 32, 32, 9)
# conv11 shape: (None, 32, 32, 270)
# conv12 shape: (None, 32, 32, 270)
# add1 shape: (None, 32, 32, 270)
# upsample3 shape: (None, 128, 128, 270)
# conv13 shape: (None, 128, 128, 135)
# conv13 shape: (None, 128, 128, 135)
# conv14 shape: (None, 128, 128, 135)
# upsample_conv4 shape: (None, 128, 128, 135)
# add2 shape: (None, 128, 128, 135)
# conv15 shape: (None, 128, 128, 24)
# conv16 shape: (None, 128, 128, 3)
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.3680 - psnr: 4.3599 - ssim_metric: 0.0189
# Epoch 1: val_loss improved from inf to 0.24739, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 163s 3s/step - loss: 0.3671 - psnr: 4.3724 - ssim_metric: 0.0198 - val_loss: 0.2474 - val_psnr: 6.0752 - val_ssim_metric: 0.1238
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 511ms/step - loss: 0.1981 - psnr: 7.1811 - ssim_metric: 0.1793
# Epoch 2: val_loss improved from 0.24739 to 0.07752, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0223 - psnr: 16.5274 - ssim_metric: 0.6098
# Epoch 23: val_loss improved from 0.02295 to 0.02280, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 28s 892ms/step - loss: 0.0223 - psnr: 16.5265 - ssim_metric: 0.6099 - val_loss: 0.0228 - val_psnr: 16.4321 - val_ssim_metric: 0.6053
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 0.0226 - psnr: 16.4828 - ssim_metric: 0.6161
# Epoch 24: val_loss improved from 0.02280 to 0.02260, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 909ms/step - loss: 0.0226 - psnr: 16.4839 - ssim_metric: 0.6161 - val_loss: 0.0226 - val_psnr: 16.4714 - val_ssim_metric: 0.6069
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - loss: 0.0223 - psnr: 16.5275 - ssim_metric: 0.6145
# Epoch 25: val_loss improved from 0.02260 to 0.02240, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 929ms/step - loss: 0.0223 - psnr: 16.5283 - ssim_metric: 0.6145 - val_loss: 0.0224 - val_psnr: 16.5099 - val_ssim_metric: 0.6090
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0221 - psnr: 16.5757 - ssim_metric: 0.6166
# Epoch 26: val_loss improved from 0.02240 to 0.02218, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - loss: 0.0221 - psnr: 16.5767 - ssim_metric: 0.6166 - val_loss: 0.0222 - val_psnr: 16.5527 - val_ssim_metric: 0.6109
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - loss: 0.0218 - psnr: 16.6331 - ssim_metric: 0.6210
# Epoch 27: val_loss improved from 0.02218 to 0.02213, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - loss: 0.0218 - psnr: 16.6332 - ssim_metric: 0.6209 - val_loss: 0.0221 - val_psnr: 16.5621 - val_ssim_metric: 0.6092
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0214 - psnr: 16.7082 - ssim_metric: 0.6198
# Epoch 28: val_loss improved from 0.02213 to 0.02188, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - loss: 0.0214 - psnr: 16.7067 - ssim_metric: 0.6198 - val_loss: 0.0219 - val_psnr: 16.6112 - val_ssim_metric: 0.6118
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - loss: 0.0215 - psnr: 16.6956 - ssim_metric: 0.6170
# Epoch 29: val_loss improved from 0.02188 to 0.02174, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - loss: 0.0215 - psnr: 16.6954 - ssim_metric: 0.6171 - val_loss: 0.0217 - val_psnr: 16.6403 - val_ssim_metric: 0.6145
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 0.0207 - psnr: 16.8511 - ssim_metric: 0.6257
# Epoch 30: val_loss improved from 0.02174 to 0.02161, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 37s 1s/step - loss: 0.0207 - psnr: 16.8474 - ssim_metric: 0.6256 - val_loss: 0.0216 - val_psnr: 16.6654 - val_ssim_metric: 0.6136
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - loss: 0.0217 - psnr: 16.6353 - ssim_metric: 0.6207
# Epoch 31: val_loss improved from 0.02161 to 0.02151, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 0.0217 - psnr: 16.6380 - ssim_metric: 0.6207 - val_loss: 0.0215 - val_psnr: 16.6855 - val_ssim_metric: 0.6146
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - loss: 0.0213 - psnr: 16.7269 - ssim_metric: 0.6237
# Epoch 32: val_loss did not improve from 0.02151
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 34s 872ms/step - loss: 0.0213 - psnr: 16.7275 - ssim_metric: 0.6237 - val_loss: 0.0219 - val_psnr: 16.6096 - val_ssim_metric: 0.6109
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 0.0210 - psnr: 16.7835 - ssim_metric: 0.6234
# Epoch 33: val_loss improved from 0.02151 to 0.02139, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - loss: 0.0210 - psnr: 16.7833 - ssim_metric: 0.6234 - val_loss: 0.0214 - val_psnr: 16.7108 - val_ssim_metric: 0.6165
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - loss: 0.0207 - psnr: 16.8551 - ssim_metric: 0.6255
# Epoch 34: val_loss improved from 0.02139 to 0.02111, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 39s 971ms/step - loss: 0.0207 - psnr: 16.8542 - ssim_metric: 0.6255 - val_loss: 0.0211 - val_psnr: 16.7676 - val_ssim_metric: 0.6185
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 0.0212 - psnr: 16.7570 - ssim_metric: 0.6251
# Epoch 35: val_loss did not improve from 0.02111
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 38s 870ms/step - loss: 0.0212 - psnr: 16.7598 - ssim_metric: 0.6252 - val_loss: 0.0212 - val_psnr: 16.7511 - val_ssim_metric: 0.6174
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - loss: 0.0210 - psnr: 16.7951 - ssim_metric: 0.6278
# Epoch 36: val_loss improved from 0.02111 to 0.02101, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 68s 2s/step - loss: 0.0209 - psnr: 16.7972 - ssim_metric: 0.6278 - val_loss: 0.0210 - val_psnr: 16.7877 - val_ssim_metric: 0.6191
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0207 - psnr: 16.8500 - ssim_metric: 0.6281
# Epoch 37: val_loss improved from 0.02101 to 0.02089, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - loss: 0.0207 - psnr: 16.8515 - ssim_metric: 0.6281 - val_loss: 0.0209 - val_psnr: 16.8132 - val_ssim_metric: 0.6204
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - loss: 0.0206 - psnr: 16.8767 - ssim_metric: 0.6329
# Epoch 38: val_loss improved from 0.02089 to 0.02076, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 31s 969ms/step - loss: 0.0206 - psnr: 16.8778 - ssim_metric: 0.6328 - val_loss: 0.0208 - val_psnr: 16.8393 - val_ssim_metric: 0.6226
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0206 - psnr: 16.8717 - ssim_metric: 0.6269
# Epoch 39: val_loss improved from 0.02076 to 0.02063, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 39s 909ms/step - loss: 0.0206 - psnr: 16.8735 - ssim_metric: 0.6270 - val_loss: 0.0206 - val_psnr: 16.8677 - val_ssim_metric: 0.6224
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - loss: 0.0202 - psnr: 16.9633 - ssim_metric: 0.6297
# Epoch 40: val_loss did not improve from 0.02063
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 876ms/step - loss: 0.0202 - psnr: 16.9626 - ssim_metric: 0.6297 - val_loss: 0.0208 - val_psnr: 16.8270 - val_ssim_metric: 0.6241
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - loss: 0.0199 - psnr: 17.0262 - ssim_metric: 0.6280
# Epoch 41: val_loss improved from 0.02063 to 0.02048, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - loss: 0.0199 - psnr: 17.0233 - ssim_metric: 0.6281 - val_loss: 0.0205 - val_psnr: 16.8989 - val_ssim_metric: 0.6239
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - loss: 0.0205 - psnr: 16.8972 - ssim_metric: 0.6333
# Epoch 42: val_loss did not improve from 0.02048
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 33s 872ms/step - loss: 0.0205 - psnr: 16.8993 - ssim_metric: 0.6332 - val_loss: 0.0205 - val_psnr: 16.8884 - val_ssim_metric: 0.6222
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 0.0197 - psnr: 17.0572 - ssim_metric: 0.6331
# Epoch 43: val_loss improved from 0.02048 to 0.02033, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - loss: 0.0197 - psnr: 17.0556 - ssim_metric: 0.6331 - val_loss: 0.0203 - val_psnr: 16.9303 - val_ssim_metric: 0.6242
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - loss: 0.0198 - psnr: 17.0513 - ssim_metric: 0.6334
# Epoch 44: val_loss did not improve from 0.02033
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 28s 873ms/step - loss: 0.0198 - psnr: 17.0501 - ssim_metric: 0.6334 - val_loss: 0.0203 - val_psnr: 16.9277 - val_ssim_metric: 0.6240
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - loss: 0.
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - loss: 0.0195 - psnr: 17.1028 - ssim_metric: 0.6371
# Epoch 56: val_loss improved from 0.01951 to 0.01946, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 936ms/step - loss: 0.0195 - psnr: 17.1052 - ssim_metric: 0.6372 - val_loss: 0.0195 - val_psnr: 17.1206 - val_ssim_metric: 0.6339
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - loss: 0.0190 - psnr: 17.2274 - ssim_metric: 0.6401
# Epoch 57: val_loss improved from 0.01946 to 0.01941, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - loss: 0.0190 - psnr: 17.2267 - ssim_metric: 0.6401 - val_loss: 0.0194 - val_psnr: 17.1327 - val_ssim_metric: 0.6323
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 0.0193 - psnr: 17.1524 - ssim_metric: 0.6401
# Epoch 58: val_loss improved from 0.01941 to 0.01933, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 0.0193 - psnr: 17.1545 - ssim_metric: 0.6401 - val_loss: 0.0193 - val_psnr: 17.1512 - val_ssim_metric: 0.6336
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - loss: 0.0191 - psnr: 17.1901 - ssim_metric: 0.6406
# Epoch 59: val_loss improved from 0.01933 to 0.01928, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 0.0191 - psnr: 17.1910 - ssim_metric: 0.6406 - val_loss: 0.0193 - val_psnr: 17.1612 - val_ssim_metric: 0.6352
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - loss: 0.0193 - psnr: 17.1489 - ssim_metric: 0.6414
# Epoch 60: val_loss improved from 0.01928 to 0.01924, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step - loss: 0.0193 - psnr: 17.1511 - ssim_metric: 0.6414 - val_loss: 0.0192 - val_psnr: 17.1709 - val_ssim_metric: 0.6343
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - loss: 0.0187 - psnr: 17.3009 - ssim_metric: 0.6447
# Epoch 61: val_loss did not improve from 0.01924
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 28s 872ms/step - loss: 0.0187 - psnr: 17.2994 - ssim_metric: 0.6446 - val_loss: 0.0193 - val_psnr: 17.1685 - val_ssim_metric: 0.6350
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - loss: 0.0187 - psnr: 17.2899 - ssim_metric: 0.6454
# Epoch 62: val_loss improved from 0.01924 to 0.01911, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - loss: 0.0187 - psnr: 17.2895 - ssim_metric: 0.6453 - val_loss: 0.0191 - val_psnr: 17.2008 - val_ssim_metric: 0.6359
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 0.0183 - psnr: 17.3848 - ssim_metric: 0.6437
# Epoch 63: val_loss did not improve from 0.01911
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 704ms/step - loss: 0.0183 - psnr: 17.3819 - ssim_metric: 0.6437 - val_loss: 0.0191 - val_psnr: 17.1996 - val_ssim_metric: 0.6353
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - loss: 0.0184 - psnr: 17.3562 - ssim_metric: 0.6468
# Epoch 64: val_loss improved from 0.01911 to 0.01910, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - loss: 0.0184 - psnr: 17.3545 - ssim_metric: 0.6467 - val_loss: 0.0191 - val_psnr: 17.2022 - val_ssim_metric: 0.6361
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - loss: 0.0184 - psnr: 17.3532 - ssim_metric: 0.6472
# Epoch 65: val_loss improved from 0.01910 to 0.01908, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 0.0185 - psnr: 17.3518 - ssim_metric: 0.6471 - val_loss: 0.0191 - val_psnr: 17.2074 - val_ssim_metric: 0.6361
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 0.0185 - psnr: 17.3504 - ssim_metric: 0.6449
# Epoch 66: val_loss improved from 0.01908 to 0.01891, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - loss: 0.0185 - psnr: 17.3494 - ssim_metric: 0.6449 - val_loss: 0.0189 - val_psnr: 17.2449 - val_ssim_metric: 0.6380
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - loss: 0.0187 - psnr: 17.3051 - ssim_metric: 0.6443
# Epoch 67: val_loss improved from 0.01891 to 0.01885, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - loss: 0.0181 - psnr: 17.4444 - ssim_metric: 0.6548
# Epoch 79: val_loss improved from 0.01836 to 0.01828, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - loss: 0.0181 - psnr: 17.4453 - ssim_metric: 0.6547 - val_loss: 0.0183 - val_psnr: 17.3947 - val_ssim_metric: 0.6461
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 0.0179 - psnr: 17.4767 - ssim_metric: 0.6521
# Epoch 80: val_loss did not improve from 0.01828
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 28s 870ms/step - loss: 0.0179 - psnr: 17.4772 - ssim_metric: 0.6521 - val_loss: 0.0183 - val_psnr: 17.3898 - val_ssim_metric: 0.6468
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 0.0182 - psnr: 17.4006 - ssim_metric: 0.6500
# Epoch 81: val_loss improved from 0.01828 to 0.01826, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - loss: 0.0182 - psnr: 17.4035 - ssim_metric: 0.6501 - val_loss: 0.0183 - val_psnr: 17.3972 - val_ssim_metric: 0.6444
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - loss: 0.0176 - psnr: 17.5475 - ssim_metric: 0.6515
# Epoch 82: val_loss improved from 0.01826 to 0.01817, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - loss: 0.0176 - psnr: 17.5463 - ssim_metric: 0.6515 - val_loss: 0.0182 - val_psnr: 17.4208 - val_ssim_metric: 0.6459
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0180 - psnr: 17.4697 - ssim_metric: 0.6523
# Epoch 83: val_loss improved from 0.01817 to 0.01808, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - loss: 0.0180 - psnr: 17.4713 - ssim_metric: 0.6523 - val_loss: 0.0181 - val_psnr: 17.4406 - val_ssim_metric: 0.6476
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - loss: 0.0175 - psnr: 17.5797 - ssim_metric: 0.6531
# Epoch 84: val_loss did not improve from 0.01808
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 34s 877ms/step - loss: 0.0175 - psnr: 17.5781 - ssim_metric: 0.6532 - val_loss: 0.0181 - val_psnr: 17.4337 - val_ssim_metric: 0.6470
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - loss: 0.0183 - psnr: 17.3919 - ssim_metric: 0.6500
# Epoch 85: val_loss improved from 0.01808 to 0.01804, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - loss: 0.0183 - psnr: 17.3958 - ssim_metric: 0.6501 - val_loss: 0.0180 - val_psnr: 17.4508 - val_ssim_metric: 0.6476
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - loss: 0.0176 - psnr: 17.5528 - ssim_metric: 0.6562
# Epoch 86: val_loss did not improve from 0.01804
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 714ms/step - loss: 0.0176 - psnr: 17.5525 - ssim_metric: 0.6562 - val_loss: 0.0181 - val_psnr: 17.4424 - val_ssim_metric: 0.6471
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - loss: 0.0178 - psnr: 17.5094 - ssim_metric: 0.6523
# Epoch 87: val_loss improved from 0.01804 to 0.01797, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - loss: 0.0178 - psnr: 17.5106 - ssim_metric: 0.6524 - val_loss: 0.0180 - val_psnr: 17.4687 - val_ssim_metric: 0.6499
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 0.0179 - psnr: 17.4810 - ssim_metric: 0.6580
# Epoch 88: val_loss improved from 0.01797 to 0.01796, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 39s 1s/step - loss: 0.0179 - psnr: 17.4836 - ssim_metric: 0.6580 - val_loss: 0.0180 - val_psnr: 17.4717 - val_ssim_metric: 0.6491
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - loss: 0.0175 - psnr: 17.5857 - ssim_metric: 0.6559
# Epoch 89: val_loss improved from 0.01796 to 0.01790, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - loss: 0.0175 - psnr: 17.5853 - ssim_metric: 0.6560 - val_loss: 0.0179 - val_psnr: 17.4854 - val_ssim_metric: 0.6492
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - loss: 0.0175 - psnr: 17.5904 - ssim_metric: 0.6585
# Epoch 90: val_loss improved from 0.01790 to 0.01786, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - loss: 0.0175 - psnr: 17.5902 - ssim_metric: 0.6584 - val_loss: 0.0179 - val_psnr: 17.4944 - val_ssim_metric: 0.6493
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 0.0172 - psnr: 17.6613 - ssim_metric: 0.6550
# Epoch 91: val_loss improved from 0.01786 to 0.01777, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - loss: 0.0172 - psnr: 17.6596 - ssim_metric: 0.6551 - val_loss: 0.0178 - val_psnr: 17.5176 - val_ssim_metric: 0.6512
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - loss: 0.0174 - psnr: 17.6145 - ssim_metric: 0.6551
# Epoch 92: val_loss improved from 0.01777 to 0.01777, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 915ms/step - loss: 0.0174 - psnr: 17.6142 - ssim_metric: 0.6552 - val_loss: 0.0178 - val_psnr: 17.5178 - val_ssim_metric: 0.6511
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - loss: 0.0173 - psnr: 17.6339 - ssim_metric: 0.6589
# Epoch 93: val_loss improved from 0.01777 to 0.01773, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - loss: 0.0173 - psnr: 17.6332 - ssim_metric: 0.6589 - val_loss: 0.0177 - val_psnr: 17.5268 - val_ssim_metric: 0.6527
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0173 - psnr: 17.6259 - ssim_metric: 0.6570
# Epoch 94: val_loss did not improve from 0.01773
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 34s 866ms/step - loss: 0.0173 - psnr: 17.6253 - ssim_metric: 0.6570 - val_loss: 0.0178 - val_psnr: 17.5106 - val_ssim_metric: 0.6527
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 547ms/step - loss: 0.0176 - psnr: 17.5551 - ssim_metric: 0.6580
# Epoch 95: val_loss improved from 0.01773 to 0.01763, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 1s/step - loss: 0.0176 - psnr: 17.5577 - ssim_metric: 0.6581 - val_loss: 0.0176 - val_psnr: 17.5513 - val_ssim_metric: 0.6530
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 0.0174 - psnr: 17.6059 - ssim_metric: 0.6577
# Epoch 96: val_loss improved from 0.01763 to 0.01763, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 985ms/step - loss: 0.0174 - psnr: 17.6071 - ssim_metric: 0.6577 - val_loss: 0.0176 - val_psnr: 17.5519 - val_ssim_metric: 0.6531
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - loss: 0.0170 - psnr: 17.7030 - ssim_metric: 0.6577
# Epoch 97: val_loss improved from 0.01763 to 0.01757, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 963ms/step - loss: 0.0170 - psnr: 17.7013 - ssim_metric: 0.6577 - val_loss: 0.0176 - val_psnr: 17.5653 - val_ssim_metric: 0.6538
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - loss: 0.0171 - psnr: 17.6813 - ssim_metric: 0.6610
# Epoch 98: val_loss improved from 0.01757 to 0.01757, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - loss: 0.0171 - psnr: 17.6806 - ssim_metric: 0.6609 - val_loss: 0.0176 - val_psnr: 17.5672 - val_ssim_metric: 0.6527
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - loss: 0.0169 - psnr: 17.7245 - ssim_metric: 0.6617
# Epoch 99: val_loss improved from 0.01757 to 0.01747, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 912ms/step - loss: 0.0169 - psnr: 17.7230 - ssim_metric: 0.6617 - val_loss: 0.0175 - val_psnr: 17.5900 - val_ssim_metric: 0.6541
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - loss: 0.0171 - psnr: 17.6686 - ssim_metric: 0.6599
# Epoch 100: val_loss did not improve from 0.01747
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 873ms/step - loss: 0.0171 - psnr: 17.6690 - ssim_metric: 0.6600 - val_loss: 0.0175 - val_psnr: 17.5796 - val_ssim_metric: 0.6540
#
# 🚀 Training Completed in 68 min 52 sec
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 288ms/step
# Training and visualization complete.
