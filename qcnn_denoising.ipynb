# %% [markdown]
# <a href="https://colab.research.google.com/github/shineamor/SP-colab-notebooks/blob/main/qcnn_denoising.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (1.26.4)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (1.14.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (11.1.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2025.2.18)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (0.4)

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !find /content/drive/MyDrive -type d -name "quaternion_layers"
# Out:
# /content/drive/MyDrive/quaternion_layers

# %%
import sys
sys.path.append('/content/drive/MyDrive')

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.1.31)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.3.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.11/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle) (3.10)

# %%
pip install tensorflow-datasets
# Out:
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.11/dist-packages (4.9.8)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.4.0)
# Requirement already satisfied: array_record>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.7.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.1.9)
# Requirement already satisfied: etils>=1.9.1 in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (1.12.2)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (4.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.26.4)
# Requirement already satisfied: promise in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (4.25.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (18.1.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (2.32.3)
# Requirement already satisfied: simple_parsing in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.1.7)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.16.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (2.5.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.10.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (4.67.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.17.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (0.8.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (6.5.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (4.12.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow-datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow-datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow-datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow-datasets) (2025.1.31)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.11/dist-packages (from dm-tree->tensorflow-datasets) (25.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from promise->tensorflow-datasets) (1.17.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.11/dist-packages (from simple_parsing->tensorflow-datasets) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /usr/local/lib/python3.11/dist-packages (from tensorflow-metadata->tensorflow-datasets) (1.69.1)

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import numpy as np
import PIL, os, random, skimage.util, csv
import tensorflow.keras.backend as K
from google.colab import files
from quaternion_layers import QConv2D, QDense
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, AveragePooling2D, UpSampling2D, Reshape, Flatten, Input, Add, Multiply, GlobalAveragePooling2D, GlobalMaxPooling2D, Concatenate, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import time

#Load Oxford Flowers dataset
dataset, info = tfds.load(
    "oxford_flowers102",
    with_info=True,
    as_supervised=True
)
print(info.splits)

#Function to covert TF Dataset to NumPy arrays
def ds_to_numpy(dataset):
    images, labels = [], []
    for img, lbl in dataset:
        images.append(img.numpy())
        labels.append(lbl.numpy())
    return np.array(images), np.array(labels)

#Preprocessing function: Resize & Normalize images
def preprocess(image, label):
    image = tf.image.resize(image, [128, 128]) # Resize to 128×128
    image = tf.cast(image, tf.float32) / 255.0 # Normalize [0,1]
    image = (image * 2.0) - 1.0  # Convert to [-1,1]
    return image, label

# Function to add noise to images (Salt & Pepper, Gaussian)
def add_noise(images, noise_factor=0.2, salt_pepper_amount=0.1):
    noisy_images = []
    for img in images:
        # Add salt & pepper noise
        img_sp = skimage.util.random_noise(img, mode='s&p', amount=salt_pepper_amount)

        # Add Gaussian noise
        img_noisy = img_sp + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=img.shape)
        img_noisy = np.clip(img_noisy, -1.0, 1.0)  # Ensure values are in the valid range [-1, 1]

        noisy_images.append(img_noisy)

    return np.array(noisy_images)

def PSNR(y_true, y_pred):
    max_pixel = 1.0  # Since images are normalized to [-1,1]
    return 10.0 * K.log((max_pixel ** 2) / (K.mean(K.square(y_pred - y_true)))) / K.log(10.0)

def ssim_metric(y_true, y_pred):
    return tf.reduce_mean(tf.image.ssim(y_true, y_pred, max_val=2.0))

# Define the Spatial Attention Module (SAM)
def spatial_attention(input_feature):
    avg_pool = Lambda(lambda x: tf.reduce_mean(x, axis=-1, keepdims=True))(input_feature)
    max_pool = Lambda(lambda x: tf.reduce_max(x, axis=-1, keepdims=True))(input_feature)
    concat = Concatenate(axis=-1)([avg_pool, max_pool])
    attention = Conv2D(1, kernel_size=7, padding='same', activation='sigmoid')(concat)
    return Multiply()([input_feature, attention])

# Load dataset splits
splits, info = tfds.load(
    'oxford_flowers102',
    split=['train','test','validation'],
    as_supervised=True,
    with_info=True
)
train_ds, test_ds, val_ds = splits

# Apply preprocessing to dataset
train_ds = train_ds.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
test_ds  = test_ds.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
val_ds   = val_ds.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)

# Convert dataset to NumPy arrays
(x_train, _), (x_valid, _), (x_test, _) = (
    ds_to_numpy(train_ds),
    ds_to_numpy(val_ds),
    ds_to_numpy(test_ds)
)

# Convert each split to NumPy
(x_train, y_train) = ds_to_numpy(train_ds)
(x_test, y_test)   = ds_to_numpy(test_ds)
(x_valid, y_valid) = ds_to_numpy(val_ds)

print("Train shape:", x_train.shape)
print("Valid shape:", x_valid.shape)
print("Test shape: ", x_test.shape)

# Model Configuration
encoding_size = 90
perturbation_max = 40
image_shape = (128,128,3)

# Define Model Architecture
model_input = Input(shape=image_shape)

# Encoder
conv1 = QConv2D(23, 3, padding='same', activation='relu')(model_input)
print("conv1 shape:", conv1.shape)
conv2 = QConv2D(23, 3, padding='same', activation='relu')(conv1)
print("conv2 shape:", conv2.shape)
pool1 = AveragePooling2D(2, 2)(conv2)
print("pool1 shape:", pool1.shape)
conv3 = QConv2D(45, 3, padding='same', activation='relu')(pool1)
print("conv3 shape:", conv3.shape)
conv4 = QConv2D(45, 3, padding='same', activation='relu')(conv3)
print("conv4 shape:", conv4.shape)
pool2 = AveragePooling2D(2, 2)(conv4)
print("pool2 shape:", pool2.shape)
conv5 = QConv2D(90, 3, padding='same', activation='relu')(pool2)
print("conv5 shape:", conv5.shape)
conv6 = QConv2D(90, 3, padding='same', activation='relu')(conv5)
print("conv6 shape:", conv6.shape)

# Decoder
flatten = Flatten()(conv6)
print("flatten shape:", flatten.shape)
encoding = QDense(encoding_size, activation='relu')(flatten)
print("encoding shape:", encoding.shape)
dense2 = QDense(192, activation='relu')(encoding)
print("dense2 shape:", dense2.shape)
reshape = Reshape((8, 8, 9))(dense2)
print("reshape shape:", reshape.shape)
upsample2 = UpSampling2D(size=(4, 4))(reshape)
print("upsample2 shape:", upsample2.shape)
conv11 = QConv2D(90, 3, padding='same', activation='relu')(upsample2)
print("conv11 shape:", conv11.shape)
conv12 = QConv2D(90, 3, padding='same', activation='relu')(conv11)
print("conv12 shape:", conv12.shape)
add1 = Add()([conv12, conv6])
print("add1 shape:", add1.shape)
upsample3 = UpSampling2D(size=(4, 4))(add1)
print("upsample3 shape:", upsample3.shape)
conv13 = QConv2D(45, 3, padding='same', activation='relu')(upsample3)
print("conv13 shape:", conv13.shape)
conv14 = QConv2D(45, 3, padding='same', activation='relu')(conv13)
print("conv14 shape:", conv14.shape)
upsample_conv4 = UpSampling2D(size=(2, 2))(conv4)
print("upsample_conv4 shape:", upsample_conv4.shape)
add2 = Add()([conv14, upsample_conv4])
print("add2 shape:", add2.shape)
upsample3 = UpSampling2D(size=(4, 4))(add2)
conv15 = QConv2D(8, 3, padding='same', activation='relu')(add2)
print("conv15 shape:", conv15.shape)
conv16 = QConv2D(1, 3, padding='same', activation='tanh')(conv15)
print("conv16 shape:", conv16.shape)

autoencoder = Model(model_input, conv16)
autoencoder.compile(loss='mse', optimizer=Adam(1e-4), metrics=[PSNR, ssim_metric])

# Ensure the directory exists
checkpoint_dir = 'checkpoint_oxford_flowers'
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

# Define callbacks
checkpoint = ModelCheckpoint('checkpoint_oxford_flowers/best_weights.keras', monitor='val_loss', save_best_only=True, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=20, verbose=1)

# Generate noisy data
x_train_noisy = add_noise(x_train)
x_valid_noisy = add_noise(x_valid)

# Start runtime tracking
start_time = time.time()

#start training
epochs = 100
batch_size = 32
history = autoencoder.fit(
    x_train_noisy, x_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_valid_noisy, x_valid),
    callbacks=[checkpoint, early_stop]
)

# Stop runtime tracking
elapsed_time = time.time() - start_time
print(f"\n🚀 Training Completed in {int(elapsed_time // 60)} min {int(elapsed_time % 60)} sec")

history_dict = history.history
num_epochs = len(history_dict['loss'])

csv_filename = f"qcnn_comparison_plot_{epochs}_epochs.csv"
with open(csv_filename, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["epoch","loss","val_loss","psnr","val_psnr","ssim_metric","val_ssim_metric"])
     # One row per epoch
    for epoch_idx in range(num_epochs):
        row = [
            epoch_idx + 1,
            history_dict['loss'][epoch_idx],
            history_dict['val_loss'][epoch_idx],
            history_dict['psnr'][epoch_idx],
            history_dict['val_psnr'][epoch_idx],
            history_dict['ssim_metric'][epoch_idx],
            history_dict['val_ssim_metric'][epoch_idx]
        ]
        writer.writerow(row)

# Download CSV in Colab
files.download(csv_filename)

# Denoise the images using the autoencoder
denoised_images = autoencoder.predict(x_valid_noisy)

plot_filename_loss = f"qcnn_loss_plot_{epochs}_epochs.png"
plot_filename_psnr = f"qcnn_psnr_plot_{epochs}_epochs.png"
plot_filename_ssim = f"qcnn_ssim_plot_{epochs}_epochs.png"
plot_filename_comparison = f"qcnn_comparison_plot_{epochs}_epochs.png"

# Plot training & validation loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig(plot_filename_loss)
plt.show()

# Plot PSNR
plt.figure()
plt.plot(history.history['psnr'], label='Train PSNR')
plt.plot(history.history['val_psnr'], label='Val PSNR')
plt.title('Model PSNR')
plt.xlabel('Epochs')
plt.ylabel('PSNR (dB)')
plt.legend()
plt.savefig(plot_filename_psnr)
plt.show()

#Plot SSIM
plt.figure()
plt.plot(history.history['ssim_metric'], label='Train SSIM')
plt.plot(history.history['val_ssim_metric'], label='Val SSIM')
plt.title('Model SSIM')
plt.xlabel('Epochs')
plt.ylabel('SSIM')
plt.legend()
plt.savefig(plot_filename_ssim)
plt.show()

files.download(plot_filename_loss)
files.download(plot_filename_psnr)
files.download(plot_filename_ssim)

def deprocess(x):
    """Map [-1,1] -> [0,255]."""
    x = (x + 1.0) * 127.5
    return np.clip(x, 0, 255).astype(np.uint8)

def display_images(original, noisy, denoised, n=5):
    plt.figure(figsize=(20, 6))
    for i in range(n):
        # Original
        ax = plt.subplot(3, n, i+1)
        plt.imshow(deprocess(original[i]))
        plt.title("Original")
        plt.axis("off")

        # Noisy
        ax = plt.subplot(3, n, i+1+n)
        plt.imshow(deprocess(noisy[i]))
        plt.title("Noisy")
        plt.axis("off")

        # Denoised
        ax = plt.subplot(3, n, i+1+2*n)
        plt.imshow(deprocess(denoised[i]))
        plt.title("Denoised")
        plt.axis("off")
    plt.savefig(plot_filename_comparison)
    plt.show()
    files.download(plot_filename_comparison)


# Visualize the first 5 original, noisy, and denoised images
display_images(x_valid, x_valid_noisy, denoised_images, n=5)

print("Training and visualization complete.")
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/oxford_flowers102/2.1.1 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/oxford_flowers102/2.1.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_flowers102/incomplete.8EKF26_2.1.1/oxford_flowers102-train.tfrecord…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_flowers102/incomplete.8EKF26_2.1.1/oxford_flowers102-test.tfrecord*…
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_flowers102/incomplete.8EKF26_2.1.1/oxford_flowers102-validation.tfr…
# Dataset oxford_flowers102 downloaded and prepared to /root/tensorflow_datasets/oxford_flowers102/2.1.1. Subsequent calls will reuse this data.
# {Split('train'): <SplitInfo num_examples=1020, num_shards=1>, Split('test'): <SplitInfo num_examples=6149, num_shards=2>, Split('validation'): <SplitInfo num_examples=1020, num_shards=1>}
# Train shape: (1020, 128, 128, 3)
# Valid shape: (1020, 128, 128, 3)
# Test shape:  (6149, 128, 128, 3)
# conv1 shape: (None, 128, 128, 69)
# conv2 shape: (None, 128, 128, 69)
# pool1 shape: (None, 64, 64, 69)
# conv3 shape: (None, 64, 64, 135)
# conv4 shape: (None, 64, 64, 135)
# pool2 shape: (None, 32, 32, 135)
# conv5 shape: (None, 32, 32, 270)
# conv6 shape: (None, 32, 32, 270)
# flatten shape: (None, 276480)
# encoding shape: (None, 270)
# dense2 shape: (None, 576)
# reshape shape: (None, 8, 8, 9)
# upsample2 shape: (None, 32, 32, 9)
# conv11 shape: (None, 32, 32, 270)
# conv12 shape: (None, 32, 32, 270)
# add1 shape: (None, 32, 32, 270)
# upsample3 shape: (None, 128, 128, 270)
# conv13 shape: (None, 128, 128, 135)
# conv14 shape: (None, 128, 128, 135)
# upsample_conv4 shape: (None, 128, 128, 135)
# add2 shape: (None, 128, 128, 135)
# conv15 shape: (None, 128, 128, 24)
# conv16 shape: (None, 128, 128, 3)
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.3352 - psnr: 4.9481 - ssim_metric: 0.0588
# Epoch 1: val_loss improved from inf to 0.08385, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 161s 3s/step - loss: 0.3325 - psnr: 4.9949 - ssim_metric: 0.0612 - val_loss: 0.0838 - val_psnr: 10.7720 - val_ssim_metric: 0.3015
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - loss: 0.0686 - psnr: 11.6902 - ssim_metric: 0.3578
# Epoch 2: val_loss improved from 0.08385 to 0.04958, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 74s 726ms/step - loss: 0.0684 - psnr: 11.7062 - ssim_metric: 0.3587 - val_loss: 0.0496 - val_psnr: 13.0556 - val_ssim_metric: 0.4300
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - loss: 0.0474 - psnr: 13.2514 - ssim_metric: 0.4462
# Epoch 3: val_loss improved from 0.04958 to 0.03951, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 47s 905ms/step - loss: 0.0474 - psnr: 13.2593 - ssim_metric: 0.4467 - val_loss: 0.0395 - val_psnr: 14.0428 - val_ssim_metric: 0.4867
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0381 - psnr: 14.2029 - ssim_metric: 0.5045
# Epoch 4: val_loss improved from 0.03951 to 0.03376, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 729ms/step - loss: 0.0380 - psnr: 14.2082 - ssim_metric: 0.5047 - val_loss: 0.0338 - val_psnr: 14.7263 - val_ssim_metric: 0.5280
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - loss: 0.0335 - psnr: 14.7607 - ssim_metric: 0.5319
# Epoch 5: val_loss improved from 0.03376 to 0.03099, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 726ms/step - loss: 0.0334 - psnr: 14.7645 - ssim_metric: 0.5321 - val_loss: 0.0310 - val_psnr: 15.0982 - val_ssim_metric: 0.5465
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 550ms/step - loss: 0.0306 - psnr: 15.1499 - ssim_metric: 0.5544
# Epoch 6: val_loss improved from 0.03099 to 0.02915, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 911ms/step - loss: 0.0306 - psnr: 15.1517 - ssim_metric: 0.5544 - val_loss: 0.0292 - val_psnr: 15.3635 - val_ssim_metric: 0.5575
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - loss: 0.0287 - psnr: 15.4307 - ssim_metric: 0.5622
# Epoch 7: val_loss improved from 0.02915 to 0.02782, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 724ms/step - loss: 0.0287 - psnr: 15.4313 - ssim_metric: 0.5623 - val_loss: 0.0278 - val_psnr: 15.5671 - val_ssim_metric: 0.5663
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 550ms/step - loss: 0.0277 - psnr: 15.5864 - ssim_metric: 0.5726
# Epoch 8: val_loss improved from 0.02782 to 0.02712, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 748ms/step - loss: 0.0276 - psnr: 15.5877 - ssim_metric: 0.5727 - val_loss: 0.0271 - val_psnr: 15.6773 - val_ssim_metric: 0.5698
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - loss: 0.0266 - psnr: 15.7692 - ssim_metric: 0.5723
# Epoch 9: val_loss improved from 0.02712 to 0.02611, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 734ms/step - loss: 0.0266 - psnr: 15.7693 - ssim_metric: 0.5725 - val_loss: 0.0261 - val_psnr: 15.8427 - val_ssim_metric: 0.5791
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - loss: 0.0263 - psnr: 15.8130 - ssim_metric: 0.5783
# Epoch 10: val_loss improved from 0.02611 to 0.02562, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 724ms/step - loss: 0.0263 - psnr: 15.8154 - ssim_metric: 0.5785 - val_loss: 0.0256 - val_psnr: 15.9253 - val_ssim_metric: 0.5813
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - loss: 0.0251 - psnr: 16.0147 - ssim_metric: 0.5876
# Epoch 11: val_loss improved from 0.02562 to 0.02502, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 47s 907ms/step - loss: 0.0251 - psnr: 16.0133 - ssim_metric: 0.5876 - val_loss: 0.0250 - val_psnr: 16.0281 - val_ssim_metric: 0.5862
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 0.0255 - psnr: 15.9443 - ssim_metric: 0.5923
# Epoch 12: val_loss improved from 0.02502 to 0.02468, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 734ms/step - loss: 0.0255 - psnr: 15.9481 - ssim_metric: 0.5923 - val_loss: 0.0247 - val_psnr: 16.0871 - val_ssim_metric: 0.5880
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - loss: 0.0244 - psnr: 16.1414 - ssim_metric: 0.5937
# Epoch 13: val_loss improved from 0.02468 to 0.02413, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 725ms/step - loss: 0.0244 - psnr: 16.1414 - ssim_metric: 0.5938 - val_loss: 0.0241 - val_psnr: 16.1847 - val_ssim_metric: 0.5927
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 550ms/step - loss: 0.0240 - psnr: 16.1973 - ssim_metric: 0.5957
# Epoch 14: val_loss improved from 0.02413 to 0.02388, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 909ms/step - loss: 0.0240 - psnr: 16.1970 - ssim_metric: 0.5957 - val_loss: 0.0239 - val_psnr: 16.2300 - val_ssim_metric: 0.5934
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - loss: 0.0235 - psnr: 16.3028 - ssim_metric: 0.6018
# Epoch 15: val_loss improved from 0.02388 to 0.02350, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 726ms/step - loss: 0.0235 - psnr: 16.3019 - ssim_metric: 0.6018 - val_loss: 0.0235 - val_psnr: 16.3007 - val_ssim_metric: 0.5973
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 549ms/step - loss: 0.0236 - psnr: 16.2900 - ssim_metric: 0.6027
# Epoch 16: val_loss improved from 0.02350 to 0.02328, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 908ms/step - loss: 0.0236 - psnr: 16.2908 - ssim_metric: 0.6027 - val_loss: 0.0233 - val_psnr: 16.3405 - val_ssim_metric: 0.5982
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - loss: 0.0235 - psnr: 16.2905 - ssim_metric: 0.6028
# Epoch 17: val_loss improved from 0.02328 to 0.02304, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 723ms/step - loss: 0.0235 - psnr: 16.2931 - ssim_metric: 0.6029 - val_loss: 0.0230 - val_psnr: 16.3872 - val_ssim_metric: 0.6003
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 0.0228 - psnr: 16.4230 - ssim_metric: 0.6080
# Epoch 18: val_loss did not improve from 0.02304
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 700ms/step - loss: 0.0228 - psnr: 16.4225 - ssim_metric: 0.6080 - val_loss: 0.0231 - val_psnr: 16.3776 - val_ssim_metric: 0.5999
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - loss: 0.0230 - psnr: 16.3934 - ssim_metric: 0.6021
# Epoch 19: val_loss improved from 0.02304 to 0.02272, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 744ms/step - loss: 0.0230 - psnr: 16.3952 - ssim_metric: 0.6023 - val_loss: 0.0227 - val_psnr: 16.4462 - val_ssim_metric: 0.6042
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 0.0225 - psnr: 16.4764 - ssim_metric: 0.6090
# Epoch 20: val_loss improved from 0.02272 to 0.02237, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 892ms/step - loss: 0.0225 - psnr: 16.4768 - ssim_metric: 0.6091 - val_loss: 0.0224 - val_psnr: 16.5145 - val_ssim_metric: 0.6072
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - loss: 0.0229 - psnr: 16.4045 - ssim_metric: 0.6088
# Epoch 21: val_loss improved from 0.02237 to 0.02221, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 740ms/step - loss: 0.0229 - psnr: 16.4084 - ssim_metric: 0.6089 - val_loss: 0.0222 - val_psnr: 16.5464 - val_ssim_metric: 0.6083
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - loss: 0.0224 - psnr: 16.5120 - ssim_metric: 0.6110
# Epoch 22: val_loss improved from 0.02221 to 0.02208, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 730ms/step - loss: 0.0224 - psnr: 16.5133 - ssim_metric: 0.6111 - val_loss: 0.0221 - val_psnr: 16.5707 - val_ssim_metric: 0.6095
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0221 - psnr: 16.5622 - ssim_metric: 0.6161
# Epoch 23: val_loss improved from 0.02208 to 0.02179, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 732ms/step - loss: 0.0221 - psnr: 16.5637 - ssim_metric: 0.6160 - val_loss: 0.0218 - val_psnr: 16.6300 - val_ssim_metric: 0.6122
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0217 - psnr: 16.6536 - ssim_metric: 0.6166
# Epoch 24: val_loss improved from 0.02179 to 0.02166, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 730ms/step - loss: 0.0217 - psnr: 16.6533 - ssim_metric: 0.6166 - val_loss: 0.0217 - val_psnr: 16.6547 - val_ssim_metric: 0.6129
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 550ms/step - loss: 0.0215 - psnr: 16.7036 - ssim_metric: 0.6174
# Epoch 25: val_loss improved from 0.02166 to 0.02160, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 747ms/step - loss: 0.0215 - psnr: 16.7025 - ssim_metric: 0.6174 - val_loss: 0.0216 - val_psnr: 16.6667 - val_ssim_metric: 0.6155
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - loss: 0.0214 - psnr: 16.6968 - ssim_metric: 0.6161
# Epoch 26: val_loss improved from 0.02160 to 0.02136, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 727ms/step - loss: 0.0214 - psnr: 16.6969 - ssim_metric: 0.6162 - val_loss: 0.0214 - val_psnr: 16.7166 - val_ssim_metric: 0.6171
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - loss: 0.0210 - psnr: 16.7841 - ssim_metric: 0.6217
# Epoch 27: val_loss improved from 0.02136 to 0.02120, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 47s 913ms/step - loss: 0.0210 - psnr: 16.7825 - ssim_metric: 0.6217 - val_loss: 0.0212 - val_psnr: 16.7486 - val_ssim_metric: 0.6184
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0212 - psnr: 16.7607 - ssim_metric: 0.6201
# Epoch 28: val_loss improved from 0.02120 to 0.02105, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 729ms/step - loss: 0.0212 - psnr: 16.7611 - ssim_metric: 0.6202 - val_loss: 0.0210 - val_psnr: 16.7798 - val_ssim_metric: 0.6192
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - loss: 0.0207 - psnr: 16.8558 - ssim_metric: 0.6265
# Epoch 29: val_loss improved from 0.02105 to 0.02093, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 903ms/step - loss: 0.0207 - psnr: 16.8537 - ssim_metric: 0.6264 - val_loss: 0.0209 - val_psnr: 16.8039 - val_ssim_metric: 0.6210
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 0.0206 - psnr: 16.8652 - ssim_metric: 0.6251
# Epoch 30: val_loss improved from 0.02093 to 0.02081, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 732ms/step - loss: 0.0206 - psnr: 16.8639 - ssim_metric: 0.6251 - val_loss: 0.0208 - val_psnr: 16.8286 - val_ssim_metric: 0.6208
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - loss: 0.0208 - psnr: 16.8329 - ssim_metric: 0.6246
# Epoch 31: val_loss improved from 0.02081 to 0.02073, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 911ms/step - loss: 0.0208 - psnr: 16.8334 - ssim_metric: 0.6246 - val_loss: 0.0207 - val_psnr: 16.8453 - val_ssim_metric: 0.6219
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - loss: 0.0209 - psnr: 16.8114 - ssim_metric: 0.6239
# Epoch 32: val_loss improved from 0.02073 to 0.02060, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 723ms/step - loss: 0.0209 - psnr: 16.8130 - ssim_metric: 0.6240 - val_loss: 0.0206 - val_psnr: 16.8740 - val_ssim_metric: 0.6236
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - loss: 0.0204 - psnr: 16.9258 - ssim_metric: 0.6311
# Epoch 33: val_loss improved from 0.02060 to 0.02057, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 47s 905ms/step - loss: 0.0204 - psnr: 16.9248 - ssim_metric: 0.6310 - val_loss: 0.0206 - val_psnr: 16.8799 - val_ssim_metric: 0.6228
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0206 - psnr: 16.8718 - ssim_metric: 0.6277
# Epoch 34: val_loss did not improve from 0.02057
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 699ms/step - loss: 0.0206 - psnr: 16.8728 - ssim_metric: 0.6277 - val_loss: 0.0211 - val_psnr: 16.7764 - val_ssim_metric: 0.6254
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - loss: 0.0206 - psnr: 16.8691 - ssim_metric: 0.6259
# Epoch 35: val_loss improved from 0.02057 to 0.02030, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 743ms/step - loss: 0.0206 - psnr: 16.8705 - ssim_metric: 0.6260 - val_loss: 0.0203 - val_psnr: 16.9382 - val_ssim_metric: 0.6274
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 0.0203 - psnr: 16.9378 - ssim_metric: 0.6334
# Epoch 36: val_loss improved from 0.02030 to 0.02021, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 730ms/step - loss: 0.0203 - psnr: 16.9384 - ssim_metric: 0.6333 - val_loss: 0.0202 - val_psnr: 16.9575 - val_ssim_metric: 0.6268
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - loss: 0.0198 - psnr: 17.0390 - ssim_metric: 0.6326
# Epoch 37: val_loss improved from 0.02021 to 0.02006, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 902ms/step - loss: 0.0198 - psnr: 17.0371 - ssim_metric: 0.6326 - val_loss: 0.0201 - val_psnr: 16.9889 - val_ssim_metric: 0.6287
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0209 - psnr: 16.8185 - ssim_metric: 0.6295
# Epoch 38: val_loss improved from 0.02006 to 0.01997, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 894ms/step - loss: 0.0208 - psnr: 16.8243 - ssim_metric: 0.6296 - val_loss: 0.0200 - val_psnr: 17.0094 - val_ssim_metric: 0.6295
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 547ms/step - loss: 0.0198 - psnr: 17.0455 - ssim_metric: 0.6331
# Epoch 39: val_loss improved from 0.01997 to 0.01995, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 909ms/step - loss: 0.0198 - psnr: 17.0445 - ssim_metric: 0.6331 - val_loss: 0.0200 - val_psnr: 17.0121 - val_ssim_metric: 0.6310
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - loss: 0.0201 - psnr: 16.9779 - ssim_metric: 0.6355
# Epoch 40: val_loss improved from 0.01995 to 0.01979, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 726ms/step - loss: 0.0201 - psnr: 16.9799 - ssim_metric: 0.6354 - val_loss: 0.0198 - val_psnr: 17.0478 - val_ssim_metric: 0.6304
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 550ms/step - loss: 0.0200 - psnr: 17.0112 - ssim_metric: 0.6363
# Epoch 41: val_loss improved from 0.01979 to 0.01975, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 748ms/step - loss: 0.0200 - psnr: 17.0126 - ssim_metric: 0.6363 - val_loss: 0.0197 - val_psnr: 17.0571 - val_ssim_metric: 0.6324
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - loss: 0.0194 - psnr: 17.1354 - ssim_metric: 0.6367
# Epoch 42: val_loss did not improve from 0.01975
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 39s 696ms/step - loss: 0.0194 - psnr: 17.1334 - ssim_metric: 0.6366 - val_loss: 0.0200 - val_psnr: 16.9938 - val_ssim_metric: 0.6285
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - loss: 0.0198 - psnr: 17.0474 - ssim_metric: 0.6376
# Epoch 43: val_loss improved from 0.01975 to 0.01959, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 48s 908ms/step - loss: 0.0198 - psnr: 17.0485 - ssim_metric: 0.6375 - val_loss: 0.0196 - val_psnr: 17.0936 - val_ssim_metric: 0.6321
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - loss: 0.0195 - psnr: 17.1057 - ssim_metric: 0.6391
# Epoch 44: val_loss improved from 0.01959 to 0.01950, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 728ms/step - loss: 0.0195 - psnr: 17.1058 - ssim_metric: 0.6390 - val_loss: 0.0195 - val_psnr: 17.1121 - val_ssim_metric: 0.6331
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - loss: 0.0193 - psnr: 17.1526 - ssim_metric: 0.6383
# Epoch 45: val_loss improved from 0.01950 to 0.01941, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 47s 915ms/step - loss: 0.0193 - psnr: 17.1519 - ssim_metric: 0.6382 - val_loss: 0.0194 - val_psnr: 17.1321 - val_ssim_metric: 0.6343
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0192 - psnr: 17.1827 - ssim_metric: 0.6370
# Epoch 46: val_loss improved from 0.01941 to 0.01941, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 894ms/step - loss: 0.0192 - psnr: 17.1815 - ssim_metric: 0.6370 - val_loss: 0.0194 - val_psnr: 17.1329 - val_ssim_metric: 0.6345
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - loss: 0.0190 - psnr: 17.2244 - ssim_metric: 0.6376
# Epoch 47: val_loss improved from 0.01941 to 0.01931, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 905ms/step - loss: 0.0190 - psnr: 17.2224 - ssim_metric: 0.6376 - val_loss: 0.0193 - val_psnr: 17.1557 - val_ssim_metric: 0.6359
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0195 - psnr: 17.1042 - ssim_metric: 0.6381
# Epoch 48: val_loss did not improve from 0.01931
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 864ms/step - loss: 0.0195 - psnr: 17.1059 - ssim_metric: 0.6381 - val_loss: 0.0197 - val_psnr: 17.0647 - val_ssim_metric: 0.6307
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 548ms/step - loss: 0.0194 - psnr: 17.1334 - ssim_metric: 0.6418
# Epoch 49: val_loss improved from 0.01931 to 0.01920, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 26s 823ms/step - loss: 0.0194 - psnr: 17.1342 - ssim_metric: 0.6417 - val_loss: 0.0192 - val_psnr: 17.1806 - val_ssim_metric: 0.6366
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0192 - psnr: 17.1692 - ssim_metric: 0.6354
# Epoch 50: val_loss improved from 0.01920 to 0.01912, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 726ms/step - loss: 0.0192 - psnr: 17.1704 - ssim_metric: 0.6356 - val_loss: 0.0191 - val_psnr: 17.1980 - val_ssim_metric: 0.6363
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - loss: 0.0187 - psnr: 17.2908 - ssim_metric: 0.6403
# Epoch 51: val_loss did not improve from 0.01912
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 698ms/step - loss: 0.0187 - psnr: 17.2888 - ssim_metric: 0.6403 - val_loss: 0.0191 - val_psnr: 17.1957 - val_ssim_metric: 0.6378
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - loss: 0.0193 - psnr: 17.1530 - ssim_metric: 0.6378
# Epoch 52: val_loss improved from 0.01912 to 0.01906, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 47s 903ms/step - loss: 0.0193 - psnr: 17.1554 - ssim_metric: 0.6380 - val_loss: 0.0191 - val_psnr: 17.2121 - val_ssim_metric: 0.6387
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - loss: 0.0187 - psnr: 17.2902 - ssim_metric: 0.6433
# Epoch 53: val_loss improved from 0.01906 to 0.01899, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 730ms/step - loss: 0.0187 - psnr: 17.2889 - ssim_metric: 0.6432 - val_loss: 0.0190 - val_psnr: 17.2286 - val_ssim_metric: 0.6377
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - loss: 0.0191 - psnr: 17.2006 - ssim_metric: 0.6402
# Epoch 54: val_loss improved from 0.01899 to 0.01886, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 729ms/step - loss: 0.0191 - psnr: 17.2026 - ssim_metric: 0.6403 - val_loss: 0.0189 - val_psnr: 17.2587 - val_ssim_metric: 0.6406
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - loss: 0.0189 - psnr: 17.2584 - ssim_metric: 0.6393
# Epoch 55: val_loss did not improve from 0.01886
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 714ms/step - loss: 0.0189 - psnr: 17.2591 - ssim_metric: 0.6394 - val_loss: 0.0189 - val_psnr: 17.2525 - val_ssim_metric: 0.6415
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - loss: 0.0190 - psnr: 17.2201 - ssim_metric: 0.6466
# Epoch 56: val_loss improved from 0.01886 to 0.01875, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 47s 893ms/step - loss: 0.0190 - psnr: 17.2222 - ssim_metric: 0.6465 - val_loss: 0.0187 - val_psnr: 17.2841 - val_ssim_metric: 0.6398
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - loss: 0.0187 - psnr: 17.2950 - ssim_metric: 0.6466
# Epoch 57: val_loss did not improve from 0.01875
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 875ms/step - loss: 0.0187 - psnr: 17.2943 - ssim_metric: 0.6465 - val_loss: 0.0189 - val_psnr: 17.2552 - val_ssim_metric: 0.6392
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0186 - psnr: 17.3084 - ssim_metric: 0.6457
# Epoch 58: val_loss improved from 0.01875 to 0.01865, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 731ms/step - loss: 0.0186 - psnr: 17.3087 - ssim_metric: 0.6457 - val_loss: 0.0187 - val_psnr: 17.3063 - val_ssim_metric: 0.6417
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - loss: 0.0189 - psnr: 17.2670 - ssim_metric: 0.6416
# Epoch 59: val_loss improved from 0.01865 to 0.01855, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 902ms/step - loss: 0.0189 - psnr: 17.2690 - ssim_metric: 0.6417 - val_loss: 0.0185 - val_psnr: 17.3303 - val_ssim_metric: 0.6419
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0189 - psnr: 17.2471 - ssim_metric: 0.6432
# Epoch 60: val_loss improved from 0.01855 to 0.01848, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 895ms/step - loss: 0.0189 - psnr: 17.2505 - ssim_metric: 0.6433 - val_loss: 0.0185 - val_psnr: 17.3465 - val_ssim_metric: 0.6428
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - loss: 0.0184 - psnr: 17.3765 - ssim_metric: 0.6469
# Epoch 61: val_loss did not improve from 0.01848
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 713ms/step - loss: 0.0184 - psnr: 17.3761 - ssim_metric: 0.6469 - val_loss: 0.0185 - val_psnr: 17.3457 - val_ssim_metric: 0.6427
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0183 - psnr: 17.3746 - ssim_metric: 0.6461
# Epoch 62: val_loss did not improve from 0.01848
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 698ms/step - loss: 0.0184 - psnr: 17.3745 - ssim_metric: 0.6461 - val_loss: 0.0188 - val_psnr: 17.2744 - val_ssim_metric: 0.6397
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - loss: 0.0184 - psnr: 17.3493 - ssim_metric: 0.6460
# Epoch 63: val_loss improved from 0.01848 to 0.01845, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 747ms/step - loss: 0.0184 - psnr: 17.3491 - ssim_metric: 0.6460 - val_loss: 0.0184 - val_psnr: 17.3537 - val_ssim_metric: 0.6434
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - loss: 0.0184 - psnr: 17.3740 - ssim_metric: 0.6485
# Epoch 64: val_loss improved from 0.01845 to 0.01831, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 746ms/step - loss: 0.0184 - psnr: 17.3750 - ssim_metric: 0.6485 - val_loss: 0.0183 - val_psnr: 17.3859 - val_ssim_metric: 0.6450
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - loss: 0.0182 - psnr: 17.4125 - ssim_metric: 0.6517
# Epoch 65: val_loss improved from 0.01831 to 0.01822, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 729ms/step - loss: 0.0182 - psnr: 17.4125 - ssim_metric: 0.6516 - val_loss: 0.0182 - val_psnr: 17.4069 - val_ssim_metric: 0.6463
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0180 - psnr: 17.4720 - ssim_metric: 0.6517
# Epoch 66: val_loss improved from 0.01822 to 0.01822, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 729ms/step - loss: 0.0180 - psnr: 17.4705 - ssim_metric: 0.6516 - val_loss: 0.0182 - val_psnr: 17.4070 - val_ssim_metric: 0.6451
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - loss: 0.0181 - psnr: 17.4469 - ssim_metric: 0.6500
# Epoch 67: val_loss improved from 0.01822 to 0.01814, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 738ms/step - loss: 0.0181 - psnr: 17.4468 - ssim_metric: 0.6500 - val_loss: 0.0181 - val_psnr: 17.4268 - val_ssim_metric: 0.6458
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0180 - psnr: 17.4579 - ssim_metric: 0.6507
# Epoch 68: val_loss improved from 0.01814 to 0.01808, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 729ms/step - loss: 0.0180 - psnr: 17.4579 - ssim_metric: 0.6507 - val_loss: 0.0181 - val_psnr: 17.4417 - val_ssim_metric: 0.6467
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - loss: 0.0178 - psnr: 17.5150 - ssim_metric: 0.6510
# Epoch 69: val_loss improved from 0.01808 to 0.01803, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 901ms/step - loss: 0.0178 - psnr: 17.5134 - ssim_metric: 0.6510 - val_loss: 0.0180 - val_psnr: 17.4527 - val_ssim_metric: 0.6479
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0179 - psnr: 17.4738 - ssim_metric: 0.6514
# Epoch 70: val_loss improved from 0.01803 to 0.01802, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 892ms/step - loss: 0.0179 - psnr: 17.4738 - ssim_metric: 0.6514 - val_loss: 0.0180 - val_psnr: 17.4549 - val_ssim_metric: 0.6473
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - loss: 0.0177 - psnr: 17.5493 - ssim_metric: 0.6549
# Epoch 71: val_loss improved from 0.01802 to 0.01796, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 911ms/step - loss: 0.0177 - psnr: 17.5475 - ssim_metric: 0.6548 - val_loss: 0.0180 - val_psnr: 17.4714 - val_ssim_metric: 0.6488
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - loss: 0.0177 - psnr: 17.5233 - ssim_metric: 0.6512
# Epoch 72: val_loss improved from 0.01796 to 0.01795, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 728ms/step - loss: 0.0177 - psnr: 17.5222 - ssim_metric: 0.6512 - val_loss: 0.0179 - val_psnr: 17.4736 - val_ssim_metric: 0.6478
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 547ms/step - loss: 0.0177 - psnr: 17.5300 - ssim_metric: 0.6543
# Epoch 73: val_loss improved from 0.01795 to 0.01787, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 47s 935ms/step - loss: 0.0177 - psnr: 17.5291 - ssim_metric: 0.6543 - val_loss: 0.0179 - val_psnr: 17.4913 - val_ssim_metric: 0.6492
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0178 - psnr: 17.5021 - ssim_metric: 0.6519
# Epoch 74: val_loss improved from 0.01787 to 0.01782, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 733ms/step - loss: 0.0178 - psnr: 17.5025 - ssim_metric: 0.6520 - val_loss: 0.0178 - val_psnr: 17.5044 - val_ssim_metric: 0.6496
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - loss: 0.0178 - psnr: 17.5210 - ssim_metric: 0.6515
# Epoch 75: val_loss improved from 0.01782 to 0.01779, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 747ms/step - loss: 0.0178 - psnr: 17.5215 - ssim_metric: 0.6515 - val_loss: 0.0178 - val_psnr: 17.5112 - val_ssim_metric: 0.6509
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - loss: 0.0174 - psnr: 17.5978 - ssim_metric: 0.6566
# Epoch 76: val_loss improved from 0.01779 to 0.01775, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 743ms/step - loss: 0.0174 - psnr: 17.5957 - ssim_metric: 0.6565 - val_loss: 0.0177 - val_psnr: 17.5219 - val_ssim_metric: 0.6512
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - loss: 0.0173 - psnr: 17.6279 - ssim_metric: 0.6548
# Epoch 77: val_loss improved from 0.01775 to 0.01771, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 726ms/step - loss: 0.0173 - psnr: 17.6252 - ssim_metric: 0.6548 - val_loss: 0.0177 - val_psnr: 17.5313 - val_ssim_metric: 0.6523
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 547ms/step - loss: 0.0174 - psnr: 17.6100 - ssim_metric: 0.6562
# Epoch 78: val_loss improved from 0.01771 to 0.01764, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 48s 962ms/step - loss: 0.0174 - psnr: 17.6084 - ssim_metric: 0.6562 - val_loss: 0.0176 - val_psnr: 17.5487 - val_ssim_metric: 0.6518
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 0.0176 - psnr: 17.5556 - ssim_metric: 0.6531
# Epoch 79: val_loss improved from 0.01764 to 0.01762, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 905ms/step - loss: 0.0176 - psnr: 17.5561 - ssim_metric: 0.6531 - val_loss: 0.0176 - val_psnr: 17.5546 - val_ssim_metric: 0.6522
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0175 - psnr: 17.5852 - ssim_metric: 0.6552
# Epoch 80: val_loss did not improve from 0.01762
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 701ms/step - loss: 0.0175 - psnr: 17.5853 - ssim_metric: 0.6552 - val_loss: 0.0177 - val_psnr: 17.5379 - val_ssim_metric: 0.6516
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - loss: 0.0175 - psnr: 17.5701 - ssim_metric: 0.6577
# Epoch 81: val_loss did not improve from 0.01762
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 869ms/step - loss: 0.0175 - psnr: 17.5707 - ssim_metric: 0.6577 - val_loss: 0.0179 - val_psnr: 17.4742 - val_ssim_metric: 0.6542
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 0.0180 - psnr: 17.4692 - ssim_metric: 0.6533
# Epoch 82: val_loss improved from 0.01762 to 0.01751, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 38s 762ms/step - loss: 0.0180 - psnr: 17.4722 - ssim_metric: 0.6534 - val_loss: 0.0175 - val_psnr: 17.5815 - val_ssim_metric: 0.6546
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 0.0173 - psnr: 17.6210 - ssim_metric: 0.6558
# Epoch 83: val_loss did not improve from 0.01751
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 44s 868ms/step - loss: 0.0173 - psnr: 17.6206 - ssim_metric: 0.6559 - val_loss: 0.0176 - val_psnr: 17.5564 - val_ssim_metric: 0.6549
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 0.0174 - psnr: 17.6068 - ssim_metric: 0.6594
# Epoch 84: val_loss improved from 0.01751 to 0.01741, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 847ms/step - loss: 0.0174 - psnr: 17.6071 - ssim_metric: 0.6594 - val_loss: 0.0174 - val_psnr: 17.6064 - val_ssim_metric: 0.6543
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - loss: 0.0174 - psnr: 17.6082 - ssim_metric: 0.6564
# Epoch 85: val_loss did not improve from 0.01741
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 22s 704ms/step - loss: 0.0174 - psnr: 17.6087 - ssim_metric: 0.6565 - val_loss: 0.0174 - val_psnr: 17.6025 - val_ssim_metric: 0.6536
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - loss: 0.0173 - psnr: 17.6338 - ssim_metric: 0.6596
# Epoch 86: val_loss improved from 0.01741 to 0.01733, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 743ms/step - loss: 0.0173 - psnr: 17.6338 - ssim_metric: 0.6596 - val_loss: 0.0173 - val_psnr: 17.6256 - val_ssim_metric: 0.6551
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - loss: 0.0173 - psnr: 17.6248 - ssim_metric: 0.6595
# Epoch 87: val_loss improved from 0.01733 to 0.01733, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 45s 859ms/step - loss: 0.0173 - psnr: 17.6254 - ssim_metric: 0.6595 - val_loss: 0.0173 - val_psnr: 17.6258 - val_ssim_metric: 0.6549
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0173 - psnr: 17.6415 - ssim_metric: 0.6615
# Epoch 88: val_loss improved from 0.01733 to 0.01725, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 37s 734ms/step - loss: 0.0173 - psnr: 17.6419 - ssim_metric: 0.6614 - val_loss: 0.0173 - val_psnr: 17.6457 - val_ssim_metric: 0.6570
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - loss: 0.0172 - psnr: 17.6551 - ssim_metric: 0.6593
# Epoch 89: val_loss did not improve from 0.01725
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 45s 875ms/step - loss: 0.0172 - psnr: 17.6556 - ssim_metric: 0.6593 - val_loss: 0.0173 - val_psnr: 17.6385 - val_ssim_metric: 0.6575
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0172 - psnr: 17.6579 - ssim_metric: 0.6623
# Epoch 90: val_loss improved from 0.01725 to 0.01720, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 897ms/step - loss: 0.0172 - psnr: 17.6587 - ssim_metric: 0.6623 - val_loss: 0.0172 - val_psnr: 17.6600 - val_ssim_metric: 0.6570
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - loss: 0.0171 - psnr: 17.6809 - ssim_metric: 0.6574
# Epoch 91: val_loss improved from 0.01720 to 0.01713, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 747ms/step - loss: 0.0171 - psnr: 17.6811 - ssim_metric: 0.6575 - val_loss: 0.0171 - val_psnr: 17.6759 - val_ssim_metric: 0.6574
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - loss: 0.0166 - psnr: 17.8215 - ssim_metric: 0.6653
# Epoch 92: val_loss did not improve from 0.01713
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 710ms/step - loss: 0.0166 - psnr: 17.8179 - ssim_metric: 0.6652 - val_loss: 0.0172 - val_psnr: 17.6641 - val_ssim_metric: 0.6563
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - loss: 0.0169 - psnr: 17.7533 - ssim_metric: 0.6623
# Epoch 93: val_loss improved from 0.01713 to 0.01706, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 727ms/step - loss: 0.0169 - psnr: 17.7515 - ssim_metric: 0.6623 - val_loss: 0.0171 - val_psnr: 17.6932 - val_ssim_metric: 0.6584
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - loss: 0.0168 - psnr: 17.7579 - ssim_metric: 0.6668
# Epoch 94: val_loss improved from 0.01706 to 0.01702, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 903ms/step - loss: 0.0168 - psnr: 17.7569 - ssim_metric: 0.6667 - val_loss: 0.0170 - val_psnr: 17.7036 - val_ssim_metric: 0.6593
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0171 - psnr: 17.6849 - ssim_metric: 0.6618
# Epoch 95: val_loss improved from 0.01702 to 0.01699, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 740ms/step - loss: 0.0171 - psnr: 17.6864 - ssim_metric: 0.6619 - val_loss: 0.0170 - val_psnr: 17.7132 - val_ssim_metric: 0.6594
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - loss: 0.0166 - psnr: 17.8166 - ssim_metric: 0.6621
# Epoch 96: val_loss did not improve from 0.01699
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 45s 872ms/step - loss: 0.0166 - psnr: 17.8143 - ssim_metric: 0.6621 - val_loss: 0.0171 - val_psnr: 17.6764 - val_ssim_metric: 0.6602
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 0.0167 - psnr: 17.7886 - ssim_metric: 0.6624
# Epoch 97: val_loss improved from 0.01699 to 0.01694, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 37s 736ms/step - loss: 0.0167 - psnr: 17.7868 - ssim_metric: 0.6624 - val_loss: 0.0169 - val_psnr: 17.7244 - val_ssim_metric: 0.6600
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 550ms/step - loss: 0.0171 - psnr: 17.6878 - ssim_metric: 0.6611
# Epoch 98: val_loss did not improve from 0.01694
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 28s 882ms/step - loss: 0.0171 - psnr: 17.6889 - ssim_metric: 0.6612 - val_loss: 0.0171 - val_psnr: 17.6870 - val_ssim_metric: 0.6583
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - loss: 0.0168 - psnr: 17.7675 - ssim_metric: 0.6659
# Epoch 99: val_loss improved from 0.01694 to 0.01688, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 728ms/step - loss: 0.0168 - psnr: 17.7673 - ssim_metric: 0.6658 - val_loss: 0.0169 - val_psnr: 17.7413 - val_ssim_metric: 0.6614
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 547ms/step - loss: 0.0170 - psnr: 17.7187 - ssim_metric: 0.6664
# Epoch 100: val_loss improved from 0.01688 to 0.01685, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 28s 901ms/step - loss: 0.0170 - psnr: 17.7203 - ssim_metric: 0.6663 - val_loss: 0.0168 - val_psnr: 17.7494 - val_ssim_metric: 0.6625
#
# 🚀 Training Completed in 63 min 6 sec
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 13s 269ms/step
# Training and visualization complete.
