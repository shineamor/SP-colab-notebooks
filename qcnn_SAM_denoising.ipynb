# %% [markdown]
# <a href="https://colab.research.google.com/github/shineamor/SP-colab-notebooks/blob/main/qcnn_SAM_denoising.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (1.26.4)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (1.14.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (11.1.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2025.2.18)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (0.4)

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !find /content/drive/MyDrive -type d -name "quaternion_layers"
# Out:
# /content/drive/MyDrive/quaternion_layers

# %%
import sys
sys.path.append('/content/drive/MyDrive')

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.1.31)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.3.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.11/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle) (3.10)

# %%
pip install tensorflow-datasets
# Out:
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.11/dist-packages (4.9.8)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.4.0)
# Requirement already satisfied: array_record>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.7.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.1.9)
# Requirement already satisfied: etils>=1.9.1 in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (1.12.2)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (4.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.26.4)
# Requirement already satisfied: promise in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (4.25.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (18.1.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (2.32.3)
# Requirement already satisfied: simple_parsing in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.1.7)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.16.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (2.5.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.10.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (4.67.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.17.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (0.8.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (6.5.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (4.12.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow-datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow-datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow-datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow-datasets) (2025.1.31)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.11/dist-packages (from dm-tree->tensorflow-datasets) (25.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from promise->tensorflow-datasets) (1.17.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.11/dist-packages (from simple_parsing->tensorflow-datasets) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /usr/local/lib/python3.11/dist-packages (from tensorflow-metadata->tensorflow-datasets) (1.69.1)

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import numpy as np
import PIL, os, random, skimage.util, csv
import tensorflow.keras.backend as K
from google.colab import files
from quaternion_layers import QConv2D, QDense
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, AveragePooling2D, UpSampling2D, Reshape, Flatten, Input, Add, Multiply, GlobalAveragePooling2D, GlobalMaxPooling2D, Concatenate, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import time

#Load Oxford Flowers dataset
dataset, info = tfds.load(
    "oxford_flowers102",
    with_info=True,
    as_supervised=True
)
print(info.splits)

#Function to covert TF Dataset to NumPy arrays
def ds_to_numpy(dataset):
    images, labels = [], []
    for img, lbl in dataset:
        images.append(img.numpy())
        labels.append(lbl.numpy())
    return np.array(images), np.array(labels)

#Preprocessing function: Resize & Normalize images
def preprocess(image, label):
    image = tf.image.resize(image, [128, 128]) # Resize to 128×128
    image = tf.cast(image, tf.float32) / 255.0 # Normalize [0,1]
    image = (image * 2.0) - 1.0  # Convert to [-1,1]
    return image, label

# Function to add noise to images (Salt & Pepper, Gaussian)
def add_noise(images, noise_factor=0.2, salt_pepper_amount=0.1):
    noisy_images = []
    for img in images:
        # Add salt & pepper noise
        img_sp = skimage.util.random_noise(img, mode='s&p', amount=salt_pepper_amount)

        # Add Gaussian noise
        img_noisy = img_sp + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=img.shape)
        img_noisy = np.clip(img_noisy, -1.0, 1.0)  # Ensure values are in the valid range [-1, 1]

        noisy_images.append(img_noisy)

    return np.array(noisy_images)

def PSNR(y_true, y_pred):
    max_pixel = 1.0  # Since images are normalized to [-1,1]
    return 10.0 * K.log((max_pixel ** 2) / (K.mean(K.square(y_pred - y_true)))) / K.log(10.0)

def ssim_metric(y_true, y_pred):
    return tf.reduce_mean(tf.image.ssim(y_true, y_pred, max_val=2.0))

# Define the Spatial Attention Module (SAM)
def spatial_attention(input_feature):
    avg_pool = Lambda(lambda x: tf.reduce_mean(x, axis=-1, keepdims=True))(input_feature)
    max_pool = Lambda(lambda x: tf.reduce_max(x, axis=-1, keepdims=True))(input_feature)
    concat = Concatenate(axis=-1)([avg_pool, max_pool])
    attention = Conv2D(1, kernel_size=7, padding='same', activation='sigmoid')(concat)
    return Multiply()([input_feature, attention])

# Load dataset splits
splits, info = tfds.load(
    'oxford_flowers102',
    split=['train','test','validation'],
    as_supervised=True,
    with_info=True
)
train_ds, test_ds, val_ds = splits

# Apply preprocessing to dataset
train_ds = train_ds.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
test_ds  = test_ds.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
val_ds   = val_ds.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)

# Convert dataset to NumPy arrays
(x_train, _), (x_valid, _), (x_test, _) = (
    ds_to_numpy(train_ds),
    ds_to_numpy(val_ds),
    ds_to_numpy(test_ds)
)

# Convert each split to NumPy
(x_train, y_train) = ds_to_numpy(train_ds)
(x_test, y_test)   = ds_to_numpy(test_ds)
(x_valid, y_valid) = ds_to_numpy(val_ds)

print("Train shape:", x_train.shape)
print("Valid shape:", x_valid.shape)
print("Test shape: ", x_test.shape)

# Model Configuration
encoding_size = 90
perturbation_max = 40
image_shape = (128,128,3)

# Define Model Architecture
model_input = Input(shape=image_shape)

# Encoder
conv1 = QConv2D(23, 3, padding='same', activation='relu')(model_input)
print("conv1 shape:", conv1.shape)
conv1 = spatial_attention(conv1)  # Apply SAM here
print("after SAM conv1 shape:", conv1.shape)
conv2 = QConv2D(23, 3, padding='same', activation='relu')(conv1)
print("conv2 shape:", conv2.shape)
pool1 = AveragePooling2D(2, 2)(conv2)
print("pool1 shape:", pool1.shape)
conv3 = QConv2D(45, 3, padding='same', activation='relu')(pool1)
print("conv3 shape:", conv3.shape)
conv3 = spatial_attention(conv3)  # Apply SAM here
print("SAM conv3 shape:", conv3.shape)
conv4 = QConv2D(45, 3, padding='same', activation='relu')(conv3)
print("conv4 shape:", conv4.shape)
pool2 = AveragePooling2D(2, 2)(conv4)
print("pool2 shape:", pool2.shape)
conv5 = QConv2D(90, 3, padding='same', activation='relu')(pool2)
print("conv5 shape:", conv5.shape)
conv5 = spatial_attention(conv5)  # Apply SAM here
print("SAM conv5 shape:", conv5.shape)
conv6 = QConv2D(90, 3, padding='same', activation='relu')(conv5)
print("conv6 shape:", conv6.shape)

# Decoder
flatten = Flatten()(conv6)
print("flatten shape:", flatten.shape)
encoding = QDense(encoding_size, activation='relu')(flatten)
print("encoding shape:", encoding.shape)
dense2 = QDense(192, activation='relu')(encoding)
print("dense2 shape:", dense2.shape)
reshape = Reshape((8, 8, 9))(dense2)
print("reshape shape:", reshape.shape)
upsample2 = UpSampling2D(size=(4, 4))(reshape)
print("upsample2 shape:", upsample2.shape)
conv11 = QConv2D(90, 3, padding='same', activation='relu')(upsample2)
print("conv11 shape:", conv11.shape)
conv12 = QConv2D(90, 3, padding='same', activation='relu')(conv11)
print("conv12 shape:", conv12.shape)
add1 = Add()([conv12, conv6])
print("add1 shape:", add1.shape)
upsample3 = UpSampling2D(size=(4, 4))(add1)
print("upsample3 shape:", upsample3.shape)
conv13 = QConv2D(45, 3, padding='same', activation='relu')(upsample3)
print("conv13 shape:", conv13.shape)
conv13 = spatial_attention(conv13)  # Apply SAM here
print("conv13 shape:", conv13.shape)
conv14 = QConv2D(45, 3, padding='same', activation='relu')(conv13)
print("conv14 shape:", conv14.shape)
upsample_conv4 = UpSampling2D(size=(2, 2))(conv4)
print("upsample_conv4 shape:", upsample_conv4.shape)
add2 = Add()([conv14, upsample_conv4])
print("add2 shape:", add2.shape)
upsample3 = UpSampling2D(size=(4, 4))(add2)
conv15 = QConv2D(8, 3, padding='same', activation='relu')(add2)
print("conv15 shape:", conv15.shape)
conv16 = QConv2D(1, 3, padding='same', activation='tanh')(conv15)
print("conv16 shape:", conv16.shape)

autoencoder = Model(model_input, conv16)
autoencoder.compile(loss='mse', optimizer=Adam(1e-4), metrics=[PSNR, ssim_metric])

# Ensure checkpoint directory exists
checkpoint_dir = 'checkpoint_oxford_flowers'
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

# Define callbacks
checkpoint = ModelCheckpoint('checkpoint_oxford_flowers/best_weights.keras', monitor='val_loss', save_best_only=True, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=20, verbose=1)

# Generate noisy data
x_train_noisy = add_noise(x_train)
x_valid_noisy = add_noise(x_valid)

# Start runtime tracking
start_time = time.time()

#start training
epochs = 100
batch_size = 32
history = autoencoder.fit(
    x_train_noisy, x_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_valid_noisy, x_valid),
    callbacks=[checkpoint, early_stop]
)

# Stop runtime tracking
elapsed_time = time.time() - start_time
print(f"\n🚀 Training Completed in {int(elapsed_time // 60)} min {int(elapsed_time % 60)} sec")

history_dict = history.history
num_epochs = len(history_dict['loss'])

csv_filename = f"qcnn-SAM_comparison_plot_{epochs}_epochs.csv"
with open(csv_filename, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["epoch","loss","val_loss","psnr","val_psnr","ssim_metric","val_ssim_metric"])
     # One row per epoch
    for epoch_idx in range(num_epochs):
        row = [
            epoch_idx + 1,
            history_dict['loss'][epoch_idx],
            history_dict['val_loss'][epoch_idx],
            history_dict['psnr'][epoch_idx],
            history_dict['val_psnr'][epoch_idx],
            history_dict['ssim_metric'][epoch_idx],
            history_dict['val_ssim_metric'][epoch_idx]
        ]
        writer.writerow(row)

# Download CSV in Colab
files.download(csv_filename)

# Denoise the images using the autoencoder
denoised_images = autoencoder.predict(x_valid_noisy)

plot_filename_loss = f"qcnn-SAM_loss_plot_{epochs}_epochs.png"
plot_filename_psnr = f"qcnn-SAM_psnr_plot_{epochs}_epochs.png"
plot_filename_ssim = f"qcnn-SAM_ssim_plot_{epochs}_epochs.png"
plot_filename_comparison = f"qcnn-SAM_comparison_plot_{epochs}_epochs.png"

# Plot training & validation loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig(plot_filename_loss)
plt.show()

# Plot PSNR
plt.figure()
plt.plot(history.history['psnr'], label='Train PSNR')
plt.plot(history.history['val_psnr'], label='Val PSNR')
plt.title('Model PSNR')
plt.xlabel('Epochs')
plt.ylabel('PSNR (dB)')
plt.legend()
plt.savefig(plot_filename_psnr)
plt.show()

#Plot SSIM
plt.figure()
plt.plot(history.history['ssim_metric'], label='Train SSIM')
plt.plot(history.history['val_ssim_metric'], label='Val SSIM')
plt.title('Model SSIM')
plt.xlabel('Epochs')
plt.ylabel('SSIM')
plt.legend()
plt.savefig(plot_filename_ssim)
plt.show()

files.download(plot_filename_loss)
files.download(plot_filename_psnr)
files.download(plot_filename_ssim)

def deprocess(x):
    x = (x + 1.0) * 127.5
    return np.clip(x, 0, 255).astype(np.uint8)

def display_images(original, noisy, denoised, n=5):
    plt.figure(figsize=(20, 6))
    for i in range(n):
        # Original
        ax = plt.subplot(3, n, i+1)
        plt.imshow(deprocess(original[i]))
        plt.title("Original")
        plt.axis("off")

        # Noisy
        ax = plt.subplot(3, n, i+1+n)
        plt.imshow(deprocess(noisy[i]))
        plt.title("Noisy")
        plt.axis("off")

        # Denoised
        ax = plt.subplot(3, n, i+1+2*n)
        plt.imshow(deprocess(denoised[i]))
        plt.title("Denoised")
        plt.axis("off")
    plt.savefig(plot_filename_comparison)
    plt.show()
    files.download(plot_filename_comparison)

# Visualize the first 5 original, noisy, and denoised images
display_images(x_valid, x_valid_noisy, denoised_images, n=5)

print("Training and visualization complete.")
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/oxford_flowers102/2.1.1 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/oxford_flowers102/2.1.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/3 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_flowers102/incomplete.ZFRH1B_2.1.1/oxford_flowers102-train.tfrecord…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_flowers102/incomplete.ZFRH1B_2.1.1/oxford_flowers102-test.tfrecord*…
# Generating validation examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_flowers102/incomplete.ZFRH1B_2.1.1/oxford_flowers102-validation.tfr…
# Dataset oxford_flowers102 downloaded and prepared to /root/tensorflow_datasets/oxford_flowers102/2.1.1. Subsequent calls will reuse this data.
# {Split('train'): <SplitInfo num_examples=1020, num_shards=1>, Split('test'): <SplitInfo num_examples=6149, num_shards=2>, Split('validation'): <SplitInfo num_examples=1020, num_shards=1>}
# Train shape: (1020, 128, 128, 3)
# Valid shape: (1020, 128, 128, 3)
# Test shape:  (6149, 128, 128, 3)
# conv1 shape: (None, 128, 128, 69)
# after SAM conv1 shape: (None, 128, 128, 69)
# conv2 shape: (None, 128, 128, 69)
# pool1 shape: (None, 64, 64, 69)
# conv3 shape: (None, 64, 64, 135)
# SAM conv3 shape: (None, 64, 64, 135)
# conv4 shape: (None, 64, 64, 135)
# pool2 shape: (None, 32, 32, 135)
# conv5 shape: (None, 32, 32, 270)
# SAM conv5 shape: (None, 32, 32, 270)
# conv6 shape: (None, 32, 32, 270)
# flatten shape: (None, 276480)
# encoding shape: (None, 270)
# dense2 shape: (None, 576)
# reshape shape: (None, 8, 8, 9)
# upsample2 shape: (None, 32, 32, 9)
# conv11 shape: (None, 32, 32, 270)
# conv12 shape: (None, 32, 32, 270)
# add1 shape: (None, 32, 32, 270)
# upsample3 shape: (None, 128, 128, 270)
# conv13 shape: (None, 128, 128, 135)
# conv13 shape: (None, 128, 128, 135)
# conv14 shape: (None, 128, 128, 135)
# upsample_conv4 shape: (None, 128, 128, 135)
# add2 shape: (None, 128, 128, 135)
# conv15 shape: (None, 128, 128, 24)
# conv16 shape: (None, 128, 128, 3)
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.3573 - psnr: 4.4839 - ssim_metric: 0.0207
# Epoch 1: val_loss improved from inf to 0.23107, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 165s 3s/step - loss: 0.3565 - psnr: 4.4945 - ssim_metric: 0.0216 - val_loss: 0.2311 - val_psnr: 6.3713 - val_ssim_metric: 0.1333
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - loss: 0.1778 - psnr: 7.7333 - ssim_metric: 0.2100
# Epoch 2: val_loss improved from 0.23107 to 0.06273, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 77s 887ms/step - loss: 0.1764 - psnr: 7.7809 - ssim_metric: 0.2122 - val_loss: 0.0627 - val_psnr: 12.0329 - val_ssim_metric: 0.4050
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 528ms/step - loss: 0.0549 - psnr: 12.6144 - ssim_metric: 0.4293
# Epoch 3: val_loss improved from 0.06273 to 0.04514, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 724ms/step - loss: 0.0549 - psnr: 12.6213 - ssim_metric: 0.4297 - val_loss: 0.0451 - val_psnr: 13.4624 - val_ssim_metric: 0.4714
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 0.0439 - psnr: 13.5863 - ssim_metric: 0.4846
# Epoch 4: val_loss improved from 0.04514 to 0.03755, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 733ms/step - loss: 0.0439 - psnr: 13.5930 - ssim_metric: 0.4850 - val_loss: 0.0376 - val_psnr: 14.2632 - val_ssim_metric: 0.5193
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - loss: 0.0369 - psnr: 14.3452 - ssim_metric: 0.5292
# Epoch 5: val_loss improved from 0.03755 to 0.03277, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 729ms/step - loss: 0.0368 - psnr: 14.3513 - ssim_metric: 0.5295 - val_loss: 0.0328 - val_psnr: 14.8561 - val_ssim_metric: 0.5505
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 0.0330 - psnr: 14.8165 - ssim_metric: 0.5540
# Epoch 6: val_loss improved from 0.03277 to 0.03059, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 737ms/step - loss: 0.0330 - psnr: 14.8215 - ssim_metric: 0.5541 - val_loss: 0.0306 - val_psnr: 15.1557 - val_ssim_metric: 0.5633
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - loss: 0.0301 - psnr: 15.2197 - ssim_metric: 0.5674
# Epoch 7: val_loss improved from 0.03059 to 0.02914, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 745ms/step - loss: 0.0301 - psnr: 15.2203 - ssim_metric: 0.5675 - val_loss: 0.0291 - val_psnr: 15.3656 - val_ssim_metric: 0.5721
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - loss: 0.0291 - psnr: 15.3760 - ssim_metric: 0.5745
# Epoch 8: val_loss improved from 0.02914 to 0.02803, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 899ms/step - loss: 0.0291 - psnr: 15.3774 - ssim_metric: 0.5746 - val_loss: 0.0280 - val_psnr: 15.5351 - val_ssim_metric: 0.5791
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 0.0276 - psnr: 15.6047 - ssim_metric: 0.5832
# Epoch 9: val_loss improved from 0.02803 to 0.02702, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 902ms/step - loss: 0.0276 - psnr: 15.6047 - ssim_metric: 0.5832 - val_loss: 0.0270 - val_psnr: 15.6941 - val_ssim_metric: 0.5826
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - loss: 0.0263 - psnr: 15.8177 - ssim_metric: 0.5876
# Epoch 10: val_loss improved from 0.02702 to 0.02656, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 900ms/step - loss: 0.0263 - psnr: 15.8156 - ssim_metric: 0.5876 - val_loss: 0.0266 - val_psnr: 15.7688 - val_ssim_metric: 0.5838
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0260 - psnr: 15.8590 - ssim_metric: 0.5916
# Epoch 11: val_loss improved from 0.02656 to 0.02552, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 897ms/step - loss: 0.0260 - psnr: 15.8591 - ssim_metric: 0.5916 - val_loss: 0.0255 - val_psnr: 15.9436 - val_ssim_metric: 0.5914
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0254 - psnr: 15.9664 - ssim_metric: 0.5932
# Epoch 12: val_loss improved from 0.02552 to 0.02521, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 734ms/step - loss: 0.0254 - psnr: 15.9665 - ssim_metric: 0.5932 - val_loss: 0.0252 - val_psnr: 15.9953 - val_ssim_metric: 0.5911
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 0.0250 - psnr: 16.0282 - ssim_metric: 0.5966
# Epoch 13: val_loss improved from 0.02521 to 0.02463, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 895ms/step - loss: 0.0250 - psnr: 16.0291 - ssim_metric: 0.5966 - val_loss: 0.0246 - val_psnr: 16.0963 - val_ssim_metric: 0.5952
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 0.0242 - psnr: 16.1799 - ssim_metric: 0.6000
# Epoch 14: val_loss improved from 0.02463 to 0.02428, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 896ms/step - loss: 0.0242 - psnr: 16.1789 - ssim_metric: 0.6000 - val_loss: 0.0243 - val_psnr: 16.1597 - val_ssim_metric: 0.5992
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0243 - psnr: 16.1481 - ssim_metric: 0.5988
# Epoch 15: val_loss improved from 0.02428 to 0.02371, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 896ms/step - loss: 0.0243 - psnr: 16.1500 - ssim_metric: 0.5989 - val_loss: 0.0237 - val_psnr: 16.2624 - val_ssim_metric: 0.6013
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 0.0233 - psnr: 16.3346 - ssim_metric: 0.6067
# Epoch 16: val_loss improved from 0.02371 to 0.02338, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 902ms/step - loss: 0.0233 - psnr: 16.3335 - ssim_metric: 0.6067 - val_loss: 0.0234 - val_psnr: 16.3230 - val_ssim_metric: 0.6026
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 0.0231 - psnr: 16.3673 - ssim_metric: 0.6053
# Epoch 17: val_loss improved from 0.02338 to 0.02325, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 747ms/step - loss: 0.0231 - psnr: 16.3663 - ssim_metric: 0.6053 - val_loss: 0.0232 - val_psnr: 16.3476 - val_ssim_metric: 0.6042
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 0.0233 - psnr: 16.3270 - ssim_metric: 0.6051
# Epoch 18: val_loss improved from 0.02325 to 0.02286, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 898ms/step - loss: 0.0233 - psnr: 16.3289 - ssim_metric: 0.6052 - val_loss: 0.0229 - val_psnr: 16.4218 - val_ssim_metric: 0.6061
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 0.0227 - psnr: 16.4521 - ssim_metric: 0.6097
# Epoch 19: val_loss improved from 0.02286 to 0.02260, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 903ms/step - loss: 0.0227 - psnr: 16.4520 - ssim_metric: 0.6097 - val_loss: 0.0226 - val_psnr: 16.4712 - val_ssim_metric: 0.6080
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 0.0233 - psnr: 16.3349 - ssim_metric: 0.6069
# Epoch 20: val_loss improved from 0.02260 to 0.02236, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 898ms/step - loss: 0.0233 - psnr: 16.3396 - ssim_metric: 0.6071 - val_loss: 0.0224 - val_psnr: 16.5161 - val_ssim_metric: 0.6095
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 0.0220 - psnr: 16.5941 - ssim_metric: 0.6140
# Epoch 21: val_loss improved from 0.02236 to 0.02223, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 896ms/step - loss: 0.0220 - psnr: 16.5922 - ssim_metric: 0.6139 - val_loss: 0.0222 - val_psnr: 16.5416 - val_ssim_metric: 0.6101
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 0.0218 - psnr: 16.6260 - ssim_metric: 0.6136
# Epoch 22: val_loss improved from 0.02223 to 0.02201, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 897ms/step - loss: 0.0218 - psnr: 16.6238 - ssim_metric: 0.6136 - val_loss: 0.0220 - val_psnr: 16.5848 - val_ssim_metric: 0.6123
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 0.0222 - psnr: 16.5486 - ssim_metric: 0.6122
# Epoch 23: val_loss improved from 0.02201 to 0.02183, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 903ms/step - loss: 0.0222 - psnr: 16.5501 - ssim_metric: 0.6123 - val_loss: 0.0218 - val_psnr: 16.6210 - val_ssim_metric: 0.6132
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0224 - psnr: 16.5160 - ssim_metric: 0.6132
# Epoch 24: val_loss did not improve from 0.02183
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 864ms/step - loss: 0.0224 - psnr: 16.5187 - ssim_metric: 0.6133 - val_loss: 0.0220 - val_psnr: 16.5949 - val_ssim_metric: 0.6109
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0216 - psnr: 16.6767 - ssim_metric: 0.6175
# Epoch 25: val_loss improved from 0.02183 to 0.02155, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 37s 731ms/step - loss: 0.0216 - psnr: 16.6759 - ssim_metric: 0.6175 - val_loss: 0.0216 - val_psnr: 16.6768 - val_ssim_metric: 0.6164
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0218 - psnr: 16.6220 - ssim_metric: 0.6181
# Epoch 26: val_loss improved from 0.02155 to 0.02146, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 895ms/step - loss: 0.0218 - psnr: 16.6242 - ssim_metric: 0.6181 - val_loss: 0.0215 - val_psnr: 16.6964 - val_ssim_metric: 0.6173
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 0.0210 - psnr: 16.7842 - ssim_metric: 0.6216
# Epoch 27: val_loss improved from 0.02146 to 0.02132, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 893ms/step - loss: 0.0210 - psnr: 16.7819 - ssim_metric: 0.6215 - val_loss: 0.0213 - val_psnr: 16.7247 - val_ssim_metric: 0.6176
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0213 - psnr: 16.7217 - ssim_metric: 0.6207
# Epoch 28: val_loss did not improve from 0.02132
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 864ms/step - loss: 0.0213 - psnr: 16.7220 - ssim_metric: 0.6207 - val_loss: 0.0215 - val_psnr: 16.6924 - val_ssim_metric: 0.6148
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 0.0212 - psnr: 16.7600 - ssim_metric: 0.6213
# Epoch 29: val_loss improved from 0.02132 to 0.02112, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 28s 896ms/step - loss: 0.0212 - psnr: 16.7603 - ssim_metric: 0.6213 - val_loss: 0.0211 - val_psnr: 16.7657 - val_ssim_metric: 0.6196
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 0.0213 - psnr: 16.7370 - ssim_metric: 0.6210
# Epoch 30: val_loss improved from 0.02112 to 0.02093, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 902ms/step - loss: 0.0213 - psnr: 16.7376 - ssim_metric: 0.6211 - val_loss: 0.0209 - val_psnr: 16.8037 - val_ssim_metric: 0.6214
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - loss: 0.0207 - psnr: 16.8438 - ssim_metric: 0.6230
# Epoch 31: val_loss improved from 0.02093 to 0.02082, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 902ms/step - loss: 0.0207 - psnr: 16.8429 - ssim_metric: 0.6230 - val_loss: 0.0208 - val_psnr: 16.8260 - val_ssim_metric: 0.6216
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - loss: 0.0204 - psnr: 16.9238 - ssim_metric: 0.6282
# Epoch 32: val_loss improved from 0.02082 to 0.02071, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 913ms/step - loss: 0.0204 - psnr: 16.9217 - ssim_metric: 0.6281 - val_loss: 0.0207 - val_psnr: 16.8502 - val_ssim_metric: 0.6231
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 0.0205 - psnr: 16.9036 - ssim_metric: 0.6251
# Epoch 33: val_loss did not improve from 0.02071
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 870ms/step - loss: 0.0205 - psnr: 16.9019 - ssim_metric: 0.6251 - val_loss: 0.0209 - val_psnr: 16.8005 - val_ssim_metric: 0.6214
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - loss: 0.0214 - psnr: 16.7204 - ssim_metric: 0.6250
# Epoch 34: val_loss improved from 0.02071 to 0.02067, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 907ms/step - loss: 0.0214 - psnr: 16.7239 - ssim_metric: 0.6250 - val_loss: 0.0207 - val_psnr: 16.8589 - val_ssim_metric: 0.6237
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 0.0207 - psnr: 16.8597 - ssim_metric: 0.6249
# Epoch 35: val_loss improved from 0.02067 to 0.02043, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 898ms/step - loss: 0.0207 - psnr: 16.8609 - ssim_metric: 0.6250 - val_loss: 0.0204 - val_psnr: 16.9083 - val_ssim_metric: 0.6250
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 0.0206 - psnr: 16.8855 - ssim_metric: 0.6272
# Epoch 36: val_loss improved from 0.02043 to 0.02040, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 734ms/step - loss: 0.0206 - psnr: 16.8864 - ssim_metric: 0.6272 - val_loss: 0.0204 - val_psnr: 16.9148 - val_ssim_metric: 0.6262
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0203 - psnr: 16.9447 - ssim_metric: 0.6286
# Epoch 37: val_loss improved from 0.02040 to 0.02027, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 897ms/step - loss: 0.0203 - psnr: 16.9443 - ssim_metric: 0.6286 - val_loss: 0.0203 - val_psnr: 16.9431 - val_ssim_metric: 0.6268
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0199 - psnr: 17.0213 - ssim_metric: 0.6298
# Epoch 38: val_loss improved from 0.02027 to 0.02020, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 896ms/step - loss: 0.0199 - psnr: 17.0192 - ssim_metric: 0.6298 - val_loss: 0.0202 - val_psnr: 16.9590 - val_ssim_metric: 0.6273
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - loss: 0.0204 - psnr: 16.9074 - ssim_metric: 0.6321
# Epoch 39: val_loss did not improve from 0.02020
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 863ms/step - loss: 0.0204 - psnr: 16.9089 - ssim_metric: 0.6321 - val_loss: 0.0202 - val_psnr: 16.9527 - val_ssim_metric: 0.6270
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0203 - psnr: 16.9251 - ssim_metric: 0.6365
# Epoch 40: val_loss improved from 0.02020 to 0.02006, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 897ms/step - loss: 0.0203 - psnr: 16.9268 - ssim_metric: 0.6363 - val_loss: 0.0201 - val_psnr: 16.9893 - val_ssim_metric: 0.6286
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0201 - psnr: 16.9648 - ssim_metric: 0.6315
# Epoch 41: val_loss did not improve from 0.02006
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 864ms/step - loss: 0.0201 - psnr: 16.9660 - ssim_metric: 0.6315 - val_loss: 0.0201 - val_psnr: 16.9860 - val_ssim_metric: 0.6290
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - loss: 0.0199 - psnr: 17.0355 - ssim_metric: 0.6335
# Epoch 42: val_loss improved from 0.02006 to 0.01990, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 895ms/step - loss: 0.0199 - psnr: 17.0351 - ssim_metric: 0.6335 - val_loss: 0.0199 - val_psnr: 17.0241 - val_ssim_metric: 0.6309
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - loss: 0.0198 - psnr: 17.0370 - ssim_metric: 0.6350
# Epoch 43: val_loss improved from 0.01990 to 0.01986, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 730ms/step - loss: 0.0198 - psnr: 17.0362 - ssim_metric: 0.6349 - val_loss: 0.0199 - val_psnr: 17.0312 - val_ssim_metric: 0.6304
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0200 - psnr: 17.0063 - ssim_metric: 0.6281
# Epoch 44: val_loss improved from 0.01986 to 0.01979, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 900ms/step - loss: 0.0200 - psnr: 17.0075 - ssim_metric: 0.6282 - val_loss: 0.0198 - val_psnr: 17.0481 - val_ssim_metric: 0.6322
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - loss: 0.0199 - psnr: 17.0346 - ssim_metric: 0.6337
# Epoch 45: val_loss improved from 0.01979 to 0.01976, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 892ms/step - loss: 0.0199 - psnr: 17.0351 - ssim_metric: 0.6338 - val_loss: 0.0198 - val_psnr: 17.0551 - val_ssim_metric: 0.6323
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - loss: 0.0194 - psnr: 17.1219 - ssim_metric: 0.6359
# Epoch 46: val_loss improved from 0.01976 to 0.01960, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 892ms/step - loss: 0.0195 - psnr: 17.1207 - ssim_metric: 0.6359 - val_loss: 0.0196 - val_psnr: 17.0902 - val_ssim_metric: 0.6341
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 0.0199 - psnr: 17.0251 - ssim_metric: 0.6350
# Epoch 47: val_loss improved from 0.01960 to 0.01958, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 899ms/step - loss: 0.0199 - psnr: 17.0271 - ssim_metric: 0.6351 - val_loss: 0.0196 - val_psnr: 17.0939 - val_ssim_metric: 0.6330
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0199 - psnr: 17.0181 - ssim_metric: 0.6355
# Epoch 48: val_loss improved from 0.01958 to 0.01947, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 734ms/step - loss: 0.0199 - psnr: 17.0205 - ssim_metric: 0.6355 - val_loss: 0.0195 - val_psnr: 17.1185 - val_ssim_metric: 0.6345
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 0.0196 - psnr: 17.0851 - ssim_metric: 0.6372
# Epoch 49: val_loss did not improve from 0.01947
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 703ms/step - loss: 0.0196 - psnr: 17.0864 - ssim_metric: 0.6372 - val_loss: 0.0197 - val_psnr: 17.0772 - val_ssim_metric: 0.6322
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - loss: 0.0192 - psnr: 17.1754 - ssim_metric: 0.6360
# Epoch 50: val_loss improved from 0.01947 to 0.01939, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 741ms/step - loss: 0.0192 - psnr: 17.1738 - ssim_metric: 0.6361 - val_loss: 0.0194 - val_psnr: 17.1358 - val_ssim_metric: 0.6357
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 0.0195 - psnr: 17.1161 - ssim_metric: 0.6368
# Epoch 51: val_loss improved from 0.01939 to 0.01935, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 746ms/step - loss: 0.0195 - psnr: 17.1172 - ssim_metric: 0.6368 - val_loss: 0.0194 - val_psnr: 17.1445 - val_ssim_metric: 0.6368
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0194 - psnr: 17.1425 - ssim_metric: 0.6384
# Epoch 52: val_loss improved from 0.01935 to 0.01924, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 896ms/step - loss: 0.0194 - psnr: 17.1432 - ssim_metric: 0.6385 - val_loss: 0.0192 - val_psnr: 17.1698 - val_ssim_metric: 0.6365
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 0.0189 - psnr: 17.2452 - ssim_metric: 0.6446
# Epoch 53: val_loss did not improve from 0.01924
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 28s 871ms/step - loss: 0.0189 - psnr: 17.2434 - ssim_metric: 0.6445 - val_loss: 0.0193 - val_psnr: 17.1665 - val_ssim_metric: 0.6372
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 0.0192 - psnr: 17.1772 - ssim_metric: 0.6381
# Epoch 54: val_loss improved from 0.01924 to 0.01923, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 37s 735ms/step - loss: 0.0192 - psnr: 17.1772 - ssim_metric: 0.6381 - val_loss: 0.0192 - val_psnr: 17.1726 - val_ssim_metric: 0.6381
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0190 - psnr: 17.2085 - ssim_metric: 0.6441
# Epoch 55: val_loss improved from 0.01923 to 0.01908, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 737ms/step - loss: 0.0190 - psnr: 17.2083 - ssim_metric: 0.6440 - val_loss: 0.0191 - val_psnr: 17.2061 - val_ssim_metric: 0.6385
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - loss: 0.0189 - psnr: 17.2409 - ssim_metric: 0.6463
# Epoch 56: val_loss improved from 0.01908 to 0.01901, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 903ms/step - loss: 0.0189 - psnr: 17.2404 - ssim_metric: 0.6462 - val_loss: 0.0190 - val_psnr: 17.2216 - val_ssim_metric: 0.6392
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - loss: 0.0196 - psnr: 17.0983 - ssim_metric: 0.6409
# Epoch 57: val_loss did not improve from 0.01901
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 28s 873ms/step - loss: 0.0196 - psnr: 17.1021 - ssim_metric: 0.6409 - val_loss: 0.0193 - val_psnr: 17.1678 - val_ssim_metric: 0.6366
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - loss: 0.0195 - psnr: 17.1070 - ssim_metric: 0.6399
# Epoch 58: val_loss improved from 0.01901 to 0.01895, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 747ms/step - loss: 0.0195 - psnr: 17.1108 - ssim_metric: 0.6400 - val_loss: 0.0189 - val_psnr: 17.2368 - val_ssim_metric: 0.6404
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - loss: 0.0193 - psnr: 17.1443 - ssim_metric: 0.6442
# Epoch 59: val_loss improved from 0.01895 to 0.01885, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 902ms/step - loss: 0.0193 - psnr: 17.1477 - ssim_metric: 0.6441 - val_loss: 0.0188 - val_psnr: 17.2599 - val_ssim_metric: 0.6413
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - loss: 0.0186 - psnr: 17.3286 - ssim_metric: 0.6438
# Epoch 60: val_loss did not improve from 0.01885
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 28s 873ms/step - loss: 0.0186 - psnr: 17.3270 - ssim_metric: 0.6438 - val_loss: 0.0189 - val_psnr: 17.2493 - val_ssim_metric: 0.6405
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - loss: 0.0187 - psnr: 17.3060 - ssim_metric: 0.6476
# Epoch 61: val_loss did not improve from 0.01885
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 869ms/step - loss: 0.0187 - psnr: 17.3052 - ssim_metric: 0.6475 - val_loss: 0.0189 - val_psnr: 17.2432 - val_ssim_metric: 0.6398
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 0.0189 - psnr: 17.2451 - ssim_metric: 0.6425
# Epoch 62: val_loss improved from 0.01885 to 0.01878, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 906ms/step - loss: 0.0189 - psnr: 17.2457 - ssim_metric: 0.6425 - val_loss: 0.0188 - val_psnr: 17.2767 - val_ssim_metric: 0.6427
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 0.0185 - psnr: 17.3371 - ssim_metric: 0.6445
# Epoch 63: val_loss improved from 0.01878 to 0.01866, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 739ms/step - loss: 0.0185 - psnr: 17.3362 - ssim_metric: 0.6446 - val_loss: 0.0187 - val_psnr: 17.3029 - val_ssim_metric: 0.6428
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 0.0186 - psnr: 17.3168 - ssim_metric: 0.6484
# Epoch 64: val_loss did not improve from 0.01866
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 705ms/step - loss: 0.0186 - psnr: 17.3164 - ssim_metric: 0.6484 - val_loss: 0.0188 - val_psnr: 17.2730 - val_ssim_metric: 0.6427
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0187 - psnr: 17.2957 - ssim_metric: 0.6459
# Epoch 65: val_loss improved from 0.01866 to 0.01858, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 47s 896ms/step - loss: 0.0187 - psnr: 17.2965 - ssim_metric: 0.6460 - val_loss: 0.0186 - val_psnr: 17.3228 - val_ssim_metric: 0.6441
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 0.0184 - psnr: 17.3577 - ssim_metric: 0.6504
# Epoch 66: val_loss improved from 0.01858 to 0.01850, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 899ms/step - loss: 0.0184 - psnr: 17.3575 - ssim_metric: 0.6503 - val_loss: 0.0185 - val_psnr: 17.3407 - val_ssim_metric: 0.6450
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0187 - psnr: 17.2888 - ssim_metric: 0.6476
# Epoch 67: val_loss did not improve from 0.01850
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 701ms/step - loss: 0.0187 - psnr: 17.2907 - ssim_metric: 0.6476 - val_loss: 0.0186 - val_psnr: 17.3229 - val_ssim_metric: 0.6442
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 533ms/step - loss: 0.0186 - psnr: 17.3199 - ssim_metric: 0.6444
# Epoch 68: val_loss improved from 0.01850 to 0.01839, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 47s 896ms/step - loss: 0.0186 - psnr: 17.3211 - ssim_metric: 0.6445 - val_loss: 0.0184 - val_psnr: 17.3663 - val_ssim_metric: 0.6460
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - loss: 0.0179 - psnr: 17.4895 - ssim_metric: 0.6522
# Epoch 69: val_loss improved from 0.01839 to 0.01838, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 907ms/step - loss: 0.0180 - psnr: 17.4864 - ssim_metric: 0.6521 - val_loss: 0.0184 - val_psnr: 17.3692 - val_ssim_metric: 0.6461
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - loss: 0.0187 - psnr: 17.2919 - ssim_metric: 0.6492
# Epoch 70: val_loss improved from 0.01838 to 0.01830, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 739ms/step - loss: 0.0187 - psnr: 17.2946 - ssim_metric: 0.6492 - val_loss: 0.0183 - val_psnr: 17.3886 - val_ssim_metric: 0.6469
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 0.0189 - psnr: 17.2452 - ssim_metric: 0.6458
# Epoch 71: val_loss did not improve from 0.01830
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 45s 867ms/step - loss: 0.0189 - psnr: 17.2426 - ssim_metric: 0.6457 - val_loss: 0.0201 - val_psnr: 16.9733 - val_ssim_metric: 0.6297
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 0.0190 - psnr: 17.2288 - ssim_metric: 0.6421
# Epoch 72: val_loss did not improve from 0.01830
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 866ms/step - loss: 0.0190 - psnr: 17.2303 - ssim_metric: 0.6423 - val_loss: 0.0185 - val_psnr: 17.3443 - val_ssim_metric: 0.6468
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0179 - psnr: 17.4858 - ssim_metric: 0.6539
# Epoch 73: val_loss improved from 0.01830 to 0.01827, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 37s 732ms/step - loss: 0.0179 - psnr: 17.4831 - ssim_metric: 0.6538 - val_loss: 0.0183 - val_psnr: 17.3964 - val_ssim_metric: 0.6482
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - loss: 0.0180 - psnr: 17.4635 - ssim_metric: 0.6501
# Epoch 74: val_loss improved from 0.01827 to 0.01824, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 23s 740ms/step - loss: 0.0180 - psnr: 17.4621 - ssim_metric: 0.6501 - val_loss: 0.0182 - val_psnr: 17.4036 - val_ssim_metric: 0.6475
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 0.0186 - psnr: 17.3194 - ssim_metric: 0.6491
# Epoch 75: val_loss improved from 0.01824 to 0.01816, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 897ms/step - loss: 0.0186 - psnr: 17.3230 - ssim_metric: 0.6492 - val_loss: 0.0182 - val_psnr: 17.4220 - val_ssim_metric: 0.6485
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - loss: 0.0181 - psnr: 17.4305 - ssim_metric: 0.6518
# Epoch 76: val_loss improved from 0.01816 to 0.01814, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 901ms/step - loss: 0.0181 - psnr: 17.4309 - ssim_metric: 0.6518 - val_loss: 0.0181 - val_psnr: 17.4265 - val_ssim_metric: 0.6482
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 0.0178 - psnr: 17.4950 - ssim_metric: 0.6529
# Epoch 77: val_loss improved from 0.01814 to 0.01805, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 898ms/step - loss: 0.0178 - psnr: 17.4937 - ssim_metric: 0.6529 - val_loss: 0.0181 - val_psnr: 17.4479 - val_ssim_metric: 0.6495
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0184 - psnr: 17.3589 - ssim_metric: 0.6494
# Epoch 78: val_loss improved from 0.01805 to 0.01800, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 906ms/step - loss: 0.0184 - psnr: 17.3624 - ssim_metric: 0.6495 - val_loss: 0.0180 - val_psnr: 17.4606 - val_ssim_metric: 0.6503
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - loss: 0.0181 - psnr: 17.4463 - ssim_metric: 0.6511
# Epoch 79: val_loss improved from 0.01800 to 0.01797, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 28s 898ms/step - loss: 0.0180 - psnr: 17.4473 - ssim_metric: 0.6512 - val_loss: 0.0180 - val_psnr: 17.4672 - val_ssim_metric: 0.6512
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - loss: 0.0180 - psnr: 17.4543 - ssim_metric: 0.6547
# Epoch 80: val_loss improved from 0.01797 to 0.01793, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 24s 744ms/step - loss: 0.0180 - psnr: 17.4551 - ssim_metric: 0.6547 - val_loss: 0.0179 - val_psnr: 17.4766 - val_ssim_metric: 0.6508
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - loss: 0.0176 - psnr: 17.5653 - ssim_metric: 0.6574
# Epoch 81: val_loss improved from 0.01793 to 0.01790, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 739ms/step - loss: 0.0176 - psnr: 17.5632 - ssim_metric: 0.6573 - val_loss: 0.0179 - val_psnr: 17.4852 - val_ssim_metric: 0.6513
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - loss: 0.0180 - psnr: 17.4483 - ssim_metric: 0.6543
# Epoch 82: val_loss improved from 0.01790 to 0.01784, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 906ms/step - loss: 0.0180 - psnr: 17.4502 - ssim_metric: 0.6544 - val_loss: 0.0178 - val_psnr: 17.4996 - val_ssim_metric: 0.6516
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - loss: 0.0178 - psnr: 17.5208 - ssim_metric: 0.6568
# Epoch 83: val_loss did not improve from 0.01784
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 866ms/step - loss: 0.0178 - psnr: 17.5208 - ssim_metric: 0.6567 - val_loss: 0.0178 - val_psnr: 17.4984 - val_ssim_metric: 0.6533
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 0.0178 - psnr: 17.5175 - ssim_metric: 0.6569
# Epoch 84: val_loss improved from 0.01784 to 0.01778, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 894ms/step - loss: 0.0178 - psnr: 17.5180 - ssim_metric: 0.6569 - val_loss: 0.0178 - val_psnr: 17.5146 - val_ssim_metric: 0.6529
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 0.0179 - psnr: 17.4879 - ssim_metric: 0.6547
# Epoch 85: val_loss did not improve from 0.01778
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 702ms/step - loss: 0.0179 - psnr: 17.4894 - ssim_metric: 0.6548 - val_loss: 0.0178 - val_psnr: 17.4975 - val_ssim_metric: 0.6512
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - loss: 0.0176 - psnr: 17.5652 - ssim_metric: 0.6567
# Epoch 86: val_loss improved from 0.01778 to 0.01768, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 47s 907ms/step - loss: 0.0176 - psnr: 17.5646 - ssim_metric: 0.6567 - val_loss: 0.0177 - val_psnr: 17.5385 - val_ssim_metric: 0.6538
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - loss: 0.0175 - psnr: 17.5847 - ssim_metric: 0.6563
# Epoch 87: val_loss improved from 0.01768 to 0.01767, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 904ms/step - loss: 0.0175 - psnr: 17.5839 - ssim_metric: 0.6563 - val_loss: 0.0177 - val_psnr: 17.5404 - val_ssim_metric: 0.6534
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 543ms/step - loss: 0.0173 - psnr: 17.6411 - ssim_metric: 0.6594
# Epoch 88: val_loss improved from 0.01767 to 0.01765, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 745ms/step - loss: 0.0173 - psnr: 17.6389 - ssim_metric: 0.6594 - val_loss: 0.0177 - val_psnr: 17.5456 - val_ssim_metric: 0.6546
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - loss: 0.0175 - psnr: 17.5816 - ssim_metric: 0.6583
# Epoch 89: val_loss improved from 0.01765 to 0.01762, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 906ms/step - loss: 0.0175 - psnr: 17.5814 - ssim_metric: 0.6583 - val_loss: 0.0176 - val_psnr: 17.5536 - val_ssim_metric: 0.6542
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - loss: 0.0175 - psnr: 17.5844 - ssim_metric: 0.6558
# Epoch 90: val_loss improved from 0.01762 to 0.01756, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 36s 750ms/step - loss: 0.0175 - psnr: 17.5845 - ssim_metric: 0.6559 - val_loss: 0.0176 - val_psnr: 17.5688 - val_ssim_metric: 0.6553
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 0.0175 - psnr: 17.5924 - ssim_metric: 0.6588
# Epoch 91: val_loss improved from 0.01756 to 0.01750, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 899ms/step - loss: 0.0175 - psnr: 17.5924 - ssim_metric: 0.6588 - val_loss: 0.0175 - val_psnr: 17.5824 - val_ssim_metric: 0.6559
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - loss: 0.0174 - psnr: 17.6154 - ssim_metric: 0.6583
# Epoch 92: val_loss improved from 0.01750 to 0.01750, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 905ms/step - loss: 0.0174 - psnr: 17.6148 - ssim_metric: 0.6583 - val_loss: 0.0175 - val_psnr: 17.5842 - val_ssim_metric: 0.6556
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - loss: 0.0175 - psnr: 17.5881 - ssim_metric: 0.6566
# Epoch 93: val_loss improved from 0.01750 to 0.01745, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 41s 898ms/step - loss: 0.0175 - psnr: 17.5884 - ssim_metric: 0.6567 - val_loss: 0.0175 - val_psnr: 17.5950 - val_ssim_metric: 0.6563
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - loss: 0.0173 - psnr: 17.6217 - ssim_metric: 0.6604
# Epoch 94: val_loss did not improve from 0.01745
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 40s 869ms/step - loss: 0.0173 - psnr: 17.6213 - ssim_metric: 0.6604 - val_loss: 0.0177 - val_psnr: 17.5314 - val_ssim_metric: 0.6527
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - loss: 0.0172 - psnr: 17.6457 - ssim_metric: 0.6605
# Epoch 95: val_loss improved from 0.01745 to 0.01736, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 37s 738ms/step - loss: 0.0172 - psnr: 17.6448 - ssim_metric: 0.6605 - val_loss: 0.0174 - val_psnr: 17.6169 - val_ssim_metric: 0.6573
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 546ms/step - loss: 0.0174 - psnr: 17.6063 - ssim_metric: 0.6618
# Epoch 96: val_loss improved from 0.01736 to 0.01734, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 906ms/step - loss: 0.0174 - psnr: 17.6072 - ssim_metric: 0.6618 - val_loss: 0.0173 - val_psnr: 17.6240 - val_ssim_metric: 0.6584
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 548ms/step - loss: 0.0174 - psnr: 17.6107 - ssim_metric: 0.6602
# Epoch 97: val_loss improved from 0.01734 to 0.01732, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 29s 912ms/step - loss: 0.0174 - psnr: 17.6118 - ssim_metric: 0.6603 - val_loss: 0.0173 - val_psnr: 17.6285 - val_ssim_metric: 0.6572
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - loss: 0.0173 - psnr: 17.6239 - ssim_metric: 0.6627
# Epoch 98: val_loss did not improve from 0.01732
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 35s 716ms/step - loss: 0.0173 - psnr: 17.6245 - ssim_metric: 0.6626 - val_loss: 0.0174 - val_psnr: 17.6165 - val_ssim_metric: 0.6588
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - loss: 0.0170 - psnr: 17.7126 - ssim_metric: 0.6620
# Epoch 99: val_loss improved from 0.01732 to 0.01724, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 42s 749ms/step - loss: 0.0170 - psnr: 17.7113 - ssim_metric: 0.6620 - val_loss: 0.0172 - val_psnr: 17.6491 - val_ssim_metric: 0.6588
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 541ms/step - loss: 0.0176 - psnr: 17.5642 - ssim_metric: 0.6590
# Epoch 100: val_loss improved from 0.01724 to 0.01722, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 46s 900ms/step - loss: 0.0176 - psnr: 17.5674 - ssim_metric: 0.6591 - val_loss: 0.0172 - val_psnr: 17.6526 - val_ssim_metric: 0.6589
#
# 🚀 Training Completed in 64 min 29 sec
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 14s 284ms/step
# Training and visualization complete.
