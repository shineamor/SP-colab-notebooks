# %% [markdown]
# <a href="https://colab.research.google.com/github/shineamor/SP-colab-notebooks/blob/main/tcnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikit-image
# Out:
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (0.25.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (1.26.4)
# Requirement already satisfied: scipy>=1.11.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (1.14.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (3.4.2)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (11.1.0)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (2025.2.18)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image) (0.4)

# %%
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.11/dist-packages (1.6.17)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.11/dist-packages (from kaggle) (1.17.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2025.1.31)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from kaggle) (4.67.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.11/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.11/dist-packages (from kaggle) (2.3.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.11/dist-packages (from kaggle) (6.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.11/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->kaggle) (3.10)

# %%
pip install tensorflow-datasets
# Out:
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.11/dist-packages (4.9.8)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.4.0)
# Requirement already satisfied: array_record>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.7.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.1.9)
# Requirement already satisfied: etils>=1.9.1 in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (1.12.2)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (4.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.26.4)
# Requirement already satisfied: promise in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (4.25.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (18.1.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (2.32.3)
# Requirement already satisfied: simple_parsing in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.1.7)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.16.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (2.5.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (0.10.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (4.67.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from tensorflow-datasets) (1.17.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (0.8.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (6.5.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (4.12.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow-datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow-datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow-datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->tensorflow-datasets) (2025.1.31)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.11/dist-packages (from dm-tree->tensorflow-datasets) (25.2.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from promise->tensorflow-datasets) (1.17.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.11/dist-packages (from simple_parsing->tensorflow-datasets) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /usr/local/lib/python3.11/dist-packages (from tensorflow-metadata->tensorflow-datasets) (1.69.1)

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow.keras as keras
import matplotlib.pyplot as plt
import numpy as np
import PIL, os, random, skimage.util, csv
import tensorflow.keras.backend as K
from google.colab import files
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, Dense, AveragePooling2D, UpSampling2D, Reshape, Flatten, Input, Add, Multiply, GlobalAveragePooling2D, GlobalMaxPooling2D, Concatenate, Lambda
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import time

#Load Oxford Flowers dataset
dataset, info = tfds.load(
    "oxford_flowers102",
    with_info=True,
    as_supervised=True
)
print(info.splits)

#Function to covert TF Dataset to NumPy arrays
def ds_to_numpy(dataset):
    images, labels = [], []
    for img, lbl in dataset:
        images.append(img.numpy())
        labels.append(lbl.numpy())
    return np.array(images), np.array(labels)

#Preprocessing function: Resize & Normalize images
def preprocess(image, label):
    image = tf.image.resize(image, [128, 128]) # Resize to 128×128
    image = tf.cast(image, tf.float32) / 255.0 # Normalize [0,1]
    image = (image * 2.0) - 1.0  # Convert to [-1,1]
    return image, label

# Function to add noise to images (Salt & Pepper, Gaussian)
def add_noise(images, noise_factor=0.2, salt_pepper_amount=0.1):
    noisy_images = []
    for img in images:
        # Add salt & pepper noise
        img_sp = skimage.util.random_noise(img, mode='s&p', amount=salt_pepper_amount)

        # Add Gaussian noise
        img_noisy = img_sp + noise_factor * np.random.normal(loc=0.0, scale=1.0, size=img.shape)
        img_noisy = np.clip(img_noisy, -1.0, 1.0)  # Ensure values are in the valid range [-1, 1]

        noisy_images.append(img_noisy)

    return np.array(noisy_images)

def PSNR(y_true, y_pred):
    max_pixel = 1.0  # Since images are normalized to [-1,1]
    return 10.0 * K.log((max_pixel ** 2) / (K.mean(K.square(y_pred - y_true)))) / K.log(10.0)

def ssim_metric(y_true, y_pred):
    return tf.reduce_mean(tf.image.ssim(y_true, y_pred, max_val=2.0))

# Define the Spatial Attention Module (SAM)
def spatial_attention(input_feature):
    avg_pool = Lambda(lambda x: tf.reduce_mean(x, axis=-1, keepdims=True))(input_feature)
    max_pool = Lambda(lambda x: tf.reduce_max(x, axis=-1, keepdims=True))(input_feature)
    concat = Concatenate(axis=-1)([avg_pool, max_pool])
    attention = Conv2D(1, kernel_size=7, padding='same', activation='sigmoid')(concat)
    return Multiply()([input_feature, attention])

# Load dataset splits
splits, info = tfds.load(
    'oxford_flowers102',
    split=['train','test','validation'],
    as_supervised=True,
    with_info=True
)
train_ds, test_ds, val_ds = splits

# Apply preprocessing to dataset
train_ds = train_ds.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
test_ds  = test_ds.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
val_ds   = val_ds.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)

# Convert dataset to NumPy arrays
(x_train, _), (x_valid, _), (x_test, _) = (
    ds_to_numpy(train_ds),
    ds_to_numpy(val_ds),
    ds_to_numpy(test_ds)
)

# Convert each split to NumPy
(x_train, y_train) = ds_to_numpy(train_ds)
(x_test, y_test)   = ds_to_numpy(test_ds)
(x_valid, y_valid) = ds_to_numpy(val_ds)

print("Train shape:", x_train.shape)
print("Valid shape:", x_valid.shape)
print("Test shape: ", x_test.shape)

# Model Configuration
encoding_size = 90
perturbation_max = 40
image_shape = (128,128,3)

# Define Model Architecture
model_input = Input(shape=image_shape)

# Encoder
conv1 = Conv2D(23, 3, padding='same', activation='relu')(model_input)
print("conv1 shape:", conv1.shape)
conv2 = Conv2D(23, 3, padding='same', activation='relu')(conv1)
print("conv2 shape:", conv2.shape)
pool1 = AveragePooling2D(2, 2)(conv2)
print("pool1 shape:", pool1.shape)
conv3 = Conv2D(45, 3, padding='same', activation='relu')(pool1)
print("conv3 shape:", conv3.shape)
conv4 = Conv2D(45, 3, padding='same', activation='relu')(conv3)
print("conv4 shape:", conv4.shape)
pool2 = AveragePooling2D(2, 2)(conv4)
print("pool2 shape:", pool2.shape)
conv5 = Conv2D(90, 3, padding='same', activation='relu')(pool2)
print("conv5 shape:", conv5.shape)
conv6 = Conv2D(90, 3, padding='same', activation='relu')(conv5)
print("conv6 shape:", conv6.shape)

# Decoder
flatten = Flatten()(conv6)
print("flatten shape:", flatten.shape)
encoding = Dense(encoding_size, activation='relu')(flatten)
print("encoding shape:", encoding.shape)
dense2 = Dense(192, activation='relu')(encoding)
print("dense2 shape:", dense2.shape)
reshape = Reshape((8, 8, 3))(dense2)
print("reshape shape:", reshape.shape)
upsample2 = UpSampling2D(size=(4, 4))(reshape)
print("upsample2 shape:", upsample2.shape)
conv11 = Conv2D(90, 3, padding='same', activation='relu')(upsample2)
print("conv11 shape:", conv11.shape)
conv12 = Conv2D(90, 3, padding='same', activation='relu')(conv11)
print("conv12 shape:", conv12.shape)
add1 = Add()([conv12, conv6])
print("add1 shape:", add1.shape)
upsample3 = UpSampling2D(size=(4, 4))(add1)
print("upsample3 shape:", upsample3.shape)
conv13 = Conv2D(45, 3, padding='same', activation='relu')(upsample3)
print("conv13 shape:", conv13.shape)
conv14 = Conv2D(45, 3, padding='same', activation='relu')(conv13)
print("conv14 shape:", conv14.shape)
upsample_conv4 = UpSampling2D(size=(2, 2))(conv4)
print("upsample_conv4 shape:", upsample_conv4.shape)
add2 = Add()([conv14, upsample_conv4])
print("add2 shape:", add2.shape)
upsample3 = UpSampling2D(size=(4, 4))(add2)
conv15 = Conv2D(8, 3, padding='same', activation='relu')(add2)
print("conv15 shape:", conv15.shape)
conv16 = Conv2D(3, 3, padding='same', activation='tanh')(conv15)
print("conv16 shape:", conv16.shape)

autoencoder = Model(model_input, conv16)
autoencoder.compile(loss='mse', optimizer=Adam(1e-4), metrics=[PSNR, ssim_metric])

# Ensure checkpoint directory exists
checkpoint_dir = 'checkpoint_oxford_flowers'
if not os.path.exists(checkpoint_dir):
    os.makedirs(checkpoint_dir)

# Define callbacks
checkpoint = ModelCheckpoint('checkpoint_oxford_flowers/best_weights.keras', monitor='val_loss', save_best_only=True, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=20, verbose=1)

# Generate noisy data
x_train_noisy = add_noise(x_train)
x_valid_noisy = add_noise(x_valid)

# Start runtime tracking
start_time = time.time()

#start training
epochs = 100
batch_size = 32
history = autoencoder.fit(
    x_train_noisy, x_train,
    batch_size=batch_size,
    epochs=epochs,
    validation_data=(x_valid_noisy, x_valid),
    callbacks=[checkpoint, early_stop]
)

# Stop runtime tracking
elapsed_time = time.time() - start_time
print(f"\n🚀 Training Completed in {int(elapsed_time // 60)} min {int(elapsed_time % 60)} sec")

history_dict = history.history
num_epochs = len(history_dict['loss'])

csv_filename = f"tcnn_comparison_plot_{epochs}_epochs.csv"
with open(csv_filename, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["epoch","loss","val_loss","psnr","val_psnr","ssim_metric","val_ssim_metric"])
     # One row per epoch
    for epoch_idx in range(num_epochs):
        row = [
            epoch_idx + 1,
            history_dict['loss'][epoch_idx],
            history_dict['val_loss'][epoch_idx],
            history_dict['psnr'][epoch_idx],
            history_dict['val_psnr'][epoch_idx],
            history_dict['ssim_metric'][epoch_idx],
            history_dict['val_ssim_metric'][epoch_idx]
        ]
        writer.writerow(row)

# Download CSV in Colab
files.download(csv_filename)

# Denoise the images using the autoencoder
denoised_images = autoencoder.predict(x_valid_noisy)

plot_filename_loss = f"tcnn_loss_plot_{epochs}_epochs.png"
plot_filename_psnr = f"tcnn_psnr_plot_{epochs}_epochs.png"
plot_filename_ssim = f"tcnn_ssim_plot_{epochs}_epochs.png"
plot_filename_comparison = f"tcnn_comparison_plot_{epochs}_epochs.png"


# Plot training & validation loss
plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.savefig(plot_filename_loss)
plt.show()

# Plot PSNR
plt.figure()
plt.plot(history.history['psnr'], label='Train PSNR')
plt.plot(history.history['val_psnr'], label='Val PSNR')
plt.title('Model PSNR')
plt.xlabel('Epochs')
plt.ylabel('PSNR (dB)')
plt.legend()
plt.savefig(plot_filename_psnr)
plt.show()

#Plot SSIM
plt.figure()
plt.plot(history.history['ssim_metric'], label='Train SSIM')
plt.plot(history.history['val_ssim_metric'], label='Val SSIM')
plt.title('Model SSIM')
plt.xlabel('Epochs')
plt.ylabel('SSIM')
plt.legend()
plt.savefig(plot_filename_ssim)
plt.show()

files.download(plot_filename_loss)
files.download(plot_filename_psnr)
files.download(plot_filename_ssim)

def deprocess(x):
    x = (x + 1.0) * 127.5
    return np.clip(x, 0, 255).astype(np.uint8)

def display_images(original, noisy, denoised, n=5):
    plt.figure(figsize=(20, 6))
    for i in range(n):
        # Original
        ax = plt.subplot(3, n, i+1)
        plt.imshow(deprocess(original[i]))
        plt.title("Original")
        plt.axis("off")

        # Noisy
        ax = plt.subplot(3, n, i+1+n)
        plt.imshow(deprocess(noisy[i]))
        plt.title("Noisy")
        plt.axis("off")

        # Denoised
        ax = plt.subplot(3, n, i+1+2*n)
        plt.imshow(deprocess(denoised[i]))
        plt.title("Denoised")
        plt.axis("off")
    plt.savefig(plot_filename_comparison)
    plt.show()
    files.download(plot_filename_comparison)


# Visualize the first 5 original, noisy, and denoised images
display_images(x_valid, x_valid_noisy, denoised_images, n=5)

print("Training and visualization complete.")
# Out:
# {'train': <SplitInfo num_examples=1020, num_shards=1>, 'test': <SplitInfo num_examples=6149, num_shards=2>, 'validation': <SplitInfo num_examples=1020, num_shards=1>}
# Train shape: (1020, 128, 128, 3)
# Valid shape: (1020, 128, 128, 3)
# Test shape:  (6149, 128, 128, 3)
# conv1 shape: (None, 128, 128, 23)
# conv2 shape: (None, 128, 128, 23)
# pool1 shape: (None, 64, 64, 23)
# conv3 shape: (None, 64, 64, 45)
# conv4 shape: (None, 64, 64, 45)
# pool2 shape: (None, 32, 32, 45)
# conv5 shape: (None, 32, 32, 90)
# conv6 shape: (None, 32, 32, 90)
# flatten shape: (None, 92160)
# encoding shape: (None, 90)
# dense2 shape: (None, 192)
# reshape shape: (None, 8, 8, 3)
# upsample2 shape: (None, 32, 32, 3)
# conv11 shape: (None, 32, 32, 90)
# conv12 shape: (None, 32, 32, 90)
# add1 shape: (None, 32, 32, 90)
# upsample3 shape: (None, 128, 128, 90)
# conv13 shape: (None, 128, 128, 45)
# conv14 shape: (None, 128, 128, 45)
# upsample_conv4 shape: (None, 128, 128, 45)
# add2 shape: (None, 128, 128, 45)
# conv15 shape: (None, 128, 128, 8)
# conv16 shape: (None, 128, 128, 3)
# Epoch 1/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - loss: 0.3005 - psnr: 5.3039 - ssim_metric: 0.0863
# Epoch 1: val_loss improved from inf to 0.15692, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 47s 872ms/step - loss: 0.2990 - psnr: 5.3300 - ssim_metric: 0.0880 - val_loss: 0.1569 - val_psnr: 8.0565 - val_ssim_metric: 0.2443
# Epoch 2/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.1435 - psnr: 8.4747 - ssim_metric: 0.2664
# Epoch 2: val_loss improved from 0.15692 to 0.09784, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 45s 176ms/step - loss: 0.1430 - psnr: 8.4905 - ssim_metric: 0.2668 - val_loss: 0.0978 - val_psnr: 10.1072 - val_ssim_metric: 0.3124
# Epoch 3/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0911 - psnr: 10.4400 - ssim_metric: 0.3408
# Epoch 3: val_loss improved from 0.09784 to 0.07205, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - loss: 0.0908 - psnr: 10.4526 - ssim_metric: 0.3415 - val_loss: 0.0720 - val_psnr: 11.4362 - val_ssim_metric: 0.3922
# Epoch 4/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0685 - psnr: 11.6614 - ssim_metric: 0.4085
# Epoch 4: val_loss improved from 0.07205 to 0.05904, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 180ms/step - loss: 0.0684 - psnr: 11.6673 - ssim_metric: 0.4089 - val_loss: 0.0590 - val_psnr: 12.2979 - val_ssim_metric: 0.4335
# Epoch 5/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0563 - psnr: 12.5180 - ssim_metric: 0.4512
# Epoch 5: val_loss improved from 0.05904 to 0.04488, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 177ms/step - loss: 0.0562 - psnr: 12.5270 - ssim_metric: 0.4515 - val_loss: 0.0449 - val_psnr: 13.4879 - val_ssim_metric: 0.4836
# Epoch 6/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0423 - psnr: 13.7520 - ssim_metric: 0.5008
# Epoch 6: val_loss improved from 0.04488 to 0.03857, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 172ms/step - loss: 0.0422 - psnr: 13.7571 - ssim_metric: 0.5009 - val_loss: 0.0386 - val_psnr: 14.1461 - val_ssim_metric: 0.5077
# Epoch 7/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0367 - psnr: 14.3702 - ssim_metric: 0.5221
# Epoch 7: val_loss improved from 0.03857 to 0.03414, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 174ms/step - loss: 0.0367 - psnr: 14.3728 - ssim_metric: 0.5222 - val_loss: 0.0341 - val_psnr: 14.6776 - val_ssim_metric: 0.5322
# Epoch 8/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0342 - psnr: 14.6738 - ssim_metric: 0.5375
# Epoch 8: val_loss improved from 0.03414 to 0.03249, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 166ms/step - loss: 0.0342 - psnr: 14.6764 - ssim_metric: 0.5375 - val_loss: 0.0325 - val_psnr: 14.8923 - val_ssim_metric: 0.5413
# Epoch 9/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0325 - psnr: 14.8881 - ssim_metric: 0.5457
# Epoch 9: val_loss improved from 0.03249 to 0.03122, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - loss: 0.0325 - psnr: 14.8903 - ssim_metric: 0.5457 - val_loss: 0.0312 - val_psnr: 15.0667 - val_ssim_metric: 0.5473
# Epoch 10/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0312 - psnr: 15.0702 - ssim_metric: 0.5517
# Epoch 10: val_loss improved from 0.03122 to 0.03021, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - loss: 0.0312 - psnr: 15.0717 - ssim_metric: 0.5518 - val_loss: 0.0302 - val_psnr: 15.2092 - val_ssim_metric: 0.5559
# Epoch 11/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0305 - psnr: 15.1697 - ssim_metric: 0.5567
# Epoch 11: val_loss improved from 0.03021 to 0.02945, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 167ms/step - loss: 0.0305 - psnr: 15.1718 - ssim_metric: 0.5568 - val_loss: 0.0294 - val_psnr: 15.3200 - val_ssim_metric: 0.5597
# Epoch 12/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0288 - psnr: 15.4146 - ssim_metric: 0.5648
# Epoch 12: val_loss improved from 0.02945 to 0.02862, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - loss: 0.0288 - psnr: 15.4133 - ssim_metric: 0.5648 - val_loss: 0.0286 - val_psnr: 15.4448 - val_ssim_metric: 0.5639
# Epoch 13/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0288 - psnr: 15.4187 - ssim_metric: 0.5675
# Epoch 13: val_loss improved from 0.02862 to 0.02820, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 172ms/step - loss: 0.0288 - psnr: 15.4196 - ssim_metric: 0.5675 - val_loss: 0.0282 - val_psnr: 15.5079 - val_ssim_metric: 0.5671
# Epoch 14/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0281 - psnr: 15.5245 - ssim_metric: 0.5712
# Epoch 14: val_loss improved from 0.02820 to 0.02769, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 181ms/step - loss: 0.0281 - psnr: 15.5254 - ssim_metric: 0.5712 - val_loss: 0.0277 - val_psnr: 15.5879 - val_ssim_metric: 0.5685
# Epoch 15/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0277 - psnr: 15.5872 - ssim_metric: 0.5730
# Epoch 15: val_loss improved from 0.02769 to 0.02729, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - loss: 0.0277 - psnr: 15.5882 - ssim_metric: 0.5730 - val_loss: 0.0273 - val_psnr: 15.6505 - val_ssim_metric: 0.5739
# Epoch 16/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0273 - psnr: 15.6402 - ssim_metric: 0.5763
# Epoch 16: val_loss improved from 0.02729 to 0.02663, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 180ms/step - loss: 0.0273 - psnr: 15.6421 - ssim_metric: 0.5764 - val_loss: 0.0266 - val_psnr: 15.7583 - val_ssim_metric: 0.5763
# Epoch 17/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0264 - psnr: 15.7956 - ssim_metric: 0.5771
# Epoch 17: val_loss did not improve from 0.02663
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - loss: 0.0264 - psnr: 15.7946 - ssim_metric: 0.5772 - val_loss: 0.0269 - val_psnr: 15.7125 - val_ssim_metric: 0.5723
# Epoch 18/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0266 - psnr: 15.7597 - ssim_metric: 0.5767
# Epoch 18: val_loss improved from 0.02663 to 0.02624, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 176ms/step - loss: 0.0266 - psnr: 15.7614 - ssim_metric: 0.5769 - val_loss: 0.0262 - val_psnr: 15.8217 - val_ssim_metric: 0.5773
# Epoch 19/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0258 - psnr: 15.9038 - ssim_metric: 0.5850
# Epoch 19: val_loss improved from 0.02624 to 0.02565, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 176ms/step - loss: 0.0258 - psnr: 15.9031 - ssim_metric: 0.5849 - val_loss: 0.0257 - val_psnr: 15.9207 - val_ssim_metric: 0.5812
# Epoch 20/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0257 - psnr: 15.9065 - ssim_metric: 0.5856
# Epoch 20: val_loss improved from 0.02565 to 0.02535, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - loss: 0.0257 - psnr: 15.9071 - ssim_metric: 0.5856 - val_loss: 0.0254 - val_psnr: 15.9715 - val_ssim_metric: 0.5830
# Epoch 21/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0253 - psnr: 15.9799 - ssim_metric: 0.5873
# Epoch 21: val_loss improved from 0.02535 to 0.02507, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 176ms/step - loss: 0.0253 - psnr: 15.9796 - ssim_metric: 0.5874 - val_loss: 0.0251 - val_psnr: 16.0201 - val_ssim_metric: 0.5858
# Epoch 22/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0248 - psnr: 16.0626 - ssim_metric: 0.5911
# Epoch 22: val_loss improved from 0.02507 to 0.02496, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - loss: 0.0248 - psnr: 16.0612 - ssim_metric: 0.5910 - val_loss: 0.0250 - val_psnr: 16.0382 - val_ssim_metric: 0.5862
# Epoch 23/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0250 - psnr: 16.0435 - ssim_metric: 0.5912
# Epoch 23: val_loss improved from 0.02496 to 0.02468, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - loss: 0.0250 - psnr: 16.0442 - ssim_metric: 0.5912 - val_loss: 0.0247 - val_psnr: 16.0886 - val_ssim_metric: 0.5900
# Epoch 24/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0246 - psnr: 16.1019 - ssim_metric: 0.5941
# Epoch 24: val_loss did not improve from 0.02468
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 0.0246 - psnr: 16.1009 - ssim_metric: 0.5941 - val_loss: 0.0248 - val_psnr: 16.0721 - val_ssim_metric: 0.5897
# Epoch 25/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0245 - psnr: 16.1122 - ssim_metric: 0.5984
# Epoch 25: val_loss improved from 0.02468 to 0.02429, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - loss: 0.0245 - psnr: 16.1123 - ssim_metric: 0.5982 - val_loss: 0.0243 - val_psnr: 16.1576 - val_ssim_metric: 0.5915
# Epoch 26/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0247 - psnr: 16.0809 - ssim_metric: 0.5939
# Epoch 26: val_loss did not improve from 0.02429
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 160ms/step - loss: 0.0247 - psnr: 16.0823 - ssim_metric: 0.5939 - val_loss: 0.0258 - val_psnr: 15.9031 - val_ssim_metric: 0.5812
# Epoch 27/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0247 - psnr: 16.0872 - ssim_metric: 0.5925
# Epoch 27: val_loss improved from 0.02429 to 0.02395, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - loss: 0.0247 - psnr: 16.0891 - ssim_metric: 0.5926 - val_loss: 0.0240 - val_psnr: 16.2183 - val_ssim_metric: 0.5948
# Epoch 28/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0236 - psnr: 16.3020 - ssim_metric: 0.5992
# Epoch 28: val_loss improved from 0.02395 to 0.02382, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 175ms/step - loss: 0.0236 - psnr: 16.3000 - ssim_metric: 0.5992 - val_loss: 0.0238 - val_psnr: 16.2429 - val_ssim_metric: 0.5953
# Epoch 29/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0238 - psnr: 16.2477 - ssim_metric: 0.6008
# Epoch 29: val_loss improved from 0.02382 to 0.02369, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.0238 - psnr: 16.2481 - ssim_metric: 0.6008 - val_loss: 0.0237 - val_psnr: 16.2665 - val_ssim_metric: 0.5973
# Epoch 30/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0236 - psnr: 16.2783 - ssim_metric: 0.5992
# Epoch 30: val_loss improved from 0.02369 to 0.02358, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 176ms/step - loss: 0.0236 - psnr: 16.2784 - ssim_metric: 0.5992 - val_loss: 0.0236 - val_psnr: 16.2863 - val_ssim_metric: 0.5979
# Epoch 31/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0232 - psnr: 16.3661 - ssim_metric: 0.6011
# Epoch 31: val_loss improved from 0.02358 to 0.02334, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - loss: 0.0232 - psnr: 16.3642 - ssim_metric: 0.6012 - val_loss: 0.0233 - val_psnr: 16.3302 - val_ssim_metric: 0.6000
# Epoch 32/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0231 - psnr: 16.3764 - ssim_metric: 0.6029
# Epoch 32: val_loss improved from 0.02334 to 0.02320, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - loss: 0.0231 - psnr: 16.3747 - ssim_metric: 0.6029 - val_loss: 0.0232 - val_psnr: 16.3568 - val_ssim_metric: 0.6009
# Epoch 33/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0233 - psnr: 16.3399 - ssim_metric: 0.6044
# Epoch 33: val_loss improved from 0.02320 to 0.02314, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - loss: 0.0233 - psnr: 16.3407 - ssim_metric: 0.6044 - val_loss: 0.0231 - val_psnr: 16.3683 - val_ssim_metric: 0.6002
# Epoch 34/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0232 - psnr: 16.3589 - ssim_metric: 0.6059
# Epoch 34: val_loss improved from 0.02314 to 0.02301, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 168ms/step - loss: 0.0232 - psnr: 16.3599 - ssim_metric: 0.6059 - val_loss: 0.0230 - val_psnr: 16.3932 - val_ssim_metric: 0.6027
# Epoch 35/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0229 - psnr: 16.4042 - ssim_metric: 0.6068
# Epoch 35: val_loss improved from 0.02301 to 0.02292, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 175ms/step - loss: 0.0229 - psnr: 16.4043 - ssim_metric: 0.6067 - val_loss: 0.0229 - val_psnr: 16.4105 - val_ssim_metric: 0.6028
# Epoch 36/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0232 - psnr: 16.3560 - ssim_metric: 0.6092
# Epoch 36: val_loss improved from 0.02292 to 0.02289, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - loss: 0.0232 - psnr: 16.3587 - ssim_metric: 0.6091 - val_loss: 0.0229 - val_psnr: 16.4160 - val_ssim_metric: 0.6054
# Epoch 37/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0226 - psnr: 16.4600 - ssim_metric: 0.6112
# Epoch 37: val_loss improved from 0.02289 to 0.02272, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 171ms/step - loss: 0.0226 - psnr: 16.4600 - ssim_metric: 0.6111 - val_loss: 0.0227 - val_psnr: 16.4468 - val_ssim_metric: 0.6064
# Epoch 38/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0221 - psnr: 16.5819 - ssim_metric: 0.6078
# Epoch 38: val_loss improved from 0.02272 to 0.02268, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.0221 - psnr: 16.5788 - ssim_metric: 0.6078 - val_loss: 0.0227 - val_psnr: 16.4552 - val_ssim_metric: 0.6039
# Epoch 39/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0222 - psnr: 16.5562 - ssim_metric: 0.6122
# Epoch 39: val_loss improved from 0.02268 to 0.02246, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.0222 - psnr: 16.5543 - ssim_metric: 0.6121 - val_loss: 0.0225 - val_psnr: 16.4980 - val_ssim_metric: 0.6061
# Epoch 40/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0224 - psnr: 16.5106 - ssim_metric: 0.6107
# Epoch 40: val_loss improved from 0.02246 to 0.02234, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 168ms/step - loss: 0.0224 - psnr: 16.5108 - ssim_metric: 0.6107 - val_loss: 0.0223 - val_psnr: 16.5211 - val_ssim_metric: 0.6068
# Epoch 41/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0223 - psnr: 16.5370 - ssim_metric: 0.6136
# Epoch 41: val_loss improved from 0.02234 to 0.02216, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 173ms/step - loss: 0.0223 - psnr: 16.5366 - ssim_metric: 0.6135 - val_loss: 0.0222 - val_psnr: 16.5565 - val_ssim_metric: 0.6095
# Epoch 42/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0222 - psnr: 16.5484 - ssim_metric: 0.6134
# Epoch 42: val_loss improved from 0.02216 to 0.02209, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 172ms/step - loss: 0.0222 - psnr: 16.5482 - ssim_metric: 0.6133 - val_loss: 0.0221 - val_psnr: 16.5706 - val_ssim_metric: 0.6099
# Epoch 43/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0223 - psnr: 16.5234 - ssim_metric: 0.6145
# Epoch 43: val_loss did not improve from 0.02209
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 0.0223 - psnr: 16.5250 - ssim_metric: 0.6145 - val_loss: 0.0221 - val_psnr: 16.5669 - val_ssim_metric: 0.6088
# Epoch 44/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0219 - psnr: 16.6000 - ssim_metric: 0.6163
# Epoch 44: val_loss improved from 0.02209 to 0.02185, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 167ms/step - loss: 0.0219 - psnr: 16.5999 - ssim_metric: 0.6163 - val_loss: 0.0219 - val_psnr: 16.6171 - val_ssim_metric: 0.6116
# Epoch 45/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0220 - psnr: 16.5936 - ssim_metric: 0.6158
# Epoch 45: val_loss did not improve from 0.02185
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 0.0220 - psnr: 16.5947 - ssim_metric: 0.6158 - val_loss: 0.0219 - val_psnr: 16.6150 - val_ssim_metric: 0.6114
# Epoch 46/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0217 - psnr: 16.6562 - ssim_metric: 0.6181
# Epoch 46: val_loss improved from 0.02185 to 0.02174, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - loss: 0.0217 - psnr: 16.6556 - ssim_metric: 0.6180 - val_loss: 0.0217 - val_psnr: 16.6393 - val_ssim_metric: 0.6134
# Epoch 47/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0211 - psnr: 16.7825 - ssim_metric: 0.6222
# Epoch 47: val_loss improved from 0.02174 to 0.02160, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.0211 - psnr: 16.7789 - ssim_metric: 0.6220 - val_loss: 0.0216 - val_psnr: 16.6671 - val_ssim_metric: 0.6140
# Epoch 48/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0216 - psnr: 16.6653 - ssim_metric: 0.6204
# Epoch 48: val_loss did not improve from 0.02160
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - loss: 0.0216 - psnr: 16.6654 - ssim_metric: 0.6203 - val_loss: 0.0216 - val_psnr: 16.6644 - val_ssim_metric: 0.6155
# Epoch 49/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0217 - psnr: 16.6503 - ssim_metric: 0.6175
# Epoch 49: val_loss improved from 0.02160 to 0.02147, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.0217 - psnr: 16.6517 - ssim_metric: 0.6176 - val_loss: 0.0215 - val_psnr: 16.6950 - val_ssim_metric: 0.6166
# Epoch 50/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0214 - psnr: 16.7121 - ssim_metric: 0.6212
# Epoch 50: val_loss improved from 0.02147 to 0.02141, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - loss: 0.0214 - psnr: 16.7123 - ssim_metric: 0.6212 - val_loss: 0.0214 - val_psnr: 16.7068 - val_ssim_metric: 0.6165
# Epoch 51/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0210 - psnr: 16.8023 - ssim_metric: 0.6198
# Epoch 51: val_loss improved from 0.02141 to 0.02129, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - loss: 0.0210 - psnr: 16.8003 - ssim_metric: 0.6198 - val_loss: 0.0213 - val_psnr: 16.7299 - val_ssim_metric: 0.6166
# Epoch 52/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0215 - psnr: 16.6736 - ssim_metric: 0.6189
# Epoch 52: val_loss improved from 0.02129 to 0.02117, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 173ms/step - loss: 0.0215 - psnr: 16.6757 - ssim_metric: 0.6190 - val_loss: 0.0212 - val_psnr: 16.7548 - val_ssim_metric: 0.6180
# Epoch 53/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0213 - psnr: 16.7264 - ssim_metric: 0.6185
# Epoch 53: val_loss did not improve from 0.02117
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - loss: 0.0213 - psnr: 16.7276 - ssim_metric: 0.6186 - val_loss: 0.0214 - val_psnr: 16.7038 - val_ssim_metric: 0.6165
# Epoch 54/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0209 - psnr: 16.8031 - ssim_metric: 0.6240
# Epoch 54: val_loss improved from 0.02117 to 0.02113, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 176ms/step - loss: 0.0209 - psnr: 16.8015 - ssim_metric: 0.6240 - val_loss: 0.0211 - val_psnr: 16.7631 - val_ssim_metric: 0.6209
# Epoch 55/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0216 - psnr: 16.6777 - ssim_metric: 0.6204
# Epoch 55: val_loss improved from 0.02113 to 0.02101, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 173ms/step - loss: 0.0215 - psnr: 16.6811 - ssim_metric: 0.6205 - val_loss: 0.0210 - val_psnr: 16.7891 - val_ssim_metric: 0.6197
# Epoch 56/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0210 - psnr: 16.7847 - ssim_metric: 0.6235
# Epoch 56: val_loss improved from 0.02101 to 0.02085, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 177ms/step - loss: 0.0210 - psnr: 16.7858 - ssim_metric: 0.6235 - val_loss: 0.0208 - val_psnr: 16.8221 - val_ssim_metric: 0.6216
# Epoch 57/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0206 - psnr: 16.8824 - ssim_metric: 0.6220
# Epoch 57: val_loss improved from 0.02085 to 0.02077, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - loss: 0.0206 - psnr: 16.8808 - ssim_metric: 0.6221 - val_loss: 0.0208 - val_psnr: 16.8378 - val_ssim_metric: 0.6224
# Epoch 58/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0205 - psnr: 16.8828 - ssim_metric: 0.6276
# Epoch 58: val_loss did not improve from 0.02077
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 154ms/step - loss: 0.0205 - psnr: 16.8815 - ssim_metric: 0.6276 - val_loss: 0.0208 - val_psnr: 16.8298 - val_ssim_metric: 0.6225
# Epoch 59/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0207 - psnr: 16.8507 - ssim_metric: 0.6250
# Epoch 59: val_loss improved from 0.02077 to 0.02069, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - loss: 0.0207 - psnr: 16.8508 - ssim_metric: 0.6250 - val_loss: 0.0207 - val_psnr: 16.8550 - val_ssim_metric: 0.6222
# Epoch 60/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0202 - psnr: 16.9600 - ssim_metric: 0.6303
# Epoch 60: val_loss improved from 0.02069 to 0.02064, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.0202 - psnr: 16.9568 - ssim_metric: 0.6302 - val_loss: 0.0206 - val_psnr: 16.8654 - val_ssim_metric: 0.6229
# Epoch 61/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0206 - psnr: 16.8735 - ssim_metric: 0.6278
# Epoch 61: val_loss improved from 0.02064 to 0.02054, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - loss: 0.0206 - psnr: 16.8738 - ssim_metric: 0.6278 - val_loss: 0.0205 - val_psnr: 16.8871 - val_ssim_metric: 0.6254
# Epoch 62/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0202 - psnr: 16.9599 - ssim_metric: 0.6302
# Epoch 62: val_loss improved from 0.02054 to 0.02048, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.0202 - psnr: 16.9583 - ssim_metric: 0.6302 - val_loss: 0.0205 - val_psnr: 16.8991 - val_ssim_metric: 0.6254
# Epoch 63/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0208 - psnr: 16.8201 - ssim_metric: 0.6267
# Epoch 63: val_loss improved from 0.02048 to 0.02044, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - loss: 0.0208 - psnr: 16.8230 - ssim_metric: 0.6268 - val_loss: 0.0204 - val_psnr: 16.9077 - val_ssim_metric: 0.6265
# Epoch 64/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0206 - psnr: 16.8730 - ssim_metric: 0.6282
# Epoch 64: val_loss did not improve from 0.02044
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 154ms/step - loss: 0.0206 - psnr: 16.8746 - ssim_metric: 0.6283 - val_loss: 0.0205 - val_psnr: 16.8990 - val_ssim_metric: 0.6255
# Epoch 65/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0204 - psnr: 16.9284 - ssim_metric: 0.6279
# Epoch 65: val_loss improved from 0.02044 to 0.02026, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 167ms/step - loss: 0.0204 - psnr: 16.9282 - ssim_metric: 0.6280 - val_loss: 0.0203 - val_psnr: 16.9456 - val_ssim_metric: 0.6278
# Epoch 66/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0206 - psnr: 16.8840 - ssim_metric: 0.6302
# Epoch 66: val_loss did not improve from 0.02026
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 160ms/step - loss: 0.0206 - psnr: 16.8864 - ssim_metric: 0.6302 - val_loss: 0.0203 - val_psnr: 16.9385 - val_ssim_metric: 0.6267
# Epoch 67/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0211 - psnr: 16.7742 - ssim_metric: 0.6284
# Epoch 67: val_loss improved from 0.02026 to 0.02014, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - loss: 0.0211 - psnr: 16.7803 - ssim_metric: 0.6285 - val_loss: 0.0201 - val_psnr: 16.9714 - val_ssim_metric: 0.6290
# Epoch 68/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0202 - psnr: 16.9594 - ssim_metric: 0.6308
# Epoch 68: val_loss did not improve from 0.02014
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - loss: 0.0202 - psnr: 16.9599 - ssim_metric: 0.6309 - val_loss: 0.0202 - val_psnr: 16.9690 - val_ssim_metric: 0.6282
# Epoch 69/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0201 - psnr: 16.9748 - ssim_metric: 0.6329
# Epoch 69: val_loss did not improve from 0.02014
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0201 - psnr: 16.9749 - ssim_metric: 0.6329 - val_loss: 0.0202 - val_psnr: 16.9591 - val_ssim_metric: 0.6277
# Epoch 70/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0203 - psnr: 16.9345 - ssim_metric: 0.6342
# Epoch 70: val_loss improved from 0.02014 to 0.02000, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - loss: 0.0203 - psnr: 16.9369 - ssim_metric: 0.6342 - val_loss: 0.0200 - val_psnr: 17.0036 - val_ssim_metric: 0.6307
# Epoch 71/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0196 - psnr: 17.0980 - ssim_metric: 0.6347
# Epoch 71: val_loss improved from 0.02000 to 0.01998, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - loss: 0.0196 - psnr: 17.0960 - ssim_metric: 0.6347 - val_loss: 0.0200 - val_psnr: 17.0075 - val_ssim_metric: 0.6308
# Epoch 72/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0201 - psnr: 16.9911 - ssim_metric: 0.6346
# Epoch 72: val_loss improved from 0.01998 to 0.01993, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.0201 - psnr: 16.9923 - ssim_metric: 0.6346 - val_loss: 0.0199 - val_psnr: 17.0169 - val_ssim_metric: 0.6313
# Epoch 73/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0200 - psnr: 17.0088 - ssim_metric: 0.6326
# Epoch 73: val_loss did not improve from 0.01993
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - loss: 0.0200 - psnr: 17.0097 - ssim_metric: 0.6327 - val_loss: 0.0200 - val_psnr: 17.0003 - val_ssim_metric: 0.6329
# Epoch 74/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0204 - psnr: 16.9070 - ssim_metric: 0.6347
# Epoch 74: val_loss improved from 0.01993 to 0.01980, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - loss: 0.0204 - psnr: 16.9110 - ssim_metric: 0.6347 - val_loss: 0.0198 - val_psnr: 17.0472 - val_ssim_metric: 0.6321
# Epoch 75/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0196 - psnr: 17.0949 - ssim_metric: 0.6367
# Epoch 75: val_loss did not improve from 0.01980
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 158ms/step - loss: 0.0196 - psnr: 17.0937 - ssim_metric: 0.6367 - val_loss: 0.0199 - val_psnr: 17.0211 - val_ssim_metric: 0.6316
# Epoch 76/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0198 - psnr: 17.0477 - ssim_metric: 0.6363
# Epoch 76: val_loss improved from 0.01980 to 0.01971, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 178ms/step - loss: 0.0198 - psnr: 17.0483 - ssim_metric: 0.6363 - val_loss: 0.0197 - val_psnr: 17.0658 - val_ssim_metric: 0.6330
# Epoch 77/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0194 - psnr: 17.1307 - ssim_metric: 0.6393
# Epoch 77: val_loss did not improve from 0.01971
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 0.0194 - psnr: 17.1293 - ssim_metric: 0.6392 - val_loss: 0.0197 - val_psnr: 17.0645 - val_ssim_metric: 0.6328
# Epoch 78/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0198 - psnr: 17.0446 - ssim_metric: 0.6366
# Epoch 78: val_loss improved from 0.01971 to 0.01966, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 169ms/step - loss: 0.0198 - psnr: 17.0464 - ssim_metric: 0.6367 - val_loss: 0.0197 - val_psnr: 17.0772 - val_ssim_metric: 0.6336
# Epoch 79/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0195 - psnr: 17.1004 - ssim_metric: 0.6375
# Epoch 79: val_loss improved from 0.01966 to 0.01961, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.0195 - psnr: 17.1006 - ssim_metric: 0.6375 - val_loss: 0.0196 - val_psnr: 17.0873 - val_ssim_metric: 0.6344
# Epoch 80/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0198 - psnr: 17.0532 - ssim_metric: 0.6387
# Epoch 80: val_loss improved from 0.01961 to 0.01955, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - loss: 0.0198 - psnr: 17.0553 - ssim_metric: 0.6387 - val_loss: 0.0195 - val_psnr: 17.1021 - val_ssim_metric: 0.6355
# Epoch 81/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0197 - psnr: 17.0725 - ssim_metric: 0.6387
# Epoch 81: val_loss improved from 0.01955 to 0.01947, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - loss: 0.0197 - psnr: 17.0744 - ssim_metric: 0.6387 - val_loss: 0.0195 - val_psnr: 17.1207 - val_ssim_metric: 0.6358
# Epoch 82/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0191 - psnr: 17.2001 - ssim_metric: 0.6360
# Epoch 82: val_loss did not improve from 0.01947
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 159ms/step - loss: 0.0191 - psnr: 17.1982 - ssim_metric: 0.6361 - val_loss: 0.0195 - val_psnr: 17.1040 - val_ssim_metric: 0.6360
# Epoch 83/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0195 - psnr: 17.1148 - ssim_metric: 0.6391
# Epoch 83: val_loss improved from 0.01947 to 0.01941, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 170ms/step - loss: 0.0195 - psnr: 17.1156 - ssim_metric: 0.6391 - val_loss: 0.0194 - val_psnr: 17.1331 - val_ssim_metric: 0.6367
# Epoch 84/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0193 - psnr: 17.1468 - ssim_metric: 0.6417
# Epoch 84: val_loss improved from 0.01941 to 0.01936, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 174ms/step - loss: 0.0193 - psnr: 17.1471 - ssim_metric: 0.6417 - val_loss: 0.0194 - val_psnr: 17.1449 - val_ssim_metric: 0.6375
# Epoch 85/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0190 - psnr: 17.2221 - ssim_metric: 0.6419
# Epoch 85: val_loss improved from 0.01936 to 0.01927, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 178ms/step - loss: 0.0190 - psnr: 17.2203 - ssim_metric: 0.6419 - val_loss: 0.0193 - val_psnr: 17.1651 - val_ssim_metric: 0.6378
# Epoch 86/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0190 - psnr: 17.2281 - ssim_metric: 0.6421
# Epoch 86: val_loss improved from 0.01927 to 0.01925, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 169ms/step - loss: 0.0190 - psnr: 17.2264 - ssim_metric: 0.6421 - val_loss: 0.0193 - val_psnr: 17.1682 - val_ssim_metric: 0.6383
# Epoch 87/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0191 - psnr: 17.1962 - ssim_metric: 0.6391
# Epoch 87: val_loss improved from 0.01925 to 0.01923, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.0191 - psnr: 17.1952 - ssim_metric: 0.6392 - val_loss: 0.0192 - val_psnr: 17.1739 - val_ssim_metric: 0.6387
# Epoch 88/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0191 - psnr: 17.1972 - ssim_metric: 0.6428
# Epoch 88: val_loss did not improve from 0.01923
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 153ms/step - loss: 0.0191 - psnr: 17.1971 - ssim_metric: 0.6428 - val_loss: 0.0193 - val_psnr: 17.1560 - val_ssim_metric: 0.6374
# Epoch 89/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0195 - psnr: 17.1135 - ssim_metric: 0.6414
# Epoch 89: val_loss improved from 0.01923 to 0.01917, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 169ms/step - loss: 0.0195 - psnr: 17.1159 - ssim_metric: 0.6415 - val_loss: 0.0192 - val_psnr: 17.1883 - val_ssim_metric: 0.6397
# Epoch 90/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0191 - psnr: 17.2016 - ssim_metric: 0.6420
# Epoch 90: val_loss improved from 0.01917 to 0.01909, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 170ms/step - loss: 0.0191 - psnr: 17.2022 - ssim_metric: 0.6420 - val_loss: 0.0191 - val_psnr: 17.2043 - val_ssim_metric: 0.6398
# Epoch 91/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0193 - psnr: 17.1633 - ssim_metric: 0.6425
# Epoch 91: val_loss did not improve from 0.01909
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 158ms/step - loss: 0.0193 - psnr: 17.1653 - ssim_metric: 0.6426 - val_loss: 0.0191 - val_psnr: 17.1987 - val_ssim_metric: 0.6395
# Epoch 92/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0186 - psnr: 17.3045 - ssim_metric: 0.6458
# Epoch 92: val_loss improved from 0.01909 to 0.01900, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 11s 169ms/step - loss: 0.0187 - psnr: 17.3025 - ssim_metric: 0.6458 - val_loss: 0.0190 - val_psnr: 17.2253 - val_ssim_metric: 0.6406
# Epoch 93/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0191 - psnr: 17.2027 - ssim_metric: 0.6405
# Epoch 93: val_loss improved from 0.01900 to 0.01895, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 172ms/step - loss: 0.0191 - psnr: 17.2043 - ssim_metric: 0.6407 - val_loss: 0.0190 - val_psnr: 17.2371 - val_ssim_metric: 0.6415
# Epoch 94/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0185 - psnr: 17.3451 - ssim_metric: 0.6482
# Epoch 94: val_loss did not improve from 0.01895
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 157ms/step - loss: 0.0185 - psnr: 17.3423 - ssim_metric: 0.6481 - val_loss: 0.0191 - val_psnr: 17.2027 - val_ssim_metric: 0.6393
# Epoch 95/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0191 - psnr: 17.1998 - ssim_metric: 0.6437
# Epoch 95: val_loss did not improve from 0.01895
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - loss: 0.0191 - psnr: 17.2016 - ssim_metric: 0.6438 - val_loss: 0.0191 - val_psnr: 17.2105 - val_ssim_metric: 0.6406
# Epoch 96/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0188 - psnr: 17.2757 - ssim_metric: 0.6454
# Epoch 96: val_loss did not improve from 0.01895
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 155ms/step - loss: 0.0188 - psnr: 17.2747 - ssim_metric: 0.6454 - val_loss: 0.0190 - val_psnr: 17.2247 - val_ssim_metric: 0.6401
# Epoch 97/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0190 - psnr: 17.2331 - ssim_metric: 0.6443
# Epoch 97: val_loss improved from 0.01895 to 0.01885, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 171ms/step - loss: 0.0190 - psnr: 17.2340 - ssim_metric: 0.6443 - val_loss: 0.0189 - val_psnr: 17.2605 - val_ssim_metric: 0.6422
# Epoch 98/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0188 - psnr: 17.2576 - ssim_metric: 0.6456
# Epoch 98: val_loss improved from 0.01885 to 0.01882, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 5s 169ms/step - loss: 0.0188 - psnr: 17.2583 - ssim_metric: 0.6456 - val_loss: 0.0188 - val_psnr: 17.2662 - val_ssim_metric: 0.6426
# Epoch 99/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0184 - psnr: 17.3502 - ssim_metric: 0.6480
# Epoch 99: val_loss improved from 0.01882 to 0.01880, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 175ms/step - loss: 0.0184 - psnr: 17.3481 - ssim_metric: 0.6480 - val_loss: 0.0188 - val_psnr: 17.2724 - val_ssim_metric: 0.6437
# Epoch 100/100
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0187 - psnr: 17.2968 - ssim_metric: 0.6490
# Epoch 100: val_loss improved from 0.01880 to 0.01871, saving model to checkpoint_oxford_flowers/best_weights.keras
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 10s 171ms/step - loss: 0.0187 - psnr: 17.2972 - ssim_metric: 0.6489 - val_loss: 0.0187 - val_psnr: 17.2940 - val_ssim_metric: 0.6444
#
# 🚀 Training Completed in 12 min 35 sec
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step
# Training and visualization complete.
